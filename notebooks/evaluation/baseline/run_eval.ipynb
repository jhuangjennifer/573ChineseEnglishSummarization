# %%
# 1. Upload evaluate.py, mbart_predictions.txt, mbart_predictions_en
# from google.colab import files
# files.upload()

# 2. Install dependencies
# !pip install datasets bert-score pandas
# !pip install pyonmttok jieba six nltk absl-py
# !pip install git+https://github.com/csebuetnlp/xl-sum.git#subdirectory=multilingual_rouge_scoring
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 52.7 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/csebuetnlp/xl-sum.git to /tmp/pip-req-build-oej1kz1d
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/xl-sum.git /tmp/pip-req-build-oej1kz1d
#   Resolved https://github.com/csebuetnlp/xl-sum.git to commit afcd803c8d7c98f3be60e9a7ce57fcbc3e729e8c
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.0.0-py3-none-any.whl size=18148 sha256=fdeba8ab124a74656dbf1a8ad012d225ecef44e4023b0e572432c0df29c3f9fb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7szxy6s9/wheels/31/f9/91/cbf1c98e41ee8da7ad1cbe2f42d08ec3b422488558ff95abf5
# Successfully built rouge_score
# ...

# %%
# !pip install nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')      # often needed by the same code path
nltk.download('punkt_tab')  # NLTK 3.8.2+ split punkt into punkt_tab
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# 3. Run
# !python evaluate.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.606 seconds.
# Prefix dict has been built successfully.
# /usr/local/lib/python3.12/dist-packages/rouge_score/rouge_scorer.py:116: UserWarning: -----unknown stemmer language-> chinese-----
#   warnings.warn(
# Chinese:
#   ROUGE-1 (R1) : 33.60
#   ROUGE-2 (R2) : 11.74
#   ROUGE-L (R-L): 28.38
# config.json: 100% 647/647 [00:00<00:00, 3.39MB/s]
# ...
