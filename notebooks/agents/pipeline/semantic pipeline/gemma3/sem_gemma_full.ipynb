# %% [markdown]
# # Semantic-Agent Pipeline for English-to-Chinese Dialogue Summarization
#
# This notebook implements a local semantic-agent pipeline for English-to-Chinese cross-lingual dialogue summarization.
#
# The semantic pipeline uses three local small language model agents. Agent 1 reads the original English dialogue and extracts a structured semantic representation, including participants, speaker intent, actor/action/recipient relations, key events, and the final outcome. Agent 2 selects the most salient events and generates a draft Chinese summary. Agent 3 verifies the draft summary against the original dialogue and revises it only if necessary.
#
# ```text
# English Dialogue
# → Agent 1: Semantic Understanding Agent
# → Agent 2: Event Selection and Chinese Summary Generation Agent
# → Agent 3: Verification and Revision Agent
# → Final Chinese Summary
# ```
#
# The pipeline consists of three agents:
#
# ```text
# Agent 1: Semantic Understanding Agent
# Input: original English dialogue
# Output: structured semantic representation
#
# Agent 2: Event Selection and Chinese Summary Generation Agent
# Input: structured semantic representation from Agent 1
# Output: selected events and draft Chinese summary
#
# Agent 3: Verification and Revision Agent
# Input: original dialogue + Agent 2 selected events and draft summary
# Output: revised final Chinese summary
# ```
# This setup is used as the proposed semantic-agent pipeline. Unlike Direct, Translate-then-Summarize, and Summarize-then-Translate baselines, this pipeline explicitly represents pragmatic meaning, semantic roles, actor/action relations, and final dialogue outcomes before generating the final Chinese summary.
#
# The local small language models are served through Ollama. The notebook controls prompt design, JSON parsing, intermediate output inspection, verification/revision, checkpointing, and result saving.

# %% [markdown]
# ## 0. Local Ollama Setup
#
# Before running this notebook, install Ollama and download the model locally.
#
# ### Recommended model setup
#
# This notebook uses a single-model multi-agent setup. All three agents use gemma3:27b.
#
# ```bash
# ollama pull gemma3:27b
# ```
#
# You can check downloaded models with:
#
# ```bash
# ollama list
# ```
#
# You can check currently loaded models with:
#
# ```bash
# ollama ps
# ```
#
# If the Ollama server is not running, start it with:
#
# ```bash
# ollama serve
# ```
#
# On macOS, opening the Ollama app usually starts the local server automatically.

# %%
# Cell 1: Install required Python packages.
# Run this only once if the packages are not installed

# !pip install requests pandas tqdm
# Out:
# Requirement already satisfied: requests in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.33.1)
# Requirement already satisfied: pandas in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: colorama in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Cell 2: Imports and global configuration

import json
import time
from pathlib import Path
from typing import Any, Dict, List, Optional

import requests
import pandas as pd
from tqdm.auto import tqdm

OLLAMA_HOST = "http://localhost:11434"

# Semantic-agent models
# All agents use the same 27B model for a consistent model-capacity setting.
SEMANTIC_UNDERSTANDING_MODEL = "gemma3:27b"
SUMMARY_GENERATION_MODEL = "gemma3:27b"
REVISION_MODEL = "gemma3:27b"

DEFAULT_TEMPERATURE = 0.2
DEFAULT_NUM_CTX = 4096
REVISION_NUM_CTX = 4096

# window project path
PROJECT_ROOT = Path(
    r"C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu"
)

# Gold set path
GOLD_SET_PATH = PROJECT_ROOT / "gold_set_50_zh_XSAMSum_bart.json"

# Output directory
OUTPUT_DIR = PROJECT_ROOT
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# Output files for semantic-agent pipeline
INTERMEDIATE_OUTPUT_PATH = OUTPUT_DIR / "semantic_gemma27b_50samples_intermediate.jsonl"
FULL_OUTPUT_PATH = OUTPUT_DIR / "semantic_gemma27b_50samples.jsonl"
FINAL_CSV_PATH = OUTPUT_DIR / "semantic_gemma27b_50samples.csv"
ERROR_OUTPUT_PATH = OUTPUT_DIR / "semantic_gemma27b_50samples_errors.jsonl"

print("Gold set path:", GOLD_SET_PATH)
print("Output directory:", OUTPUT_DIR)
print("Intermediate JSONL output path:", INTERMEDIATE_OUTPUT_PATH)
print("Full JSONL output path:", FULL_OUTPUT_PATH)
print("Final CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)

print("Agent 1 model:", SEMANTIC_UNDERSTANDING_MODEL)
print("Agent 2 model:", SUMMARY_GENERATION_MODEL)
print("Agent 3 model:", REVISION_MODEL)
# Out:
# Gold set path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\gold_set_50_zh_XSAMSum_bart.json
# Output directory: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu
# Intermediate JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples_intermediate.jsonl
# Full JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.jsonl
# Final CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples_errors.jsonl
# Agent 1 model: gemma3:27b
# Agent 2 model: gemma3:27b
# Agent 3 model: gemma3:27b

# %%
print(GOLD_SET_PATH.exists())
# Out:
# True

# %%
# Cell 3: Check whether Ollama is running

def check_ollama_server() -> bool:
    try:
        response = requests.get(f"{OLLAMA_HOST}/api/tags", timeout=10)
        response.raise_for_status()
        models = response.json().get("models", [])

        print("Ollama server is running.")
        print(f"Downloaded models: {[m.get('name') for m in models]}")

        return True

    except Exception as e:
        print("Could not connect to Ollama.")
        print("Make sure Ollama is installed and running.")
        print("Try running this in Terminal:")
        print("  ollama serve")
        print()
        print("Error:", repr(e))

        return False


_ = check_ollama_server()
# Out:
# Ollama server is running.
# Downloaded models: ['aya-expanse:32b', 'gemma3:27b', 'qwen3.5:27b']

# %%
# Cell 4: Ollama API helper

def call_ollama(
    model: str,
    prompt: str,
    system: Optional[str] = None,
    temperature: float = DEFAULT_TEMPERATURE,
    num_ctx: int = DEFAULT_NUM_CTX,
    timeout: int = 900,
    keep_alive: Optional[str] = None,
    json_mode: bool = True,
) -> str:
    """Call Ollama's local chat API and return the assistant content."""

    messages = []

    if system:
        messages.append({"role": "system", "content": system})

    messages.append({"role": "user", "content": prompt})

    payload = {
        "model": model,
        "messages": messages,
        "stream": False,
        "options": {
            "temperature": temperature,
            "num_ctx": num_ctx,
            "num_predict": 1024,
        },
        "think": False,
    }

    if json_mode:
        payload["format"] = "json"

    if keep_alive is not None:
        payload["keep_alive"] = keep_alive

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=timeout,
    )
    response.raise_for_status()

    data = response.json()
    content = data.get("message", {}).get("content", "")

    if content is None:
        content = ""

    return content.strip()


def load_ollama_model(model: str) -> None:
    """Preload a model into Ollama memory."""
    payload = {
        "model": model,
        "messages": [],
        "stream": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=300,
    )
    response.raise_for_status()

    print(f"Loaded model: {model}")


def unload_ollama_model(model: str) -> None:
    """Unload a model from Ollama memory."""
    payload = {
        "model": model,
        "messages": [],
        "keep_alive": 0,
        "stream": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=300,
    )
    response.raise_for_status()

    print(f"Unloaded model: {model}")

# %% [markdown]
# ## 1. Prompt Templates
#
# Each agent is defined as:
#
# ```text
# Agent = model + role-specific prompt + input/output format
# ```
#
# In the first version, we use a fixed workflow rather than a fully autonomous agent system.

# %%
# Cell 5: Prompt templates

# Agent 1: Semantic Understanding
SEMANTIC_UNDERSTANDING_PROMPT = """Analyze the English dialogue and extract only the key semantic events needed for the final summary.

Focus on:
- participants
- speaker intent
- actor/action/recipient relations
- final decisions, refusals, commitments, changed plans, or cancellations
- the final outcome of the dialogue

Rules:
- Do not analyze every utterance.
- Ignore greetings, jokes, reactions, and closings unless they affect the outcome.
- Resolve ambiguity from context.
- For imperatives, the actor is usually the listener, not the speaker.
  Example: if A says "Just text him" to B, B is the actor.
- Do not infer visual details from placeholders such as <file_photo>, <file_gif>, or <file>.

Extract 1-6 key events. Use fewer events for simple dialogues.
Write final_outcome as one concise sentence.

Output valid JSON only.

Schema:
{
  "participants": ["speaker names"],
  "semantic_grounding": [
    {
      "event_id": 1,
      "speaker": "speaker name",
      "speech_act": "short label",
      "intended_meaning": "concise interpretation",
      "actor": "person or null",
      "action": "concise action",
      "object": "object or null",
      "recipient": "person or null",
      "evidence": ["short quote"]
    }
  ],
  "final_outcome": "one concise sentence"
}

Input dialogue:
{dialogue}

JSON output:
"""

# Agent 2: Event Selection and Chinese Summary Generation
SUMMARY_GENERATION_PROMPT = """You will receive a structured semantic representation of an English dialogue.

Select the most important events and write a concise Chinese summary.

Rules:
- Select only 1-3 salient events.
- Prioritize the final outcome, changed plans, decisions, refusals, commitments, and important actor/action relations.
- If an earlier plan is later changed, summarize the final updated state.
- Do not invent details from placeholders.
- Use natural Chinese.

STRICT TRANSLATION RULE:
- You MUST translate ALL English proper nouns and speaker names into standard Chinese characters (e.g., Paul -> 保罗, Laura -> 劳拉).
- ABSOLUTELY NO English letters or names should appear in the final Chinese summary.

Conciseness:
- For simple dialogues, prefer 20-50 Chinese characters.
- For complex dialogues, allow up to 80 Chinese characters.

Output valid JSON only.

Schema:
{
  "selected_events": [
    {
      "event_id": 1,
      "key_event": "short description"
    }
  ],
  "summary_zh": "Chinese summary"
}

Input semantic representation:
{semantic_representation}

JSON output:
"""

# Agent 3: Concise Verification and Revision
REVISION_PROMPT = """Verify the draft Chinese summary against the original English dialogue.

Revise only if necessary.

Check for:
- hallucination
- missing final outcome
- wrong actor/action/recipient
- missing key event
- outdated plan
- unsupported visual detail
- awkward Chinese
- unnecessary verbosity
- untranslated English names or proper nouns in the draft Chinese summary

Rules:
- Trust the original dialogue if it conflicts with selected_events.
- Do not rewrite merely for style.
- If the draft is correct, keep it exactly unchanged.
- Be extremely concise.
- Use short issue tags only.
- revision_reason must be under 12 words.
- Output valid JSON only.

Conciseness:
- For simple dialogues, prefer 20-50 Chinese characters.
- For complex dialogues, allow up to 80 Chinese characters.

Allowed issue tags:
"hallucination", "wrong_actor", "wrong_action", "wrong_recipient",
"missing_final_outcome", "missing_key_event", "outdated_plan",
"too_verbose", "awkward_chinese", "unsupported_visual_detail", "untranslated_names"

Schema:
{
  "needs_revision": false,
  "issues_identified": [],
  "events_dropped": [],
  "revision_reason": "",
  "summary_zh_final": "Chinese summary"
}

Original English dialogue:
{dialogue}

Draft Chinese summary and selected events:
{summary_points}

JSON output:
"""

# %%
# Cell 6: JSONL utility functions

def append_jsonl(record: Dict[str, Any], path: Path) -> None:
    """Append one record to a JSONL file."""
    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")


def load_jsonl(path: Path) -> List[Dict[str, Any]]:
    """Load a JSONL file into a list of dictionaries."""
    if not path.exists():
        return []

    records = []

    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if line:
                records.append(json.loads(line))

    return records


def load_processed_ids(path: Path) -> set:
    """Return IDs that have already been processed."""
    records = load_jsonl(path)

    return {str(record["id"]) for record in records if "id" in record}

# %%
# Cell 7: Agent functions

import re

def fill_prompt(template: str, replacements: Dict[str, str]) -> str:
    """Replace only named placeholders while keeping JSON braces in the prompt unchanged."""
    prompt = template

    for key, value in replacements.items():
        prompt = prompt.replace("{" + key + "}", value)

    return prompt


def extract_json_object(text: str) -> Dict[str, Any]:
    """Extract and parse a JSON object from a model response.

    This function is intentionally robust because small local models may:
    - wrap JSON in markdown fences,
    - add extra text before or after JSON,
    - output Python-style booleans such as True/False.
    """
    raw = text.strip()

    # Remove markdown fences if present.
    if raw.startswith("```"):
        lines = raw.splitlines()
        raw = "\n".join(
            line for line in lines
            if not line.strip().startswith("```")
        ).strip()

    candidates = [raw]

    # Try extracting the substring between the first "{" and the last "}".
    start = raw.find("{")
    end = raw.rfind("}")

    if start != -1 and end != -1 and end > start:
        candidates.append(raw[start:end + 1])

    for candidate in candidates:
        # First try direct JSON parsing.
        try:
            parsed = json.loads(candidate)
            if isinstance(parsed, dict):
                return parsed
        except json.JSONDecodeError:
            pass

        # Repair common Python-style JSON issues.
        repaired = candidate
        repaired = re.sub(r"\bTrue\b", "true", repaired)
        repaired = re.sub(r"\bFalse\b", "false", repaired)
        repaired = re.sub(r"\bNone\b", "null", repaired)

        try:
            parsed = json.loads(repaired)
            if isinstance(parsed, dict):
                return parsed
        except json.JSONDecodeError:
            pass

    # Safe fallback for debugging.
    return {
        "raw_output": text,
        "parse_error": True,
    }


def format_json(data: Any) -> str:
    """Format Python objects as readable JSON text."""
    return json.dumps(
        data,
        ensure_ascii=False,
        indent=2,
    )


def extract_final_chinese_summary(revision_result: Dict[str, Any]) -> str:
    """Extract the final Chinese summary from Agent 3's revision output."""
    summary = revision_result.get("summary_zh_final", "")

    if isinstance(summary, list):
        return " ".join(str(item).strip() for item in summary if str(item).strip())

    if isinstance(summary, str):
        return summary.strip()

    if summary:
        return str(summary).strip()

    # Backward-compatible fallback.
    summary = revision_result.get("summary_zh", "")

    if isinstance(summary, str):
        return summary.strip()

    raw_output = revision_result.get("raw_output", "")

    if isinstance(raw_output, str):
        return raw_output.strip()

    return ""


def semantic_understanding_agent(dialogue: str) -> Dict[str, Any]:
    """Agent 1: Information Extraction Agent.

    Input:
        Original English dialogue

    Output:
        Structured representation of the dialogue
    """
    prompt = fill_prompt(
        SEMANTIC_UNDERSTANDING_PROMPT,
        {
            "dialogue": dialogue,
        },
    )

    response = call_ollama(
        model=SEMANTIC_UNDERSTANDING_MODEL,
        prompt=prompt,
        temperature=0.1,
        num_ctx=DEFAULT_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)

def summary_generation_agent(
    semantic_representation: Dict[str, Any],
) -> Dict[str, Any]:
    """Agent 2: Summary Generation Agent.

    Input:
        Structured semantic representation from Agent 1

    Output:
        Selected key events and draft Chinese summary
    """
    prompt = fill_prompt(
        SUMMARY_GENERATION_PROMPT,
        {
            "semantic_representation": format_json(semantic_representation),
        },
    )

    response = call_ollama(
        model=SUMMARY_GENERATION_MODEL,
        prompt=prompt,
        temperature=0.2,
        num_ctx=DEFAULT_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)


def revision_agent(
    dialogue: str,
    summary_generation_result: Dict[str, Any],
) -> Dict[str, Any]:
    """Agent 3: Verification and Revision Agent.

    Input:
        Original dialogue, selected events, and draft Chinese summary from Agent 2

    Output:
        Revised final Chinese summary
    """
    prompt = fill_prompt(
        REVISION_PROMPT,
        {
            "dialogue": dialogue,
            "summary_points": format_json(summary_generation_result),
        },
    )

    response = call_ollama(
        model=REVISION_MODEL,
        prompt=prompt,
        temperature=0.1,
        num_ctx=REVISION_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)

# %% [markdown]
# ## 2. Agent Functions
#
# Each function corresponds to one agent in the pipeline.

# %%
# Cell 8: Three-agent semantic pipeline

def run_agents_1_2(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run Agent 1 and Agent 2 and save intermediate outputs."""

    sample_id = str(example.get("id", "unknown"))
    dialogue = example["dialogue"]

    reference_english_summary = example.get("reference_english_summary", "")
    reference_chinese_summary = example.get("reference_chinese_summary", "")

    # Agent 1: Semantic Understanding Agent
    semantic_representation = semantic_understanding_agent(dialogue)

    if verbose:
        print("\n" + "=" * 80)
        print(f"Sample ID: {sample_id}")
        print("=== Agent 1 Intermediate Output: Semantic Representation ===")
        print(format_json(semantic_representation))
        print("=" * 80 + "\n")

    # Agent 2: Event Selection and Chinese Summary Generation Agent
    summary_generation = summary_generation_agent(
        semantic_representation=semantic_representation,
    )

    if verbose:
        print("=== Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===")
        print(format_json(summary_generation))
        print("=" * 80 + "\n")

    return {
        "id": sample_id,
        "test_index": example.get("test_index", ""),
        "dialogue": dialogue,

        # References
        "reference_english_summary": reference_english_summary,
        "reference_chinese_summary": reference_chinese_summary,

        # Models
        "agent1_model": SEMANTIC_UNDERSTANDING_MODEL,
        "agent2_model": SUMMARY_GENERATION_MODEL,

        # Intermediate output from Agent 1
        "agent1_semantic_representation": semantic_representation,
        "agent1_semantic_representation_json": format_json(semantic_representation),

        # Intermediate output from Agent 2
        "agent2_summary_generation": summary_generation,
        "agent2_summary_generation_json": format_json(summary_generation),
    }


def run_agent_3_from_intermediate(
    intermediate_record: Dict[str, Any],
    verbose: bool = True,
) -> Dict[str, Any]:
    """Run Agent 3 using saved Agent 1/2 intermediate outputs."""

    dialogue = intermediate_record["dialogue"]
    summary_generation = intermediate_record["agent2_summary_generation"]

    # Agent 3: Verification and Revision Agent
    revision = revision_agent(
        dialogue=dialogue,
        summary_generation_result=summary_generation,
    )

    final_chinese_summary = extract_final_chinese_summary(
        revision_result=revision,
    )

    if verbose:
        print("=== Agent 3 Output: Verification + Revision ===")
        print(format_json(revision))
        print()
        print("=== Final Chinese Summary ===")
        print(final_chinese_summary)
        print("=" * 80 + "\n")

    return {
        **intermediate_record,

        # Model
        "agent3_model": REVISION_MODEL,

        # Agent 3 output
        "agent3_revision": revision,
        "agent3_revision_json": format_json(revision),

        # Final output
        "agent3_final_chinese_summary": final_chinese_summary,
        "final_summary": final_chinese_summary,

        # Metadata
        "pipeline": "semantic_agent",
        "num_model_calls": 3,
    }


def run_three_agent_pipeline(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run the full semantic-agent pipeline for one example."""

    # Since all agents use the same 27B model, load it once.
    load_ollama_model(SEMANTIC_UNDERSTANDING_MODEL)

    # Agent 1 + Agent 2
    intermediate_record = run_agents_1_2(example, verbose=verbose)

    # Agent 3
    final_record = run_agent_3_from_intermediate(
        intermediate_record,
        verbose=verbose,
    )

    return final_record

# %% [markdown]
# ## 3. Test with Examples
#
# Start with five examples before running the full dataset.
# This is the best way to inspect the intermediate outputs between agents.

# %%
# Cell 9: Load first 5 examples from the gold set

def load_examples_from_gold_set(path: Path, n: int = 5) -> List[Dict[str, Any]]:
    """Load the first n examples from the gold-set JSON file."""
    if not path.exists():
        raise FileNotFoundError(f"Gold set not found: {path}")

    with path.open("r", encoding="utf-8") as f:
        raw_data = json.load(f)

    examples = []

    for i, item in enumerate(raw_data[:n]):
        examples.append({
            "id": f"gold_{i+1:05d}",
            "test_index": item.get("test_index", ""),
            "dialogue": item["dialogue"],
            "reference_english_summary": item.get("summary", ""),
            "reference_chinese_summary": item.get("summary_zh", ""),
        })

    return examples


test_data = load_examples_from_gold_set(GOLD_SET_PATH, n=50)

print(f"Loaded {len(test_data)} examples.")
print("First example:")
print(test_data[0])
# Out:
# Loaded 50 examples.
# First example:
# {'id': 'gold_00001', 'test_index': 23, 'dialogue': "Anne: You were right, he was lying to me :/\nIrene: Oh no, what happened?\nJane: who? that Mark guy?\nAnne: yeah, he told me he's 30, today I saw his passport - he's 40\nIrene: You sure it's so important?\nAnne: he lied to me Irene", 'reference_english_summary': 'Mark lied to Anne about his age. Mark is 40.', 'reference_chinese_summary': '马克向安妮隐瞒了自己的年龄。他40岁了。'}

# %%
# Cell 10: Run the semantic-agent pipeline for the first example

result = run_three_agent_pipeline(test_data[4], verbose=True)
result
# Out:
# Loaded model: gemma3:27b
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Joyce",
#     "Michael",
#     "Edson"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Joyce",
#       "speech_act": "information",
#       "intended_meaning": "Joyce shares a link to a travel offer.",
#       "actor": null,
#       "action": "share",
#       "object": "link",
#       "recipient": "Michael, Edson",
#       "evidence": [
#         "Check this out!",
#         "<link>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Edson",
#       "speech_act": "commitment",
#       "intended_meaning": "Edson commits to booking a ticket based on the offer.",
#       "actor": "Edson",
#       "action": "book",
#       "object": "ticket",
#       "recipient": null,
#       "evidence": [
#         "No way! I'm booking my ticket now!!"
#       ]
#     }
#   ],
#   "final_outcome": "Edson decided to book a ticket after Joyce shared a cheap travel offer."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Joyce shares a travel offer link."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Edson commits to booking a ticket."
#     }
#   ],
#   "summary_zh": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"
# }
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"
# }
#
# === Final Chinese Summary ===
# 乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。
# ================================================================================
# {'id': 'gold_00005',
#  'test_index': 66,
#  'dialogue': "Joyce: Check this out!\r\nJoyce: <link>\r\nMichael: That's cheap!\r\nEdson: No way! I'm booking my ticket now!! ",
#  'reference_english_summary': 'Edson is booking his ticket now.',
#  'reference_chinese_summary': '埃德森正在订票。',
#  'agent1_model': 'gemma3:27b',
#  'agent2_model': 'gemma3:27b',
#  'agent1_semantic_representation': {'participants': ['Joyce',
#    'Michael',
#    'Edson'],
#   'semantic_grounding': [{'event_id': 1,
#     'speaker': 'Joyce',
#     'speech_act': 'information',
#     'intended_meaning': 'Joyce shares a link to a travel offer.',
#     'actor': None,
#     'action': 'share',
#     'object': 'link',
#     'recipient': 'Michael, Edson',
#     'evidence': ['Check this out!', '<link>']},
#    {'event_id': 2,
#     'speaker': 'Edson',
#     'speech_act': 'commitment',
#     'intended_meaning': 'Edson commits to booking a ticket based on the offer.',
#     'actor': 'Edson',
#     'action': 'book',
#     'object': 'ticket',
#     'recipient': None,
#     'evidence': ["No way! I'm booking my ticket now!!"]}],
#   'final_outcome': 'Edson decided to book a ticket after Joyce shared a cheap travel offer.'},
#  'agent1_semantic_representation_json': '{\n  "participants": [\n    "Joyce",\n    "Michael",\n    "Edson"\n  ],\n  "semantic_grounding": [\n    {\n      "event_id": 1,\n      "speaker": "Joyce",\n      "speech_act": "information",\n      "intended_meaning": "Joyce shares a link to a travel offer.",\n      "actor": null,\n      "action": "share",\n      "object": "link",\n      "recipient": "Michael, Edson",\n      "evidence": [\n        "Check this out!",\n        "<link>"\n      ]\n    },\n    {\n      "event_id": 2,\n      "speaker": "Edson",\n      "speech_act": "commitment",\n      "intended_meaning": "Edson commits to booking a ticket based on the offer.",\n      "actor": "Edson",\n      "action": "book",\n      "object": "ticket",\n      "recipient": null,\n      "evidence": [\n        "No way! I\'m booking my ticket now!!"\n      ]\n    }\n  ],\n  "final_outcome": "Edson decided to book a ticket after Joyce shared a cheap travel offer."\n}',
#  'agent2_summary_generation': {'selected_events': [{'event_id': 1,
#     'key_event': 'Joyce shares a travel offer link.'},
#    {'event_id': 2, 'key_event': 'Edson commits to booking a ticket.'}],
#   'summary_zh': '乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。'},
#  'agent2_summary_generation_json': '{\n  "selected_events": [\n    {\n      "event_id": 1,\n      "key_event": "Joyce shares a travel offer link."\n    },\n    {\n      "event_id": 2,\n      "key_event": "Edson commits to booking a ticket."\n    }\n  ],\n  "summary_zh": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"\n}',
#  'agent3_model': 'gemma3:27b',
#  'agent3_revision': {'needs_revision': False,
#   'issues_identified': [],
#   'events_dropped': [],
#   'revision_reason': '',
#   'summary_zh_final': '乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。'},
#  'agent3_revision_json': '{\n  "needs_revision": false,\n  "issues_identified": [],\n  "events_dropped": [],\n  "revision_reason": "",\n  "summary_zh_final": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"\n}',
#  'agent3_final_chinese_summary': '乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。',
#  'final_summary': '乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。',
#  'pipeline': 'semantic_agent',
#  'num_model_calls': 3}

# %%
# Cell 11: Print semantic-agent pipeline result clearly

def print_semantic_agent_result(result: Dict[str, Any]) -> None:
    print("=== Original Dialogue ===")
    print(result["dialogue"])
    print()

    print("=== Agent 1 Intermediate Output: Semantic Representation ===")
    print(result["agent1_semantic_representation_json"])
    print()

    print("=== Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===")
    print(result["agent2_summary_generation_json"])
    print()

    print("=== Agent 3 Output: Verification + Revision ===")
    print(result["agent3_revision_json"])
    print()

    print("=== Final Chinese Summary ===")
    print(result["final_summary"])
    print()

    print("=== Reference English Summary ===")
    print(result["reference_english_summary"])
    print()

    print("=== Reference Chinese Summary ===")
    print(result["reference_chinese_summary"])
    print()

    print("=== Metadata ===")
    print("Pipeline:", result["pipeline"])
    print("Agent 1 model:", result["agent1_model"])
    print("Agent 2 model:", result["agent2_model"])
    print("Agent 3 model:", result["agent3_model"])
    print("Model calls:", result["num_model_calls"])


print_semantic_agent_result(result)
# Out:
# === Original Dialogue ===
# Joyce: Check this out!
# Joyce: <link>
# Michael: That's cheap!
# Edson: No way! I'm booking my ticket now!!
#
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Joyce",
#     "Michael",
#     "Edson"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Joyce",
#       "speech_act": "information",
#       "intended_meaning": "Joyce shares a link to a travel offer.",
#       "actor": null,
#       "action": "share",
#       "object": "link",
#       "recipient": "Michael, Edson",
#       "evidence": [
#         "Check this out!",
#         "<link>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Edson",
#       "speech_act": "commitment",
#       "intended_meaning": "Edson commits to booking a ticket based on the offer.",
#       "actor": "Edson",
#       "action": "book",
#       "object": "ticket",
#       "recipient": null,
#       "evidence": [
#         "No way! I'm booking my ticket now!!"
#       ]
#     }
#   ],
#   "final_outcome": "Edson decided to book a ticket after Joyce shared a cheap travel offer."
# }
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Joyce shares a travel offer link."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Edson commits to booking a ticket."
#     }
#   ],
#   "summary_zh": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"
# }
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。"
# }
#
# === Final Chinese Summary ===
# 乔伊斯分享了旅行优惠链接，埃德森决定立即预订机票。
#
# === Reference English Summary ===
# Edson is booking his ticket now.
#
# === Reference Chinese Summary ===
# 埃德森正在订票。
#
# === Metadata ===
# Pipeline: semantic_agent
# Agent 1 model: gemma3:27b
# Agent 2 model: gemma3:27b
# Agent 3 model: gemma3:27b
# Model calls: 3

# %% [markdown]
# ## 4. Save Results
#
# This saves all intermediate outputs and the final output.

# %%
# Cell 12: Reset previous outputs before batch inference

INTERMEDIATE_OUTPUT_PATH.unlink(missing_ok=True)
FULL_OUTPUT_PATH.unlink(missing_ok=True)
FINAL_CSV_PATH.unlink(missing_ok=True)
ERROR_OUTPUT_PATH.unlink(missing_ok=True)

print("Previous output files reset.")
print("Intermediate output path:", INTERMEDIATE_OUTPUT_PATH)
print("Final JSONL output path:", FULL_OUTPUT_PATH)
print("CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Previous output files reset.
# Intermediate output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples_intermediate.jsonl
# Final JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.jsonl
# CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples_errors.jsonl

# %% [markdown]
# ## 5. Batch Inference with Checkpointing
#
# This cell processes examples one by one and appends each completed result to `results/agentic_outputs.jsonl`.
#
# If the notebook stops, already processed examples remain saved.

# %%
# Cell 13: Two-stage batch inference with semantic-agent pipeline
# Time stamp: 9m 9.6s

from datetime import datetime

MAX_EXAMPLES = 50
SLEEP_SECONDS = 0.2

processed_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed: {len(processed_ids)} examples")

subset = test_data[:MAX_EXAMPLES]

print("Batch inference started at:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Semantic-agent pipeline with all 27B agents")
print("Agent 1 model:", SEMANTIC_UNDERSTANDING_MODEL)
print("Agent 2 model:", SUMMARY_GENERATION_MODEL)
print("Agent 3 model:", REVISION_MODEL)

# Load the shared 27B model once
load_ollama_model(SEMANTIC_UNDERSTANDING_MODEL)

# -------------------------
# Stage 1: Agent 1 + Agent 2
# -------------------------

processed_intermediate_ids = load_processed_ids(INTERMEDIATE_OUTPUT_PATH)
print(f"Already processed by Agent 1/2: {len(processed_intermediate_ids)} examples")

for ex in tqdm(
    subset,
    desc=f"Stage 1: Agent 1/2 with {SEMANTIC_UNDERSTANDING_MODEL}",
):
    sample_id = str(ex.get("id", "unknown"))

    if sample_id in processed_intermediate_ids:
        print(f"Skipping Agent 1/2 already processed sample: {sample_id}")
        continue

    try:
        intermediate_record = run_agents_1_2(ex, verbose=True)

        append_jsonl(intermediate_record, INTERMEDIATE_OUTPUT_PATH)
        processed_intermediate_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "stage": "agent_1_2",
            "id": sample_id,
            "test_index": ex.get("test_index", ""),
            "error": repr(e),
            "dialogue": ex.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error in Agent 1/2 on {sample_id}: {repr(e)}")


# -------------------------
# Stage 2: Agent 3
# -------------------------

intermediate_records = load_jsonl(INTERMEDIATE_OUTPUT_PATH)

processed_final_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed by Agent 3: {len(processed_final_ids)} examples")

for intermediate_record in tqdm(
    intermediate_records,
    desc=f"Stage 2: Agent 3 with {REVISION_MODEL}",
):
    sample_id = str(intermediate_record.get("id", "unknown"))

    if sample_id in processed_final_ids:
        print(f"Skipping Agent 3 already processed sample: {sample_id}")
        continue

    try:
        final_record = run_agent_3_from_intermediate(
            intermediate_record,
            verbose=True,
        )

        append_jsonl(final_record, FULL_OUTPUT_PATH)
        processed_final_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "stage": "agent_3",
            "id": sample_id,
            "test_index": intermediate_record.get("test_index", ""),
            "error": repr(e),
            "dialogue": intermediate_record.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error in Agent 3 on {sample_id}: {repr(e)}")

print("Batch inference finished at:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print(f"Finished. Intermediate outputs saved to: {INTERMEDIATE_OUTPUT_PATH}")
print(f"Finished. Final outputs saved to: {FULL_OUTPUT_PATH}")
# Out:
# Already processed: 0 examples
# Batch inference started at: 2026-05-15 02:56:01
# Semantic-agent pipeline with all 27B agents
# Agent 1 model: gemma3:27b
# Agent 2 model: gemma3:27b
# Agent 3 model: gemma3:27b
# Loaded model: gemma3:27b
# Already processed by Agent 1/2: 0 examples
# Stage 1: Agent 1/2 with gemma3:27b:   0%|          | 0/50 [00:00<?, ?it/s]
# ================================================================================
# Sample ID: gold_00001
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Anne",
#     "Irene",
#     "Jane"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Anne",
#       "speech_act": "disclosure",
#       "intended_meaning": "Anne reveals Mark lied about his age.",
#       "actor": "Mark",
#       "action": "lied",
#       "object": "age",
#       "recipient": "Anne",
#       "evidence": [
#         "yeah, he told me he's 30, today I saw his passport - he's 40"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Anne",
#       "speech_act": "assertion",
#       "intended_meaning": "Anne emphasizes the significance of the lie.",
#       "actor": null,
#       "action": "lie",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "he lied to me Irene"
#       ]
#     }
#   ],
#   "final_outcome": "Anne discovered Mark lied about his age, which she considers a significant issue."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "安妮发现马克谎报年龄"
#     }
#   ],
#   "summary_zh": "安妮发现马克谎称自己三十岁，实际四十岁，她认为这是个严重的问题。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00002
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Mary",
#     "Carter"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Mary",
#       "speech_act": "request",
#       "intended_meaning": "Mary asks Carter for money.",
#       "actor": "Carter",
#       "action": "lend",
#       "object": "money",
#       "recipient": "Mary",
#       "evidence": [
#         "im kinda broke, lend me a few box"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Carter",
#       "speech_act": "promise",
#       "intended_meaning": "Carter agrees to lend Mary money within an hour.",
#       "actor": "Carter",
#       "action": "lend",
#       "object": "money",
#       "recipient": "Mary",
#       "evidence": [
#         "okay, give me an hour"
#       ]
#     }
#   ],
#   "final_outcome": "Carter promised to lend Mary money within an hour."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "玛丽向卡特请求借钱"
#     },
#     {
#       "event_id": 2,
#       "key_event": "卡特承诺在一小时内借钱给玛丽"
#     }
#   ],
#   "summary_zh": "玛丽向卡特借钱，卡特答应在一小时内借给她。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00003
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Tina",
#     "Ala"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Tina",
#       "speech_act": "report",
#       "intended_meaning": "Tina reports a delay with her flight.",
#       "actor": "airport staff",
#       "action": "delay",
#       "object": "Tina's flight",
#       "recipient": "Tina",
#       "evidence": [
#         "And I sucked at the airport, they've kept us one hour in the plane and finally I'll catch the evening flight back home"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Ala",
#       "speech_act": "commitment",
#       "intended_meaning": "Ala commits to updating Tina on her meeting.",
#       "actor": "Ala",
#       "action": "update",
#       "object": "meeting outcome",
#       "recipient": "Tina",
#       "evidence": [
#         "Sure, let me know how did it go",
#         "Ok darling, in touch"
#       ]
#     }
#   ],
#   "final_outcome": "Tina experienced a flight delay, and Ala promised to update Tina about her important meeting."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Tina's flight was delayed."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Ala committed to updating Tina on the meeting."
#     }
#   ],
#   "summary_zh": "蒂娜的航班延误。阿拉承诺向蒂娜汇报会议结果。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00004
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ana",
#     "Catherine"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Ana",
#       "speech_act": "proposal",
#       "intended_meaning": "Ana suggests visiting their grandmother tomorrow.",
#       "actor": "Ana and Catherine",
#       "action": "visit",
#       "object": "grandma",
#       "recipient": "grandma",
#       "evidence": [
#         "Wanna go visit grandma tomorrow? I miss her."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Catherine",
#       "speech_act": "agreement",
#       "intended_meaning": "Catherine agrees to the proposal.",
#       "actor": null,
#       "action": "agree",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "Yeah that would be nice :)"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Catherine",
#       "speech_act": "commitment",
#       "intended_meaning": "Catherine commits to contacting Ana tomorrow morning.",
#       "actor": "Catherine",
#       "action": "call",
#       "object": null,
#       "recipient": "Ana",
#       "evidence": [
#         "I'll call you when I wake up"
#       ]
#     }
#   ],
#   "final_outcome": "Ana and Catherine plan to visit their grandmother tomorrow, with Catherine promising to call Ana in the morning."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Ana proposes visiting grandma tomorrow"
#     },
#     {
#       "event_id": 3,
#       "key_event": "Catherine commits to calling Ana tomorrow morning"
#     }
#   ],
#   "summary_zh": "安娜和凯瑟琳计划明天拜访奶奶，凯瑟琳承诺明天早上给安娜打电话。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Semantic Representation ===
# {}
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {}
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00006
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Jane",
#     "Steven"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Jane",
#       "speech_act": "statement",
#       "intended_meaning": "Travel time is long according to maps.",
#       "actor": null,
#       "action": "estimate travel time",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "google maps says it is at least 3h"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Jane",
#       "speech_act": "proposal",
#       "intended_meaning": "Suggests changing the meeting time to 4:30 to avoid stress.",
#       "actor": "Jane",
#       "action": "change meeting time",
#       "object": null,
#       "recipient": "Steven",
#       "evidence": [
#         "I don't want to stress out , let's meet at 4:30 instead of 5, ok?"
#       ]
#     }
#   ],
#   "final_outcome": "Jane and Steven agreed to meet at 4:30 at the main entrance."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Jane proposed changing the meeting time to 4:30."
#     },
#     {
#       "event_id": 1,
#       "key_event": "Jane mentioned the long travel time."
#     }
#   ],
#   "summary_zh": "根据地图，旅程较长。简恩建议将会议时间改为下午四点半，并得到史蒂文的同意。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00007
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Fiona",
#     "Tina"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Fiona",
#       "speech_act": "request",
#       "intended_meaning": "Fiona asks Tina to help her make a tart.",
#       "actor": "Tina",
#       "action": "help",
#       "object": "tart",
#       "recipient": "Fiona",
#       "evidence": [
#         "Could help me do it?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Tina",
#       "speech_act": "agreement",
#       "intended_meaning": "Tina agrees to help Fiona make the tart.",
#       "actor": "Tina",
#       "action": "help",
#       "object": "tart",
#       "recipient": "Fiona",
#       "evidence": [
#         "Sure!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Fiona",
#       "speech_act": "disclosure",
#       "intended_meaning": "Fiona reveals she bought a pre-made crust.",
#       "actor": "Fiona",
#       "action": "buy",
#       "object": "crust",
#       "recipient": "Tina",
#       "evidence": [
#         "I bought the crust..."
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Tina",
#       "speech_act": "instruction",
#       "intended_meaning": "Tina explains a key step to avoid making scrambled eggs when making the tart.",
#       "actor": "Fiona",
#       "action": "mix",
#       "object": "eggs",
#       "recipient": "Fiona",
#       "evidence": [
#         "once you start adding eggs you can't stop mixing it, otherwise you'll end up with scrambled eggs."
#       ]
#     }
#   ],
#   "final_outcome": "Fiona and Tina will collaborate on making the tart, with Tina providing guidance on the egg mixture."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Tina agrees to help Fiona make a tart."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Tina instructs Fiona on how to properly mix the eggs for the tart."
#     }
#   ],
#   "summary_zh": "蒂娜同意帮助菲奥娜制作馅饼，并指导她混合鸡蛋的方法。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00008
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Olafur",
#     "Nathalie",
#     "Zoe"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Nathalie",
#       "speech_act": "proposal",
#       "intended_meaning": "Nathalie suggests attending the opera for New Year's Eve.",
#       "actor": null,
#       "action": "attend",
#       "object": "opera",
#       "recipient": null,
#       "evidence": [
#         "I was thinking about something classy, like opera or sth like that"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Olafur",
#       "speech_act": "rejection",
#       "intended_meaning": "Olafur expresses disinterest in the opera.",
#       "actor": null,
#       "action": "reject",
#       "object": "opera",
#       "recipient": null,
#       "evidence": [
#         "opera is not for me"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Olafur",
#       "speech_act": "alternative_proposal",
#       "intended_meaning": "Olafur suggests going to a party.",
#       "actor": null,
#       "action": "party",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I was thinking about partying somewhere"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Zoe",
#       "speech_act": "suggestion",
#       "intended_meaning": "Zoe suggests 'Breakfast at Tiffany's' party as a classy option.",
#       "actor": null,
#       "action": "suggest",
#       "object": "Breakfast at Tiffany's party",
#       "recipient": null,
#       "evidence": [
#         "Breakfast at Tiffany's party sounds classy"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Nathalie",
#       "speech_act": "agreement",
#       "intended_meaning": "Nathalie approves of the 'Breakfast at Tiffany's' party and decides to go to Soho.",
#       "actor": null,
#       "action": "decide",
#       "object": "go to Soho",
#       "recipient": null,
#       "evidence": [
#         "we'll going to Soho then"
#       ]
#     },
#     {
#       "event_id": 6,
#       "speaker": "Olafur",
#       "speech_act": "request",
#       "intended_meaning": "Olafur urges the group to buy tickets quickly.",
#       "actor": "they",
#       "action": "buy",
#       "object": "tickets",
#       "recipient": null,
#       "evidence": [
#         "we just need to hurry up and buy some tickets soon"
#       ]
#     }
#   ],
#   "final_outcome": "The group decided to go to the 'Breakfast at Tiffany's' party in Soho and plans to buy tickets soon."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 3,
#       "key_event": "奥拉夫提议去参加派对"
#     },
#     {
#       "event_id": 4,
#       "key_event": "佐伊建议去‘蒂凡尼早餐’派对"
#     },
#     {
#       "event_id": 5,
#       "key_event": "娜塔莉决定去索霍参加派对"
#     }
#   ],
#   "summary_zh": "奥拉夫和娜塔莉最初想看歌剧，后决定去索霍参加‘蒂凡尼早餐’派对，并计划尽快购票。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00009
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "John",
#     "Joan"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "John",
#       "speech_act": "proposal",
#       "intended_meaning": "John proposes seeing a movie on Wednesday.",
#       "actor": "John",
#       "action": "propose",
#       "object": "seeing \"A Star is Born\"",
#       "recipient": "Joan",
#       "evidence": [
#         "wanna go see \"A Star is Born\" on Wed?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Joan",
#       "speech_act": "refusal",
#       "intended_meaning": "Joan declines the Wednesday proposal due to being busy.",
#       "actor": "Joan",
#       "action": "decline",
#       "object": "movie on Wednesday",
#       "recipient": "John",
#       "evidence": [
#         "sorry can't",
#         "super busy",
#         "don't have time for anything :("
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Joan",
#       "speech_act": "alternative_proposal",
#       "intended_meaning": "Joan proposes Thursday as an alternative.",
#       "actor": "Joan",
#       "action": "propose",
#       "object": "Thursday",
#       "recipient": "John",
#       "evidence": [
#         "I'm free on Thursday"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "John",
#       "speech_act": "acceptance",
#       "intended_meaning": "John accepts the Thursday proposal.",
#       "actor": "John",
#       "action": "accept",
#       "object": "Thursday",
#       "recipient": "Joan",
#       "evidence": [
#         "I could do Thursday"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Joan",
#       "speech_act": "confirmation",
#       "intended_meaning": "Joan confirms a time of 8pm on Thursday.",
#       "actor": "Joan",
#       "action": "confirm",
#       "object": "8pm",
#       "recipient": "John",
#       "evidence": [
#         "ok! so around 8pm?"
#       ]
#     },
#     {
#       "event_id": 6,
#       "speaker": "John",
#       "speech_act": "commitment",
#       "intended_meaning": "John commits to finding movie details and sending them to Joan.",
#       "actor": "John",
#       "action": "send",
#       "object": "movie details",
#       "recipient": "Joan",
#       "evidence": [
#         "I'll see where it's palying and send you the details"
#       ]
#     }
#   ],
#   "final_outcome": "John and Joan agreed to see \"A Star is Born\" on Thursday around 8pm, and John will send Joan the movie details."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Joan refused Wednesday's movie plan."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Joan proposed Thursday instead."
#     },
#     {
#       "event_id": 6,
#       "key_event": "John committed to sending movie details."
#     }
#   ],
#   "summary_zh": "约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00010
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Peyton",
#     "Cameron"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Peyton",
#       "speech_act": "request",
#       "intended_meaning": "Peyton requests Cameron to bring a video game.",
#       "actor": "Cameron",
#       "action": "bring",
#       "object": "video game",
#       "recipient": "Peyton",
#       "evidence": [
#         "I have been asking you to bring that video game for me"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Cameron",
#       "speech_act": "refusal",
#       "intended_meaning": "Cameron refuses to come home immediately due to lack of time.",
#       "actor": "Cameron",
#       "action": "come home",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I am not having enough time to come home"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Cameron",
#       "speech_act": "commitment",
#       "intended_meaning": "Cameron commits to staying away for another week.",
#       "actor": "Cameron",
#       "action": "stay",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I will have to stay out of town for another week i guess"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Peyton",
#       "speech_act": "suggestion",
#       "intended_meaning": "Peyton suggests Cameron send the game via courier.",
#       "actor": "Cameron",
#       "action": "deliver",
#       "object": "game",
#       "recipient": null,
#       "evidence": [
#         "Cant you just deliver that game through the courier? :P"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Peyton",
#       "speech_act": "demand",
#       "intended_meaning": "Peyton demands Cameron finish work and return home quickly.",
#       "actor": "Cameron",
#       "action": "get job done and come home",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "Get the job done and come to home then. ASAP :P"
#       ]
#     }
#   ],
#   "final_outcome": "Peyton wants Cameron to bring or send a video game and return home quickly, while Cameron is delayed and will stay out of town for another week."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Cameron refuses to return home immediately."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Cameron commits to staying away for another week."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Peyton suggests Cameron send the game via courier."
#     }
#   ],
#   "summary_zh": "卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00011
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Paul",
#     "Emma"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Paul",
#       "speech_act": "report",
#       "intended_meaning": "Paul informs Emma he forgot his physiotherapy appointment.",
#       "actor": "Paul",
#       "action": "forget",
#       "object": "physiotherapy appointment",
#       "recipient": null,
#       "evidence": [
#         "I forgot about my physiotherapy"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Paul",
#       "speech_act": "offer",
#       "intended_meaning": "Paul offers to prepare food for Emma.",
#       "actor": "Paul",
#       "action": "prepare food",
#       "object": "food",
#       "recipient": "Emma",
#       "evidence": [
#         "Do you want me to prepare some food for you?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Emma",
#       "speech_act": "acceptance",
#       "intended_meaning": "Emma accepts Paul's offer.",
#       "actor": "Emma",
#       "action": "accept offer",
#       "object": null,
#       "recipient": "Paul",
#       "evidence": [
#         "That would be lovely"
#       ]
#     }
#   ],
#   "final_outcome": "Paul will prepare food for Emma when she returns home after midnight."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "保罗忘记了理疗预约"
#     },
#     {
#       "event_id": 3,
#       "key_event": "艾玛接受了保罗准备食物的提议"
#     }
#   ],
#   "summary_zh": "保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00012
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Harris",
#     "Lena"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Harris",
#       "speech_act": "report",
#       "intended_meaning": "Harris informs Lena about Aoki's death.",
#       "actor": null,
#       "action": "die",
#       "object": "Aoki",
#       "recipient": null,
#       "evidence": [
#         "My friend Aoki died yesterday."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Lena",
#       "speech_act": "question",
#       "intended_meaning": "Lena asks for details about the cause of death.",
#       "actor": null,
#       "action": "ask",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "What happened?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Harris",
#       "speech_act": "report",
#       "intended_meaning": "Harris states he doesn't know the cause of death and fears the worst.",
#       "actor": null,
#       "action": "speculate",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "Not sure yet. Thinking the worst..."
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Harris",
#       "speech_act": "exit",
#       "intended_meaning": "Harris announces he must end the conversation due to his mother calling.",
#       "actor": "Harris",
#       "action": "leave",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "Got to go, mom's calling."
#       ]
#     }
#   ],
#   "final_outcome": "Harris informed Lena about the death of his friend Aoki and then ended the conversation because his mother called."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "哈里斯告知莱娜，青木去世。"
#     },
#     {
#       "event_id": 4,
#       "key_event": "哈里斯因母亲来电而结束对话。"
#     }
#   ],
#   "summary_zh": "哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00013
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Yaz",
#     "Mary"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Mary",
#       "speech_act": "acknowledgment",
#       "intended_meaning": "Mary acknowledges she should attend slimming club despite reluctance.",
#       "actor": "Mary",
#       "action": "attend",
#       "object": "slimming club",
#       "recipient": null,
#       "evidence": [
#         "Well, I don't want to, but I really should."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Yaz",
#       "speech_act": "suggestion",
#       "intended_meaning": "Yaz suggests they both attend and offers a ride.",
#       "actor": "Yaz",
#       "action": "pick up",
#       "object": "Mary",
#       "recipient": "Mary",
#       "evidence": [
#         "See you at 6ish, pick you up!?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Mary",
#       "speech_act": "agreement",
#       "intended_meaning": "Mary accepts Yaz's offer and confirms attendance.",
#       "actor": "Mary",
#       "action": "accept",
#       "object": "ride",
#       "recipient": "Yaz",
#       "evidence": [
#         "Yep! See you then!"
#       ]
#     }
#   ],
#   "final_outcome": "Mary and Yaz will both attend slimming club, with Yaz giving Mary a ride."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "邀约接送"
#     },
#     {
#       "event_id": 3,
#       "key_event": "玛丽接受邀约"
#     }
#   ],
#   "summary_zh": "玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00014
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ellie",
#     "Aaliyah",
#     "Camille"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Camille",
#       "speech_act": "report",
#       "intended_meaning": "Camille informs the group she is ill.",
#       "actor": "Camille",
#       "action": "be sick",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I'm sick :/"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Ellie",
#       "speech_act": "request_info",
#       "intended_meaning": "Ellie asks for the new class location.",
#       "actor": "Ellie",
#       "action": "ask",
#       "object": "class location",
#       "recipient": "Aaliyah",
#       "evidence": [
#         "Aali, where are we having our classes now?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Aaliyah",
#       "speech_act": "provide_info",
#       "intended_meaning": "Aaliyah states the new class location.",
#       "actor": null,
#       "action": "be located",
#       "object": "classes",
#       "recipient": "Ellie",
#       "evidence": [
#         "342 on the second floor"
#       ]
#     }
#   ],
#   "final_outcome": "The group knows their class has been moved to room 342 on the second floor, but Camille will not be attending due to illness."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "卡米尔报告自己生病了"
#     },
#     {
#       "event_id": 3,
#       "key_event": "阿莉亚告知新教室位置"
#     }
#   ],
#   "summary_zh": "卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00015
# === Agent 1 Intermediate Output: Semantic Representation ===
# {}
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {}
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00016
# === Agent 1 Intermediate Output: Semantic Representation ===
# {}
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {}
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00017
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Jones",
#     "Angelina"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Jones",
#       "speech_act": "request",
#       "intended_meaning": "Jones asks Angelina if they can meet later that day.",
#       "actor": "Jones",
#       "action": "request meeting",
#       "object": null,
#       "recipient": "Angelina",
#       "evidence": [
#         "You think we can meet today later in the afternoon in town?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Angelina",
#       "speech_act": "agreement",
#       "intended_meaning": "Angelina agrees to meet with Jones.",
#       "actor": null,
#       "action": "agree",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "Definitely."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Jones",
#       "speech_act": "commitment",
#       "intended_meaning": "Jones commits to contacting Angelina to finalize meeting details.",
#       "actor": "Jones",
#       "action": "call",
#       "object": null,
#       "recipient": "Angelina",
#       "evidence": [
#         "I will call you to confirm where we will meet."
#       ]
#     }
#   ],
#   "final_outcome": "Jones and Angelina agreed to meet later that day, and Jones will call to confirm the location."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Angelina agreed to meet with Jones."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Jones committed to calling Angelina to confirm the meeting location."
#     }
#   ],
#   "summary_zh": "琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00018
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Casey",
#     "Amelia",
#     "Kristen"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Amelia",
#       "speech_act": "request",
#       "intended_meaning": "Amelia asks Casey to replicate the nail design for her.",
#       "actor": "Casey",
#       "action": "do nails",
#       "object": "nails",
#       "recipient": "Amelia",
#       "evidence": [
#         "can you do it for us too?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Kristen",
#       "speech_act": "request",
#       "intended_meaning": "Kristen seconds Amelia's request for Casey to do their nails.",
#       "actor": "Casey",
#       "action": "do nails",
#       "object": "nails",
#       "recipient": "Kristen",
#       "evidence": [
#         "pretty please!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Casey",
#       "speech_act": "refusal",
#       "intended_meaning": "Casey declines to do nails for Amelia and Kristen due to the time commitment.",
#       "actor": "Casey",
#       "action": "refuse request",
#       "object": null,
#       "recipient": "Amelia & Kristen",
#       "evidence": [
#         "sorry you guys... it was a nightmare :( seriously 4 hours for nails is too much"
#       ]
#     }
#   ],
#   "final_outcome": "Casey refused to do Amelia and Kristen's nails because it took too long to do her own."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Amelia and Kristen requested Casey to do their nails."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Casey refused to do nails for Amelia and Kristen due to the time commitment."
#     }
#   ],
#   "summary_zh": "劳拉和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00019
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Sue",
#     "Steve"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Sue",
#       "speech_act": "request",
#       "intended_meaning": "Sue wants Steve to call her upon receiving the message.",
#       "actor": "Steve",
#       "action": "call",
#       "object": "null",
#       "recipient": "Sue",
#       "evidence": [
#         "Call me when you get this.",
#         "it's important"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Steve",
#       "speech_act": "agreement",
#       "intended_meaning": "Steve acknowledges and agrees to Sue's request.",
#       "actor": "Steve",
#       "action": "call",
#       "object": "null",
#       "recipient": "Sue",
#       "evidence": [
#         "OK, I'm calling"
#       ]
#     }
#   ],
#   "final_outcome": "Steve agreed to call Sue immediately."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Sue requested Steve to call her upon receiving the message."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Steve agreed to call Sue immediately."
#     }
#   ],
#   "summary_zh": "苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00020
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Timmy",
#     "Gemma"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Gemma",
#       "speech_act": "suggestion",
#       "intended_meaning": "Gemma suggests inviting Timmy and his date.",
#       "actor": "Gemma",
#       "action": "suggest",
#       "object": "invitation",
#       "recipient": "Timmy",
#       "evidence": [
#         "Well, there's u and ur date :)"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Gemma",
#       "speech_act": "suggestion",
#       "intended_meaning": "Gemma suggests inviting Lona and Michelle.",
#       "actor": "Gemma",
#       "action": "suggest",
#       "object": "invitation",
#       "recipient": "Timmy",
#       "evidence": [
#         "I was thinking about Lona and Michelle."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Gemma",
#       "speech_act": "admission",
#       "intended_meaning": "Gemma admits she wants to attend Lona and Michelle's wedding receptions.",
#       "actor": "Gemma",
#       "action": "want",
#       "object": "attendance",
#       "recipient": null,
#       "evidence": [
#         "Fine! I want to come to their wedding receptions!"
#       ]
#     }
#   ],
#   "final_outcome": "Gemma admitted she wants to attend Lona and Michelle's wedding receptions, and Timmy acknowledged her admission."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 3,
#       "key_event": "Gemma wants to attend Lona and Michelle's wedding receptions."
#     }
#   ],
#   "summary_zh": "格玛承认她想参加洛娜和米歇尔的婚礼招待会。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00021
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ann",
#     "Sue",
#     "Julie"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Ann",
#       "speech_act": "Proposal",
#       "intended_meaning": "Ann suggests a celebration.",
#       "actor": "Ann",
#       "action": "propose",
#       "object": "celebration",
#       "recipient": "Sue & Julie",
#       "evidence": [
#         "Let's have a little celebration tonight!"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Sue",
#       "speech_act": "Acceptance",
#       "intended_meaning": "Sue agrees to the celebration.",
#       "actor": "Sue",
#       "action": "accept",
#       "object": "celebration",
#       "recipient": "Ann & Julie",
#       "evidence": [
#         "I'm in"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Julie",
#       "speech_act": "Acceptance",
#       "intended_meaning": "Julie also agrees to the celebration.",
#       "actor": "Julie",
#       "action": "accept",
#       "object": "celebration",
#       "recipient": "Ann & Sue",
#       "evidence": [
#         "me too!!!"
#       ]
#     }
#   ],
#   "final_outcome": "Ann, Sue, and Julie will have a celebration tonight."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Ann proposes a celebration"
#     },
#     {
#       "event_id": 3,
#       "key_event": "Sue and Julie accept the proposal"
#     }
#   ],
#   "summary_zh": "安娜、苏和朱莉今晚将举行庆祝活动。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00022
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Steve",
#     "Mum"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Steve",
#       "speech_act": "report",
#       "intended_meaning": "Steve informs Mum the dishwasher has arrived and was installed.",
#       "actor": "installers",
#       "action": "install",
#       "object": "dishwasher",
#       "recipient": "Steve",
#       "evidence": [
#         "hiya the dishwasher has turned up",
#         "yes they did a good job"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Mum",
#       "speech_act": "question",
#       "intended_meaning": "Mum asks if the installers did the installation.",
#       "actor": "installers",
#       "action": "install",
#       "object": "dishwasher",
#       "recipient": "Steve",
#       "evidence": [
#         "good did they install it for you"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Steve",
#       "speech_act": "affirmation",
#       "intended_meaning": "Steve confirms the dishwasher is a 12 place setting.",
#       "actor": null,
#       "action": "be",
#       "object": "12 place setting dishwasher",
#       "recipient": null,
#       "evidence": [
#         "I think so"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Steve",
#       "speech_act": "statement",
#       "intended_meaning": "Steve states he is pleased with the dishwasher.",
#       "actor": "Steve",
#       "action": "be pleased",
#       "object": "dishwasher",
#       "recipient": null,
#       "evidence": [
#         "I am thanks mum"
#       ]
#     }
#   ],
#   "final_outcome": "Steve received and is pleased with the new dishwasher installation."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Dishwasher installed successfully"
#     },
#     {
#       "event_id": 4,
#       "key_event": "Steve is pleased with the dishwasher"
#     }
#   ],
#   "summary_zh": "史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00023
# === Agent 1 Intermediate Output: Semantic Representation ===
# {}
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {}
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00024
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Miranda",
#     "Stephanie"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Miranda",
#       "speech_act": "request",
#       "intended_meaning": "Miranda requests to cancel the meeting.",
#       "actor": "Miranda",
#       "action": "cancel",
#       "object": "meeting",
#       "recipient": "Stephanie",
#       "evidence": [
#         "Hi S, could we cancel tomorrow's meeting?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Miranda",
#       "speech_act": "explanation",
#       "intended_meaning": "Miranda explains she has to work.",
#       "actor": "Miranda",
#       "action": "work",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I have to work :("
#       ]
#     }
#   ],
#   "final_outcome": "Miranda requested to cancel the meeting due to work commitments, and Stephanie acknowledged the request after some playful banter."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Miranda requests to cancel the meeting"
#     },
#     {
#       "event_id": 2,
#       "key_event": "Miranda explains she has to work"
#     }
#   ],
#   "summary_zh": "米兰达因工作原因向斯蒂芬妮请求取消会议，斯蒂芬妮同意了。 "
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00025
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Javier",
#     "Judie"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Javier",
#       "speech_act": "request",
#       "intended_meaning": "Javier asks for tattoo parlor recommendations with English speakers.",
#       "actor": null,
#       "action": "seek information",
#       "object": null,
#       "recipient": "Judie",
#       "evidence": [
#         "Hey do you know any tattoo parlors over here with English speaking employees?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Judie",
#       "speech_act": "recommendation",
#       "intended_meaning": "Judie recommends Warsaw Ink.",
#       "actor": null,
#       "action": "recommend",
#       "object": "Warsaw Ink",
#       "recipient": "Javier",
#       "evidence": [
#         "Oh there's Warsaw ink"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Javier",
#       "speech_act": "information_request",
#       "intended_meaning": "Javier asks if Judie has experience with Warsaw Ink.",
#       "actor": null,
#       "action": "ask about experience",
#       "object": "Warsaw Ink",
#       "recipient": "Judie",
#       "evidence": [
#         "have you had a tattoo done there?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Javier",
#       "speech_act": "decision",
#       "intended_meaning": "Javier decides to get a tattoo in Colombia instead due to the price.",
#       "actor": "Javier",
#       "action": "decide",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "let me just get a tatttoo back in colombia then, thx"
#       ]
#     }
#   ],
#   "final_outcome": "Javier decided to get a tattoo in Colombia instead of at Warsaw Ink due to the cost."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Judie recommends Warsaw Ink."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Javier decides to get a tattoo in Colombia due to price."
#     }
#   ],
#   "summary_zh": "哈维尔询问纹身店推荐，劳拉推荐华沙墨水。但哈维尔最终决定在哥伦比亚纹身，因为价格更优惠。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00026
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Sam",
#     "Jessica",
#     "Michael"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Sam",
#       "speech_act": "request",
#       "intended_meaning": "Sam asks about the hotel room reservation.",
#       "actor": "manager",
#       "action": "arrange",
#       "object": "hotel room",
#       "recipient": "Sam",
#       "evidence": [
#         "How is our hotel room set for next month?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Michael",
#       "speech_act": "confirmation",
#       "intended_meaning": "Michael confirms the reservation will be good.",
#       "actor": null,
#       "action": "confirm",
#       "object": null,
#       "recipient": "Sam",
#       "evidence": [
#         "you’re damn right, Sam"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Michael",
#       "speech_act": "question",
#       "intended_meaning": "Michael confirms Sam's arrival date.",
#       "actor": null,
#       "action": "ask",
#       "object": null,
#       "recipient": "Sam",
#       "evidence": [
#         "are you coming on the 15th of August?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Sam",
#       "speech_act": "affirmation",
#       "intended_meaning": "Sam confirms arrival date and time.",
#       "actor": "Sam",
#       "action": "arrive",
#       "object": null,
#       "recipient": "hotel",
#       "evidence": [
#         "Yep! We’ll be at the hotel around 2 p.m."
#       ]
#     }
#   ],
#   "final_outcome": "Sam and their companions will arrive at Michael and Jessica's hotel on August 15th around 2 p.m."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 3,
#       "key_event": "Michael confirms Sam's arrival date."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Sam confirms arrival time at 2 p.m."
#     }
#   ],
#   "summary_zh": "萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00027
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Terence",
#     "Daniel"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Terence",
#       "speech_act": "accusation",
#       "intended_meaning": "Terence accuses Daniel of stealing his money.",
#       "actor": "Daniel",
#       "action": "take",
#       "object": "money",
#       "recipient": "Terence",
#       "evidence": [
#         "What the hell, Danny. You took my money, didn't you? :/"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Terence",
#       "speech_act": "demand_clarification",
#       "intended_meaning": "Terence insists Daniel is not being truthful.",
#       "actor": "Daniel",
#       "action": "pretend to be unaware",
#       "object": null,
#       "recipient": "Terence",
#       "evidence": [
#         "Don't play dumb"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Terence",
#       "speech_act": "apology",
#       "intended_meaning": "Terence realizes he was wrong and apologizes for accusing Daniel.",
#       "actor": "Terence",
# ...
# }
#
# === Final Chinese Summary ===
# 约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。"
# }
#
# === Final Chinese Summary ===
# 卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。"
# }
#
# === Final Chinese Summary ===
# 保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。"
# }
#
# === Final Chinese Summary ===
# 哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。"
# }
#
# === Final Chinese Summary ===
# 玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。"
# }
#
# === Final Chinese Summary ===
# 卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精神时刻。"
# }
#
# === Final Chinese Summary ===
# 亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精神时刻。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。"
# }
#
# === Final Chinese Summary ===
# 大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。"
# }
#
# === Final Chinese Summary ===
# 琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "wrong_actor"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Amelia and Kristen, not Laura and Kristen.",
#   "summary_zh_final": "阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。"
# }
#
# === Final Chinese Summary ===
# 阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。"
# }
#
# === Final Chinese Summary ===
# 苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "格玛承认她想参加洛娜和米歇尔的婚礼招待会。"
# }
#
# === Final Chinese Summary ===
# 格玛承认她想参加洛娜和米歇尔的婚礼招待会。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "安娜、苏和朱莉今晚将举行庆祝活动。"
# }
#
# === Final Chinese Summary ===
# 安娜、苏和朱莉今晚将举行庆祝活动。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。"
# }
#
# === Final Chinese Summary ===
# 史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "玛丽卡问拉拉今天是否来，拉拉回答肯定。"
# }
#
# === Final Chinese Summary ===
# 玛丽卡问拉拉今天是否来，拉拉回答肯定。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "missing_final_outcome"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Missing Stephanie's reaction and the humorous exchange.",
#   "summary_zh_final": "米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。"
# }
#
# === Final Chinese Summary ===
# 米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "wrong_actor",
#     "untranslated_names"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Judie, not Laura, recommended the tattoo parlor.",
#   "summary_zh_final": "哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。"
# }
#
# === Final Chinese Summary ===
# 哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。"
# }
#
# === Final Chinese Summary ===
# 萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "wrong_actor"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Terence and Daniel, not Paul. Correct actor names.",
#   "summary_zh_final": "特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。"
# }
#
# === Final Chinese Summary ===
# 特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。"
# }
#
# === Final Chinese Summary ===
# 娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "wrong_action"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Meg asks to meet Ann, not the other way around.",
#   "summary_zh_final": "梅格问安娜几点可以见面，安娜说晚上七点到家。"
# }
#
# === Final Chinese Summary ===
# 梅格问安娜几点可以见面，安娜说晚上七点到家。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。"
# }
#
# === Final Chinese Summary ===
# 珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "克里斯蒂和凯蒂都觉得派对很棒，但都很累。"
# }
#
# === Final Chinese Summary ===
# 克里斯蒂和凯蒂都觉得派对很棒，但都很累。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。"
# }
#
# === Final Chinese Summary ===
# 萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔安娜将把游戏带到桑迪那里一起玩。"
# }
#
# === Final Chinese Summary ===
# 乔安娜将把游戏带到桑迪那里一起玩。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。"
# }
#
# === Final Chinese Summary ===
# 史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔伊向彼得分享了她的美容店链接，彼得将查看该链接。"
# }
#
# === Final Chinese Summary ===
# 乔伊向彼得分享了她的美容店链接，彼得将查看该链接。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告知是否参加。"
# }
#
# === Final Chinese Summary ===
# 伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告知是否参加。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "missing_key_event"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Missing cat invading pitch and fan reaction.",
#   "summary_zh_final": "布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。"
# }
#
# === Final Chinese Summary ===
# 布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "wrong_actor"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Names are wrong; Sean, not Paul. Missing Zac's arrival.",
#   "summary_zh_final": "肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。"
# }
#
# === Final Chinese Summary ===
# 肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。"
# }
#
# === Final Chinese Summary ===
# 杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。"
# }
#
# === Final Chinese Summary ===
# 德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。"
# }
#
# === Final Chinese Summary ===
# 梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "wrong_actor"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Callan, not Paul, has the phone issue.",
#   "summary_zh_final": "卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。"
# }
#
# === Final Chinese Summary ===
# 卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔安娜泡茶。"
# }
#
# === Final Chinese Summary ===
# 安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔安娜泡茶。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。"
# }
#
# === Final Chinese Summary ===
# 凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。"
# }
#
# === Final Chinese Summary ===
# 卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。"
# }
#
# === Final Chinese Summary ===
# 亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。"
# }
#
# === Final Chinese Summary ===
# 达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "wrong_actor"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Barry proposed the strike, not Paul. Names untranslated.",
#   "summary_zh_final": "巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。"
# }
#
# === Final Chinese Summary ===
# 巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。"
# }
#
# === Final Chinese Summary ===
# 玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。"
# }
#
# === Final Chinese Summary ===
# 迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。
# ================================================================================
#
# Batch inference finished at: 2026-05-15 04:43:06
# Finished. Intermediate outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples_intermediate.jsonl
# Finished. Final outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.jsonl

# %% [markdown]
# ## 6. Export Final Summaries to CSV
#
# This file can be used for ROUGE, BERTScore, OmniScore, or manual analysis.

# %%
# Cell 14: Export semantic-agent summaries to CSV

records = load_jsonl(FULL_OUTPUT_PATH)

rows = []

for record in records:
    if "final_summary" not in record:
        continue

    rows.append({
        "id": record.get("id", ""),
        "test_index": record.get("test_index", ""),
        "dialogue": record.get("dialogue", ""),

        # Final output
        "final_summary": record.get("final_summary", ""),

        # References
        "reference_english_summary": record.get("reference_english_summary", ""),
        "reference_chinese_summary": record.get("reference_chinese_summary", ""),

        # Intermediate outputs
        "agent1_semantic_representation_json": record.get(
            "agent1_semantic_representation_json", ""
        ),
        "agent2_summary_generation_json": record.get(
            "agent2_summary_generation_json", ""
        ),
        "agent3_revision_json": record.get(
            "agent3_revision_json", ""
        ),

        # Agent 3 final
        "agent3_final_chinese_summary": record.get(
            "agent3_final_chinese_summary", ""
        ),

        # Metadata
        "pipeline": record.get("pipeline", "semantic_agent"),
        "agent1_model": record.get("agent1_model", ""),
        "agent2_model": record.get("agent2_model", ""),
        "agent3_model": record.get("agent3_model", ""),
        "num_model_calls": record.get("num_model_calls", 3),
    })

df = pd.DataFrame(rows)

if not df.empty:
    df = df.drop_duplicates(subset=["id"], keep="last")

df.to_csv(FINAL_CSV_PATH, index=False, encoding="utf-8-sig")

print(f"Saved final summaries to: {FINAL_CSV_PATH}")
df
# Out:
# Saved final summaries to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_gemma27b_50samples.csv
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                                         final_summary  \
# 0                    安妮发现马克谎称自己三十岁，实际四十岁，她认为这是个严重的问题。
# 1                               玛丽向卡特借钱，卡特答应在一小时内借给她。
# 2                              蒂娜的航班延误。阿拉承诺向蒂娜汇报会议结果。
# 3                     安娜和凯瑟琳计划明天拜访奶奶，凯瑟琳承诺明天早上给安娜打电话。
# 4                          乔伊斯分享链接，迈克尔觉得便宜，埃德森立即预订机票。
# 5               根据地图，旅程较长。简恩建议将会议时间改为下午四点半，并得到史蒂文的同意。
# 6                          蒂娜同意帮助菲奥娜制作馅饼，并指导她混合鸡蛋的方法。
# 7            奥拉夫和娜塔莉最初想看歌剧，后决定去索霍参加‘蒂凡尼早餐’派对，并计划尽快购票。
# 8                 约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。
# 9              卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。
# 10          保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。
# 11                      哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。
# 12                          玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。
# 13                  卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。
# 14  亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精...
# 15      大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。
# 16                         琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。
# 17                  阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。
# 18                        苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。
# 19                              格玛承认她想参加洛娜和米歇尔的婚礼招待会。
# 20                                  安娜、苏和朱莉今晚将举行庆祝活动。
# 21                       史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。
# 22                                玛丽卡问拉拉今天是否来，拉拉回答肯定。
# 23           米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。
# 24                哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。
# 25                      萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。
# 26              特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。
# 27                    娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。
# 28                             梅格问安娜几点可以见面，安娜说晚上七点到家。
# 29                 珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。
# 30                               克里斯蒂和凯蒂都觉得派对很棒，但都很累。
# 31                            萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。
# 32                                  乔安娜将把游戏带到桑迪那里一起玩。
# 33                     史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。
# 34                          乔伊向彼得分享了她的美容店链接，彼得将查看该链接。
# 35  伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告...
# 36     布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。
# 37                             肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。
# 38           杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。
# 39                         德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。
# 40          梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。
# 41                      卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。
# 42  安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔...
# 43        凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。
# 44                卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。
# 45           亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。
# 46       达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。
# 47                 巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。
# 48            玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。
# 49                     迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary  \
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
#
#                   agent1_semantic_representation_json  \
# 0   {\n  "participants": [\n    "Anne",\n    "Iren...
# 1   {\n  "participants": [\n    "Mary",\n    "Cart...
# 2   {\n  "participants": [\n    "Tina",\n    "Ala"...
# 3   {\n  "participants": [\n    "Ana",\n    "Cathe...
# 4                                                  {}
# 5   {\n  "participants": [\n    "Jane",\n    "Stev...
# 6   {\n  "participants": [\n    "Fiona",\n    "Tin...
# 7   {\n  "participants": [\n    "Olafur",\n    "Na...
# 8   {\n  "participants": [\n    "John",\n    "Joan...
# 9   {\n  "participants": [\n    "Peyton",\n    "Ca...
# 10  {\n  "participants": [\n    "Paul",\n    "Emma...
# 11  {\n  "participants": [\n    "Harris",\n    "Le...
# 12  {\n  "participants": [\n    "Yaz",\n    "Mary"...
# 13  {\n  "participants": [\n    "Ellie",\n    "Aal...
# 14                                                 {}
# 15                                                 {}
# 16  {\n  "participants": [\n    "Jones",\n    "Ang...
# 17  {\n  "participants": [\n    "Casey",\n    "Ame...
# 18  {\n  "participants": [\n    "Sue",\n    "Steve...
# 19  {\n  "participants": [\n    "Timmy",\n    "Gem...
# 20  {\n  "participants": [\n    "Ann",\n    "Sue",...
# 21  {\n  "participants": [\n    "Steve",\n    "Mum...
# 22                                                 {}
# 23  {\n  "participants": [\n    "Miranda",\n    "S...
# 24  {\n  "participants": [\n    "Javier",\n    "Ju...
# 25  {\n  "participants": [\n    "Sam",\n    "Jessi...
# 26  {\n  "participants": [\n    "Terence",\n    "D...
# 27  {\n  "participants": [\n    "Natacha",\n    "C...
# 28  {\n  "participants": [\n    "Meg",\n    "Ann"\...
# 29  {\n  "participants": [\n    "Pete",\n    "Jen"...
# 30                                                 {}
# 31  {\n  "participants": [\n    "Sam",\n    "Carla...
# 32  {\n  "participants": [\n    "Joana",\n    "San...
# 33  {\n  "participants": [\n    "Steve",\n    "Rob...
# 34  {\n  "participants": [\n    "Peter",\n    "Joy...
# 35  {\n  "participants": [\n    "Ethan",\n    "Noa...
# 36                                                 {}
# 37  {\n  "participants": [\n    "Barbara",\n    "S...
# 38  {\n  "participants": [\n    "Jake",\n    "Tom"...
# 39  {\n  "participants": [\n    "Phil",\n    "Dean...
# 40  {\n  "participants": [\n    "Mell",\n    "Glor...
# 41  {\n  "participants": [\n    "Callan",\n    "Wa...
# 42  {\n  "participants": [\n    "Anna",\n    "Joan...
# 43  {\n  "participants": [\n    "Sam",\n    "Kate"...
# 44  {\n  "participants": [\n    "Mia",\n    "Jenni...
# 45  {\n  "participants": [\n    "Pedro",\n    "Ale...
# 46  {\n  "participants": [\n    "Damian",\n    "Et...
# 47  {\n  "participants": [\n    "Barry",\n    "Jak...
# 48  {\n  "participants": [\n    "Martha",\n    "Op...
# 49  {\n  "participants": [\n    "Linda",\n    "Mic...
#
#                        agent2_summary_generation_json  \
# 0   {\n  "selected_events": [\n    {\n      "event...
# 1   {\n  "selected_events": [\n    {\n      "event...
# 2   {\n  "selected_events": [\n    {\n      "event...
# 3   {\n  "selected_events": [\n    {\n      "event...
# 4                                                  {}
# 5   {\n  "selected_events": [\n    {\n      "event...
# 6   {\n  "selected_events": [\n    {\n      "event...
# 7   {\n  "selected_events": [\n    {\n      "event...
# 8   {\n  "selected_events": [\n    {\n      "event...
# 9   {\n  "selected_events": [\n    {\n      "event...
# 10  {\n  "selected_events": [\n    {\n      "event...
# 11  {\n  "selected_events": [\n    {\n      "event...
# 12  {\n  "selected_events": [\n    {\n      "event...
# 13  {\n  "selected_events": [\n    {\n      "event...
# 14                                                 {}
# 15                                                 {}
# 16  {\n  "selected_events": [\n    {\n      "event...
# 17  {\n  "selected_events": [\n    {\n      "event...
# 18  {\n  "selected_events": [\n    {\n      "event...
# 19  {\n  "selected_events": [\n    {\n      "event...
# 20  {\n  "selected_events": [\n    {\n      "event...
# 21  {\n  "selected_events": [\n    {\n      "event...
# 22                                                 {}
# 23  {\n  "selected_events": [\n    {\n      "event...
# 24  {\n  "selected_events": [\n    {\n      "event...
# 25  {\n  "selected_events": [\n    {\n      "event...
# 26  {\n  "selected_events": [\n    {\n      "event...
# 27  {\n  "selected_events": [\n    {\n      "event...
# 28  {\n  "selected_events": [\n    {\n      "event...
# 29  {\n  "selected_events": [\n    {\n      "event...
# 30                                                 {}
# 31  {\n  "selected_events": [\n    {\n      "event...
# 32  {\n  "selected_events": [\n    {\n      "event...
# 33  {\n  "selected_events": [\n    {\n      "event...
# 34  {\n  "selected_events": [\n    {\n      "event...
# 35  {\n  "selected_events": [\n    {\n      "event...
# 36                                                 {}
# 37  {\n  "selected_events": [\n    {\n      "event...
# 38  {\n  "selected_events": [\n    {\n      "event...
# 39  {\n  "selected_events": [\n    {\n      "event...
# 40  {\n  "selected_events": [\n    {\n      "event...
# 41  {\n  "selected_events": [\n    {\n      "event...
# 42  {\n  "selected_events": [\n    {\n      "event...
# 43  {\n  "selected_events": [\n    {\n      "event...
# 44  {\n  "selected_events": [\n    {\n      "event...
# 45  {\n  "selected_events": [\n    {\n      "event...
# 46  {\n  "selected_events": [\n    {\n      "event...
# 47  {\n  "selected_events": [\n    {\n      "event...
# 48  {\n  "selected_events": [\n    {\n      "event...
# 49  {\n  "selected_events": [\n    {\n      "event...
#
#                                  agent3_revision_json  \
# 0   {\n  "needs_revision": false,\n  "issues_ident...
# 1   {\n  "needs_revision": false,\n  "issues_ident...
# 2   {\n  "needs_revision": false,\n  "issues_ident...
# 3   {\n  "needs_revision": false,\n  "issues_ident...
# 4   {\n  "needs_revision": true,\n  "issues_identi...
# 5   {\n  "needs_revision": false,\n  "issues_ident...
# 6   {\n  "needs_revision": false,\n  "issues_ident...
# 7   {\n  "needs_revision": false,\n  "issues_ident...
# 8   {\n  "needs_revision": false,\n  "issues_ident...
# 9   {\n  "needs_revision": false,\n  "issues_ident...
# 10  {\n  "needs_revision": false,\n  "issues_ident...
# 11  {\n  "needs_revision": false,\n  "issues_ident...
# 12  {\n  "needs_revision": false,\n  "issues_ident...
# 13  {\n  "needs_revision": false,\n  "issues_ident...
# 14  {\n  "needs_revision": false,\n  "issues_ident...
# 15  {\n  "needs_revision": false,\n  "issues_ident...
# 16  {\n  "needs_revision": false,\n  "issues_ident...
# 17  {\n  "needs_revision": true,\n  "issues_identi...
# 18  {\n  "needs_revision": false,\n  "issues_ident...
# 19  {\n  "needs_revision": false,\n  "issues_ident...
# 20  {\n  "needs_revision": false,\n  "issues_ident...
# 21  {\n  "needs_revision": false,\n  "issues_ident...
# 22  {\n  "needs_revision": false,\n  "issues_ident...
# 23  {\n  "needs_revision": true,\n  "issues_identi...
# 24  {\n  "needs_revision": true,\n  "issues_identi...
# 25  {\n  "needs_revision": false,\n  "issues_ident...
# 26  {\n  "needs_revision": true,\n  "issues_identi...
# 27  {\n  "needs_revision": false,\n  "issues_ident...
# 28  {\n  "needs_revision": true,\n  "issues_identi...
# 29  {\n  "needs_revision": false,\n  "issues_ident...
# 30  {\n  "needs_revision": false,\n  "issues_ident...
# 31  {\n  "needs_revision": false,\n  "issues_ident...
# 32  {\n  "needs_revision": false,\n  "issues_ident...
# 33  {\n  "needs_revision": false,\n  "issues_ident...
# 34  {\n  "needs_revision": false,\n  "issues_ident...
# 35  {\n  "needs_revision": false,\n  "issues_ident...
# 36  {\n  "needs_revision": true,\n  "issues_identi...
# 37  {\n  "needs_revision": true,\n  "issues_identi...
# 38  {\n  "needs_revision": false,\n  "issues_ident...
# 39  {\n  "needs_revision": false,\n  "issues_ident...
# 40  {\n  "needs_revision": false,\n  "issues_ident...
# 41  {\n  "needs_revision": true,\n  "issues_identi...
# 42  {\n  "needs_revision": false,\n  "issues_ident...
# 43  {\n  "needs_revision": false,\n  "issues_ident...
# 44  {\n  "needs_revision": false,\n  "issues_ident...
# 45  {\n  "needs_revision": false,\n  "issues_ident...
# 46  {\n  "needs_revision": false,\n  "issues_ident...
# 47  {\n  "needs_revision": true,\n  "issues_identi...
# 48  {\n  "needs_revision": false,\n  "issues_ident...
# 49  {\n  "needs_revision": false,\n  "issues_ident...
#
#                          agent3_final_chinese_summary        pipeline  \
# 0                    安妮发现马克谎称自己三十岁，实际四十岁，她认为这是个严重的问题。  semantic_agent
# 1                               玛丽向卡特借钱，卡特答应在一小时内借给她。  semantic_agent
# 2                              蒂娜的航班延误。阿拉承诺向蒂娜汇报会议结果。  semantic_agent
# 3                     安娜和凯瑟琳计划明天拜访奶奶，凯瑟琳承诺明天早上给安娜打电话。  semantic_agent
# 4                          乔伊斯分享链接，迈克尔觉得便宜，埃德森立即预订机票。  semantic_agent
# 5               根据地图，旅程较长。简恩建议将会议时间改为下午四点半，并得到史蒂文的同意。  semantic_agent
# 6                          蒂娜同意帮助菲奥娜制作馅饼，并指导她混合鸡蛋的方法。  semantic_agent
# 7            奥拉夫和娜塔莉最初想看歌剧，后决定去索霍参加‘蒂凡尼早餐’派对，并计划尽快购票。  semantic_agent
# 8                 约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。  semantic_agent
# 9              卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。  semantic_agent
# 10          保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。  semantic_agent
# 11                      哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。  semantic_agent
# 12                          玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。  semantic_agent
# 13                  卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。  semantic_agent
# 14  亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精...  semantic_agent
# 15      大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。  semantic_agent
# 16                         琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。  semantic_agent
# 17                  阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。  semantic_agent
# 18                        苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。  semantic_agent
# 19                              格玛承认她想参加洛娜和米歇尔的婚礼招待会。  semantic_agent
# 20                                  安娜、苏和朱莉今晚将举行庆祝活动。  semantic_agent
# 21                       史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。  semantic_agent
# 22                                玛丽卡问拉拉今天是否来，拉拉回答肯定。  semantic_agent
# 23           米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。  semantic_agent
# 24                哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。  semantic_agent
# 25                      萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。  semantic_agent
# 26              特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。  semantic_agent
# 27                    娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。  semantic_agent
# 28                             梅格问安娜几点可以见面，安娜说晚上七点到家。  semantic_agent
# 29                 珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。  semantic_agent
# 30                               克里斯蒂和凯蒂都觉得派对很棒，但都很累。  semantic_agent
# 31                            萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。  semantic_agent
# 32                                  乔安娜将把游戏带到桑迪那里一起玩。  semantic_agent
# 33                     史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。  semantic_agent
# 34                          乔伊向彼得分享了她的美容店链接，彼得将查看该链接。  semantic_agent
# 35  伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告...  semantic_agent
# 36     布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。  semantic_agent
# 37                             肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。  semantic_agent
# 38           杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。  semantic_agent
# 39                         德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。  semantic_agent
# 40          梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。  semantic_agent
# 41                      卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。  semantic_agent
# 42  安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔...  semantic_agent
# 43        凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。  semantic_agent
# 44                卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。  semantic_agent
# 45           亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。  semantic_agent
# 46       达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。  semantic_agent
# 47                 巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。  semantic_agent
# 48            玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。  semantic_agent
# 49                     迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。  semantic_agent
#
#    agent1_model agent2_model agent3_model  num_model_calls
# 0    gemma3:27b   gemma3:27b   gemma3:27b                3
# 1    gemma3:27b   gemma3:27b   gemma3:27b                3
# 2    gemma3:27b   gemma3:27b   gemma3:27b                3
# 3    gemma3:27b   gemma3:27b   gemma3:27b                3
# 4    gemma3:27b   gemma3:27b   gemma3:27b                3
# 5    gemma3:27b   gemma3:27b   gemma3:27b                3
# 6    gemma3:27b   gemma3:27b   gemma3:27b                3
# 7    gemma3:27b   gemma3:27b   gemma3:27b                3
# 8    gemma3:27b   gemma3:27b   gemma3:27b                3
# 9    gemma3:27b   gemma3:27b   gemma3:27b                3
# 10   gemma3:27b   gemma3:27b   gemma3:27b                3
# 11   gemma3:27b   gemma3:27b   gemma3:27b                3
# 12   gemma3:27b   gemma3:27b   gemma3:27b                3
# 13   gemma3:27b   gemma3:27b   gemma3:27b                3
# 14   gemma3:27b   gemma3:27b   gemma3:27b                3
# 15   gemma3:27b   gemma3:27b   gemma3:27b                3
# 16   gemma3:27b   gemma3:27b   gemma3:27b                3
# 17   gemma3:27b   gemma3:27b   gemma3:27b                3
# 18   gemma3:27b   gemma3:27b   gemma3:27b                3
# 19   gemma3:27b   gemma3:27b   gemma3:27b                3
# 20   gemma3:27b   gemma3:27b   gemma3:27b                3
# 21   gemma3:27b   gemma3:27b   gemma3:27b                3
# 22   gemma3:27b   gemma3:27b   gemma3:27b                3
# 23   gemma3:27b   gemma3:27b   gemma3:27b                3
# 24   gemma3:27b   gemma3:27b   gemma3:27b                3
# 25   gemma3:27b   gemma3:27b   gemma3:27b                3
# 26   gemma3:27b   gemma3:27b   gemma3:27b                3
# 27   gemma3:27b   gemma3:27b   gemma3:27b                3
# 28   gemma3:27b   gemma3:27b   gemma3:27b                3
# 29   gemma3:27b   gemma3:27b   gemma3:27b                3
# 30   gemma3:27b   gemma3:27b   gemma3:27b                3
# 31   gemma3:27b   gemma3:27b   gemma3:27b                3
# 32   gemma3:27b   gemma3:27b   gemma3:27b                3
# 33   gemma3:27b   gemma3:27b   gemma3:27b                3
# 34   gemma3:27b   gemma3:27b   gemma3:27b                3
# 35   gemma3:27b   gemma3:27b   gemma3:27b                3
# 36   gemma3:27b   gemma3:27b   gemma3:27b                3
# 37   gemma3:27b   gemma3:27b   gemma3:27b                3
# 38   gemma3:27b   gemma3:27b   gemma3:27b                3
# 39   gemma3:27b   gemma3:27b   gemma3:27b                3
# 40   gemma3:27b   gemma3:27b   gemma3:27b                3
# 41   gemma3:27b   gemma3:27b   gemma3:27b                3
# 42   gemma3:27b   gemma3:27b   gemma3:27b                3
# 43   gemma3:27b   gemma3:27b   gemma3:27b                3
# 44   gemma3:27b   gemma3:27b   gemma3:27b                3
# 45   gemma3:27b   gemma3:27b   gemma3:27b                3
# 46   gemma3:27b   gemma3:27b   gemma3:27b                3
# 47   gemma3:27b   gemma3:27b   gemma3:27b                3
# 48   gemma3:27b   gemma3:27b   gemma3:27b                3
# 49   gemma3:27b   gemma3:27b   gemma3:27b                3

# %%
# Cell 15: Compare semantic-agent outputs with references

comparison_columns = [
    "id",
    "test_index",
    "final_summary",
    "reference_chinese_summary",
]

comparison_df = df[comparison_columns].copy()

comparison_df
# Out:
#             id  test_index                                      final_summary  \
# 0   gold_00001          23                   安妮发现马克谎称自己三十岁，实际四十岁，她认为这是个严重的问题。
# 1   gold_00002          30                              玛丽向卡特借钱，卡特答应在一小时内借给她。
# 2   gold_00003          39                             蒂娜的航班延误。阿拉承诺向蒂娜汇报会议结果。
# 3   gold_00004          65                    安娜和凯瑟琳计划明天拜访奶奶，凯瑟琳承诺明天早上给安娜打电话。
# 4   gold_00005          66                         乔伊斯分享链接，迈克尔觉得便宜，埃德森立即预订机票。
# 5   gold_00006          67              根据地图，旅程较长。简恩建议将会议时间改为下午四点半，并得到史蒂文的同意。
# 6   gold_00007          78                         蒂娜同意帮助菲奥娜制作馅饼，并指导她混合鸡蛋的方法。
# 7   gold_00008          86           奥拉夫和娜塔莉最初想看歌剧，后决定去索霍参加‘蒂凡尼早餐’派对，并计划尽快购票。
# 8   gold_00009         120                约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。
# 9   gold_00010         137             卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。
# 10  gold_00011         139          保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。
# 11  gold_00012         192                      哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。
# 12  gold_00013         210                          玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。
# 13  gold_00014         211                  卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。
# 14  gold_00015         212  亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精...
# 15  gold_00016         215      大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。
# 16  gold_00017         244                         琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。
# 17  gold_00018         285                  阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。
# 18  gold_00019         319                        苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。
# 19  gold_00020         346                              格玛承认她想参加洛娜和米歇尔的婚礼招待会。
# 20  gold_00021         355                                  安娜、苏和朱莉今晚将举行庆祝活动。
# 21  gold_00022         367                       史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。
# 22  gold_00023         393                                玛丽卡问拉拉今天是否来，拉拉回答肯定。
# 23  gold_00024         417           米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。
# 24  gold_00025         432                哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。
# 25  gold_00026         433                      萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。
# 26  gold_00027         442              特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。
# 27  gold_00028         499                    娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。
# 28  gold_00029         528                             梅格问安娜几点可以见面，安娜说晚上七点到家。
# 29  gold_00030         532                 珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。
# 30  gold_00031         536                               克里斯蒂和凯蒂都觉得派对很棒，但都很累。
# 31  gold_00032         537                            萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。
# 32  gold_00033         544                                  乔安娜将把游戏带到桑迪那里一起玩。
# 33  gold_00034         548                     史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。
# 34  gold_00035         551                          乔伊向彼得分享了她的美容店链接，彼得将查看该链接。
# 35  gold_00036         590  伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告...
# 36  gold_00037         598     布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。
# 37  gold_00038         605                             肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。
# 38  gold_00039         616           杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。
# 39  gold_00040         621                         德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。
# 40  gold_00041         635          梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。
# 41  gold_00042         649                      卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。
# 42  gold_00043         676  安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔...
# 43  gold_00044         678        凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。
# 44  gold_00045         690                卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。
# 45  gold_00046         711           亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。
# 46  gold_00047         737       达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。
# 47  gold_00048         767                 巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。
# 48  gold_00049         799            玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。
# 49  gold_00050         800                     迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。

# %%
# Cell 16: Inspect semantic-agent intermediate outputs and final output

if not df.empty:
    inspection_columns = [
        "id",
        "test_index",
        "dialogue",
        "agent1_semantic_representation_json",
        "agent2_summary_generation_json",
        "agent3_revision_json",
        "final_summary",
        "reference_english_summary",
        "reference_chinese_summary",
    ]

    inspection_df = df[inspection_columns].copy()
    display(inspection_df)
else:
    print("No results found.")
# Out:
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                   agent1_semantic_representation_json  \
# 0   {\n  "participants": [\n    "Anne",\n    "Iren...
# 1   {\n  "participants": [\n    "Mary",\n    "Cart...
# 2   {\n  "participants": [\n    "Tina",\n    "Ala"...
# 3   {\n  "participants": [\n    "Ana",\n    "Cathe...
# 4                                                  {}
# 5   {\n  "participants": [\n    "Jane",\n    "Stev...
# 6   {\n  "participants": [\n    "Fiona",\n    "Tin...
# 7   {\n  "participants": [\n    "Olafur",\n    "Na...
# 8   {\n  "participants": [\n    "John",\n    "Joan...
# 9   {\n  "participants": [\n    "Peyton",\n    "Ca...
# 10  {\n  "participants": [\n    "Paul",\n    "Emma...
# 11  {\n  "participants": [\n    "Harris",\n    "Le...
# 12  {\n  "participants": [\n    "Yaz",\n    "Mary"...
# 13  {\n  "participants": [\n    "Ellie",\n    "Aal...
# 14                                                 {}
# 15                                                 {}
# 16  {\n  "participants": [\n    "Jones",\n    "Ang...
# 17  {\n  "participants": [\n    "Casey",\n    "Ame...
# 18  {\n  "participants": [\n    "Sue",\n    "Steve...
# 19  {\n  "participants": [\n    "Timmy",\n    "Gem...
# 20  {\n  "participants": [\n    "Ann",\n    "Sue",...
# 21  {\n  "participants": [\n    "Steve",\n    "Mum...
# 22                                                 {}
# 23  {\n  "participants": [\n    "Miranda",\n    "S...
# 24  {\n  "participants": [\n    "Javier",\n    "Ju...
# 25  {\n  "participants": [\n    "Sam",\n    "Jessi...
# 26  {\n  "participants": [\n    "Terence",\n    "D...
# 27  {\n  "participants": [\n    "Natacha",\n    "C...
# 28  {\n  "participants": [\n    "Meg",\n    "Ann"\...
# 29  {\n  "participants": [\n    "Pete",\n    "Jen"...
# 30                                                 {}
# 31  {\n  "participants": [\n    "Sam",\n    "Carla...
# 32  {\n  "participants": [\n    "Joana",\n    "San...
# 33  {\n  "participants": [\n    "Steve",\n    "Rob...
# 34  {\n  "participants": [\n    "Peter",\n    "Joy...
# 35  {\n  "participants": [\n    "Ethan",\n    "Noa...
# 36                                                 {}
# 37  {\n  "participants": [\n    "Barbara",\n    "S...
# 38  {\n  "participants": [\n    "Jake",\n    "Tom"...
# 39  {\n  "participants": [\n    "Phil",\n    "Dean...
# 40  {\n  "participants": [\n    "Mell",\n    "Glor...
# 41  {\n  "participants": [\n    "Callan",\n    "Wa...
# 42  {\n  "participants": [\n    "Anna",\n    "Joan...
# 43  {\n  "participants": [\n    "Sam",\n    "Kate"...
# 44  {\n  "participants": [\n    "Mia",\n    "Jenni...
# 45  {\n  "participants": [\n    "Pedro",\n    "Ale...
# 46  {\n  "participants": [\n    "Damian",\n    "Et...
# 47  {\n  "participants": [\n    "Barry",\n    "Jak...
# 48  {\n  "participants": [\n    "Martha",\n    "Op...
# 49  {\n  "participants": [\n    "Linda",\n    "Mic...
#
#                        agent2_summary_generation_json  \
# 0   {\n  "selected_events": [\n    {\n      "event...
# 1   {\n  "selected_events": [\n    {\n      "event...
# 2   {\n  "selected_events": [\n    {\n      "event...
# 3   {\n  "selected_events": [\n    {\n      "event...
# 4                                                  {}
# 5   {\n  "selected_events": [\n    {\n      "event...
# 6   {\n  "selected_events": [\n    {\n      "event...
# 7   {\n  "selected_events": [\n    {\n      "event...
# 8   {\n  "selected_events": [\n    {\n      "event...
# 9   {\n  "selected_events": [\n    {\n      "event...
# 10  {\n  "selected_events": [\n    {\n      "event...
# 11  {\n  "selected_events": [\n    {\n      "event...
# 12  {\n  "selected_events": [\n    {\n      "event...
# 13  {\n  "selected_events": [\n    {\n      "event...
# 14                                                 {}
# 15                                                 {}
# 16  {\n  "selected_events": [\n    {\n      "event...
# 17  {\n  "selected_events": [\n    {\n      "event...
# 18  {\n  "selected_events": [\n    {\n      "event...
# 19  {\n  "selected_events": [\n    {\n      "event...
# 20  {\n  "selected_events": [\n    {\n      "event...
# 21  {\n  "selected_events": [\n    {\n      "event...
# 22                                                 {}
# 23  {\n  "selected_events": [\n    {\n      "event...
# 24  {\n  "selected_events": [\n    {\n      "event...
# 25  {\n  "selected_events": [\n    {\n      "event...
# 26  {\n  "selected_events": [\n    {\n      "event...
# 27  {\n  "selected_events": [\n    {\n      "event...
# 28  {\n  "selected_events": [\n    {\n      "event...
# 29  {\n  "selected_events": [\n    {\n      "event...
# 30                                                 {}
# 31  {\n  "selected_events": [\n    {\n      "event...
# 32  {\n  "selected_events": [\n    {\n      "event...
# 33  {\n  "selected_events": [\n    {\n      "event...
# 34  {\n  "selected_events": [\n    {\n      "event...
# 35  {\n  "selected_events": [\n    {\n      "event...
# 36                                                 {}
# 37  {\n  "selected_events": [\n    {\n      "event...
# 38  {\n  "selected_events": [\n    {\n      "event...
# 39  {\n  "selected_events": [\n    {\n      "event...
# 40  {\n  "selected_events": [\n    {\n      "event...
# 41  {\n  "selected_events": [\n    {\n      "event...
# 42  {\n  "selected_events": [\n    {\n      "event...
# 43  {\n  "selected_events": [\n    {\n      "event...
# 44  {\n  "selected_events": [\n    {\n      "event...
# 45  {\n  "selected_events": [\n    {\n      "event...
# 46  {\n  "selected_events": [\n    {\n      "event...
# 47  {\n  "selected_events": [\n    {\n      "event...
# 48  {\n  "selected_events": [\n    {\n      "event...
# 49  {\n  "selected_events": [\n    {\n      "event...
#
#                                  agent3_revision_json  \
# 0   {\n  "needs_revision": false,\n  "issues_ident...
# 1   {\n  "needs_revision": false,\n  "issues_ident...
# 2   {\n  "needs_revision": false,\n  "issues_ident...
# 3   {\n  "needs_revision": false,\n  "issues_ident...
# 4   {\n  "needs_revision": true,\n  "issues_identi...
# 5   {\n  "needs_revision": false,\n  "issues_ident...
# 6   {\n  "needs_revision": false,\n  "issues_ident...
# 7   {\n  "needs_revision": false,\n  "issues_ident...
# 8   {\n  "needs_revision": false,\n  "issues_ident...
# 9   {\n  "needs_revision": false,\n  "issues_ident...
# 10  {\n  "needs_revision": false,\n  "issues_ident...
# 11  {\n  "needs_revision": false,\n  "issues_ident...
# 12  {\n  "needs_revision": false,\n  "issues_ident...
# 13  {\n  "needs_revision": false,\n  "issues_ident...
# 14  {\n  "needs_revision": false,\n  "issues_ident...
# 15  {\n  "needs_revision": false,\n  "issues_ident...
# 16  {\n  "needs_revision": false,\n  "issues_ident...
# 17  {\n  "needs_revision": true,\n  "issues_identi...
# 18  {\n  "needs_revision": false,\n  "issues_ident...
# 19  {\n  "needs_revision": false,\n  "issues_ident...
# 20  {\n  "needs_revision": false,\n  "issues_ident...
# 21  {\n  "needs_revision": false,\n  "issues_ident...
# 22  {\n  "needs_revision": false,\n  "issues_ident...
# 23  {\n  "needs_revision": true,\n  "issues_identi...
# 24  {\n  "needs_revision": true,\n  "issues_identi...
# 25  {\n  "needs_revision": false,\n  "issues_ident...
# 26  {\n  "needs_revision": true,\n  "issues_identi...
# 27  {\n  "needs_revision": false,\n  "issues_ident...
# 28  {\n  "needs_revision": true,\n  "issues_identi...
# 29  {\n  "needs_revision": false,\n  "issues_ident...
# 30  {\n  "needs_revision": false,\n  "issues_ident...
# 31  {\n  "needs_revision": false,\n  "issues_ident...
# 32  {\n  "needs_revision": false,\n  "issues_ident...
# 33  {\n  "needs_revision": false,\n  "issues_ident...
# 34  {\n  "needs_revision": false,\n  "issues_ident...
# 35  {\n  "needs_revision": false,\n  "issues_ident...
# 36  {\n  "needs_revision": true,\n  "issues_identi...
# 37  {\n  "needs_revision": true,\n  "issues_identi...
# 38  {\n  "needs_revision": false,\n  "issues_ident...
# 39  {\n  "needs_revision": false,\n  "issues_ident...
# 40  {\n  "needs_revision": false,\n  "issues_ident...
# 41  {\n  "needs_revision": true,\n  "issues_identi...
# 42  {\n  "needs_revision": false,\n  "issues_ident...
# 43  {\n  "needs_revision": false,\n  "issues_ident...
# 44  {\n  "needs_revision": false,\n  "issues_ident...
# 45  {\n  "needs_revision": false,\n  "issues_ident...
# 46  {\n  "needs_revision": false,\n  "issues_ident...
# 47  {\n  "needs_revision": true,\n  "issues_identi...
# 48  {\n  "needs_revision": false,\n  "issues_ident...
# 49  {\n  "needs_revision": false,\n  "issues_ident...
#
#                                         final_summary  \
# 0                    安妮发现马克谎称自己三十岁，实际四十岁，她认为这是个严重的问题。
# 1                               玛丽向卡特借钱，卡特答应在一小时内借给她。
# 2                              蒂娜的航班延误。阿拉承诺向蒂娜汇报会议结果。
# 3                     安娜和凯瑟琳计划明天拜访奶奶，凯瑟琳承诺明天早上给安娜打电话。
# 4                          乔伊斯分享链接，迈克尔觉得便宜，埃德森立即预订机票。
# 5               根据地图，旅程较长。简恩建议将会议时间改为下午四点半，并得到史蒂文的同意。
# 6                          蒂娜同意帮助菲奥娜制作馅饼，并指导她混合鸡蛋的方法。
# 7            奥拉夫和娜塔莉最初想看歌剧，后决定去索霍参加‘蒂凡尼早餐’派对，并计划尽快购票。
# 8                 约翰和琼原计划周三看电影，后改至周四晚上八点。约翰将发送电影详情给琼。
# 9              卡梅隆拒绝立即回家，并表示将在外地停留一周。佩顿建议卡梅隆通过快递寄送游戏。
# 10          保罗忘记了理疗，并提议为艾玛准备食物。艾玛欣然接受，保罗将在她午夜回家后准备食物。
# 11                      哈里斯告诉莱娜青木去世的消息，随后因母亲来电而结束了对话。
# 12                          玛丽和雅兹都将参加减肥俱乐部，雅兹将接送玛丽前往。
# 13                  卡米尔生病，无法参加课程。阿莉亚告知大家课程已搬到二楼342教室。
# 14  亚伦看到一个视频，觉得像他猫便便时的表情，并分享了多个表情包。内森觉得视频中的人像是在经历精...
# 15      大家在讨论各自正在观看的Netflix剧集，包括《广告狂人》、《王冠》、《权力的游戏》等。
# 16                         琼斯和安吉丽娜同意当天见面，琼斯将致电确认具体地点。
# 17                  阿米莉亚和克里斯汀请求凯西为她们做美甲，但凯西因耗时太长而拒绝了。
# 18                        苏伊要求史蒂夫收到信息后立即给她打电话，史蒂夫同意了。
# 19                              格玛承认她想参加洛娜和米歇尔的婚礼招待会。
# 20                                  安娜、苏和朱莉今晚将举行庆祝活动。
# 21                       史蒂夫告知母亲洗碗机已安装完毕，并且他对新洗碗机很满意。
# 22                                玛丽卡问拉拉今天是否来，拉拉回答肯定。
# 23           米兰达因工作请求取消会议，斯蒂芬妮质疑她工作过多，米兰达解释这是年轻医生的常态。
# 24                哈维尔询问纹身店，朱迪推荐华沙墨水。因价格，哈维尔决定在哥伦比亚纹身。
# 25                      萨姆和同伴将于八月十五日下午两点抵达迈克尔和杰西卡的酒店。
# 26              特伦斯误以为丹尼尔偷钱，后发现钱已放好并道歉。丹尼尔对之前的指控表示愤怒。
# 27                    娜塔莎将接查尔斯，查尔斯承诺到达韦西内站后会打电话告知娜塔莎。
# 28                             梅格问安娜几点可以见面，安娜说晚上七点到家。
# 29                 珍要求彼得购买梨味酸奶，如果没有则不买。她只接受梨味，拒绝其他口味。
# 30                               克里斯蒂和凯蒂都觉得派对很棒，但都很累。
# 31                            萨姆和卡拉约定在米恩伍德的咖啡馆下午两点见面。
# 32                                  乔安娜将把游戏带到桑迪那里一起玩。
# 33                     史蒂夫和罗布都获得了新的梦剧场专辑，并将稍后分享他们的看法。
# 34                          乔伊向彼得分享了她的美容店链接，彼得将查看该链接。
# 35  伊森询问谁将参加索尔斯塔菲尔演唱会。诺亚因工作原因不确定，但莱奥极力劝说。诺亚表示会确认后告...
# 36     布拉德利看到一只猫闯入古迪逊公园球场，吉尔和茱莉亚觉得很可爱。球迷认为这是本赛季最好的娱乐。
# 37                             肖恩获准带狗去芭芭拉家过夜。扎克也正在赶来。
# 38           杰克获得了团队每周最佳球员，计划将其出售，并用所得资金购买更适合自己队伍的球员。
# 39                         德娜建议菲尔保留太阳镜，菲尔决定留下，因为无人认领。
# 40          梅尔和格洛丽亚决定在本周六在梅尔家举办烧烤，梅尔准备食物，格洛丽亚负责饮品和甜点。
# 41                      卡兰的三星S8手机屏幕变黑，他计划送修，并确认已备份数据。
# 42  安娜（Anna）感到胃痛，她和乔安娜（Joanna）决定如果疼痛持续，就去看医生。安娜将为乔...
# 43        凯特告知萨姆和杰夫厨房楼梯下正在制作的蛋糕上装饰着不寻常的图案，萨姆表示想看这个蛋糕。
# 44                卡琳认为对方正在破坏地球。米娅承诺竭尽全力赢得下次选举，卡琳表示赞同。
# 45           亚历克斯向佩德罗表达了对闪电侠的喜爱，并以其速度为例说服佩德罗认可闪电侠的力量。
# 46       达米安请求伊森购买烤肉卷，并承诺改正自身行为。伊森虽然不情愿，但最终同意了达米安的要求。
# 47                 巴里、杰克、戴夫和凯莉将一同参加妇女罢工，并约定中午在校园附近集合。
# 48            玛莎询问奥菲莉亚镜片来源，奥菲莉亚告知为“疯狂镜片”。玛莎感谢并表示将去查看。
# 49                     迈克尔告知琳达，妈妈最喜欢洋桔梗，并让她购买洋桔梗作为礼物。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
