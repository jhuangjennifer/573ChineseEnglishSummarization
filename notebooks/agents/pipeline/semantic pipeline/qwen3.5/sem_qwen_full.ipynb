# %% [markdown]
# # Semantic-Agent Pipeline for English-to-Chinese Dialogue Summarization
#
# This notebook implements a local semantic-agent pipeline for English-to-Chinese cross-lingual dialogue summarization.
#
# The semantic pipeline uses three local small language model agents. Agent 1 reads the original English dialogue and extracts a structured semantic representation, including participants, speaker intent, actor/action/recipient relations, key events, and the final outcome. Agent 2 selects the most salient events and generates a draft Chinese summary. Agent 3 verifies the draft summary against the original dialogue and revises it only if necessary.
#
# ```text
# English Dialogue
# → Agent 1: Semantic Understanding Agent
# → Agent 2: Event Selection and Chinese Summary Generation Agent
# → Agent 3: Verification and Revision Agent
# → Final Chinese Summary
# ```
#
# The pipeline consists of three agents:
#
# ```text
# Agent 1: Semantic Understanding Agent
# Input: original English dialogue
# Output: structured semantic representation
#
# Agent 2: Event Selection and Chinese Summary Generation Agent
# Input: structured semantic representation from Agent 1
# Output: selected events and draft Chinese summary
#
# Agent 3: Verification and Revision Agent
# Input: original dialogue + Agent 2 selected events and draft summary
# Output: revised final Chinese summary
# ```
# This setup is used as the proposed semantic-agent pipeline. Unlike Direct, Translate-then-Summarize, and Summarize-then-Translate baselines, this pipeline explicitly represents pragmatic meaning, semantic roles, actor/action relations, and final dialogue outcomes before generating the final Chinese summary.
#
# The local small language models are served through Ollama. The notebook controls prompt design, JSON parsing, intermediate output inspection, verification/revision, checkpointing, and result saving.

# %% [markdown]
# ## 0. Local Ollama Setup
#
# Before running this notebook, install Ollama and download the model locally.
#
# ### Recommended model setup
#
# This notebook uses a single-model multi-agent setup. All three agents use Qwen3.5-27B.
#
# ```bash
# ollama pull qwen3.5:27b
# ```
#
# You can check downloaded models with:
#
# ```bash
# ollama list
# ```
#
# You can check currently loaded models with:
#
# ```bash
# ollama ps
# ```
#
# If the Ollama server is not running, start it with:
#
# ```bash
# ollama serve
# ```
#
# On macOS, opening the Ollama app usually starts the local server automatically.

# %%
# Cell 1: Install required Python packages.
# Run this only once if the packages are not installed

# !pip install requests pandas tqdm
# Out:
# Requirement already satisfied: requests in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.33.1)
# Requirement already satisfied: pandas in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: colorama in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# current working path check
import os
from pathlib import Path

PROJECT_ROOT = Path("/Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization")
os.chdir(PROJECT_ROOT)

print("Current working directory:", Path.cwd())
# Out:
# Current working directory: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization

# %%
# Cell 2: Imports and global configuration

import json
import time
from pathlib import Path
from typing import Any, Dict, List, Optional

import requests
import pandas as pd
from tqdm.auto import tqdm

OLLAMA_HOST = "http://localhost:11434"

# Semantic-agent models
# All agents use the same 27B model for a consistent model-capacity setting.
SEMANTIC_UNDERSTANDING_MODEL = "qwen3.5:27b"
SUMMARY_GENERATION_MODEL = "qwen3.5:27b"
REVISION_MODEL = "qwen3.5:27b"

DEFAULT_TEMPERATURE = 0.2
DEFAULT_NUM_CTX = 4096
REVISION_NUM_CTX = 4096

# Gold set path
GOLD_SET_PATH = Path(
    "/Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/data/gold_results/gold_set_50_zh_XSAMSum_bart.json"
)

# Output directory
OUTPUT_DIR = Path(
    "/Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results"
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# Output files for semantic-agent pipeline
INTERMEDIATE_OUTPUT_PATH = OUTPUT_DIR / "semantic_qwen27b_50samples_intermediate.jsonl"
FULL_OUTPUT_PATH = OUTPUT_DIR / "semantic_qwen27b_50samples.jsonl"
FINAL_CSV_PATH = OUTPUT_DIR / "semantic_qwen27b_50samples.csv"
ERROR_OUTPUT_PATH = OUTPUT_DIR / "semantic_qwen27b_50samples_errors.jsonl"

print("Gold set path:", GOLD_SET_PATH)
print("Output directory:", OUTPUT_DIR)
print("Intermediate JSONL output path:", INTERMEDIATE_OUTPUT_PATH)
print("Full JSONL output path:", FULL_OUTPUT_PATH)
print("Final CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)

print("Agent 1 model:", SEMANTIC_UNDERSTANDING_MODEL)
print("Agent 2 model:", SUMMARY_GENERATION_MODEL)
print("Agent 3 model:", REVISION_MODEL)
# Out:
# Gold set path: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/data/gold_results/gold_set_50_zh_XSAMSum_bart.json
# Output directory: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results
# Intermediate JSONL output path: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results/semantic_qwen27b_50samples_intermediate.jsonl
# Full JSONL output path: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results/semantic_qwen27b_50samples.jsonl
# Final CSV output path: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results/semantic_qwen27b_50samples.csv
# Error output path: /Users/yunu919/Desktop/CLMS/LING573/573ChineseEnglishSummarization/notebooks/agents/results/semantic_qwen27b_50samples_errors.jsonl
# Agent 1 model: qwen3.5:27b
# Agent 2 model: qwen3.5:27b
# Agent 3 model: qwen3.5:27b

# %%
print(GOLD_SET_PATH.exists())
# Out:
# True

# %%
# Cell 3: Check whether Ollama is running

def check_ollama_server() -> bool:
    try:
        response = requests.get(f"{OLLAMA_HOST}/api/tags", timeout=10)
        response.raise_for_status()
        models = response.json().get("models", [])

        print("Ollama server is running.")
        print(f"Downloaded models: {[m.get('name') for m in models]}")

        return True

    except Exception as e:
        print("Could not connect to Ollama.")
        print("Make sure Ollama is installed and running.")
        print("Try running this in Terminal:")
        print("  ollama serve")
        print()
        print("Error:", repr(e))

        return False


_ = check_ollama_server()
# Out:
# Ollama server is running.
# Downloaded models: ['gemma3:27b', 'qwen3.5:27b']

# %%
# Cell 4: Ollama API helper

def call_ollama(
    model: str,
    prompt: str,
    system: Optional[str] = None,
    temperature: float = DEFAULT_TEMPERATURE,
    num_ctx: int = DEFAULT_NUM_CTX,
    timeout: int = 900,
    keep_alive: Optional[str] = None,
    json_mode: bool = True,
) -> str:
    """Call Ollama's local chat API and return the assistant content."""

    messages = []

    if system:
        messages.append({"role": "system", "content": system})

    messages.append({"role": "user", "content": prompt})

    payload = {
        "model": model,
        "messages": messages,
        "stream": False,
        "options": {
            "temperature": temperature,
            "num_ctx": num_ctx,
            "num_predict": 1024,
        },
        "think": False,
    }

    if json_mode:
        payload["format"] = "json"

    if keep_alive is not None:
        payload["keep_alive"] = keep_alive

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=timeout,
    )
    response.raise_for_status()

    data = response.json()
    content = data.get("message", {}).get("content", "")

    if content is None:
        content = ""

    return content.strip()


def load_ollama_model(model: str) -> None:
    """Preload a model into Ollama memory."""
    payload = {
        "model": model,
        "messages": [],
        "stream": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=300,
    )
    response.raise_for_status()

    print(f"Loaded model: {model}")


def unload_ollama_model(model: str) -> None:
    """Unload a model from Ollama memory."""
    payload = {
        "model": model,
        "messages": [],
        "keep_alive": 0,
        "stream": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=300,
    )
    response.raise_for_status()

    print(f"Unloaded model: {model}")

# %% [markdown]
# ## 1. Prompt Templates
#
# Each agent is defined as:
#
# ```text
# Agent = model + role-specific prompt + input/output format
# ```
#
# In the first version, we use a fixed workflow rather than a fully autonomous agent system.

# %%
# Cell 5: Prompt templates

# Agent 1: Semantic Understanding
SEMANTIC_UNDERSTANDING_PROMPT = """Analyze the English dialogue and extract only the key semantic events needed for the final summary.

Focus on:
- participants
- speaker intent
- actor/action/recipient relations
- final decisions, refusals, commitments, changed plans, or cancellations
- the final outcome of the dialogue

Rules:
- Do not analyze every utterance.
- Ignore greetings, jokes, reactions, and closings unless they affect the outcome.
- Resolve ambiguity from context.
- For imperatives, the actor is usually the listener, not the speaker.
  Example: if A says "Just text him" to B, B is the actor.
- Do not infer visual details from placeholders such as <file_photo>, <file_gif>, or <file>.

Extract 1-6 key events. Use fewer events for simple dialogues.
Write final_outcome as one concise sentence.

Output valid JSON only.

Schema:
{
  "participants": ["speaker names"],
  "semantic_grounding": [
    {
      "event_id": 1,
      "speaker": "speaker name",
      "speech_act": "short label",
      "intended_meaning": "concise interpretation",
      "actor": "person or null",
      "action": "concise action",
      "object": "object or null",
      "recipient": "person or null",
      "evidence": ["short quote"]
    }
  ],
  "final_outcome": "one concise sentence"
}

Input dialogue:
{dialogue}

JSON output:
"""

# Agent 2: Event Selection and Chinese Summary Generation
SUMMARY_GENERATION_PROMPT = """You will receive a structured semantic representation of an English dialogue.

Select the most important events and write a concise Chinese summary.

Rules:
- Select only 1-3 salient events.
- Prioritize the final outcome, changed plans, decisions, refusals, commitments, and important actor/action relations.
- If an earlier plan is later changed, summarize the final updated state.
- Do not invent details from placeholders.
- Use natural Chinese.

STRICT TRANSLATION RULE:
- You MUST translate ALL English proper nouns and speaker names into standard Chinese characters (e.g., Paul -> 保罗, Laura -> 劳拉).
- ABSOLUTELY NO English letters or names should appear in the final Chinese summary.

Conciseness:
- For simple dialogues, prefer 20-50 Chinese characters.
- For complex dialogues, allow up to 80 Chinese characters.

Output valid JSON only.

Schema:
{
  "selected_events": [
    {
      "event_id": 1,
      "key_event": "short description"
    }
  ],
  "summary_zh": "Chinese summary"
}

Input semantic representation:
{semantic_representation}

JSON output:
"""

# Agent 3: Concise Verification and Revision
REVISION_PROMPT = """Verify the draft Chinese summary against the original English dialogue.

Revise only if necessary.

Check for:
- hallucination
- missing final outcome
- wrong actor/action/recipient
- missing key event
- outdated plan
- unsupported visual detail
- awkward Chinese
- unnecessary verbosity
- untranslated English names or proper nouns

Rules:
- Trust the original dialogue if it conflicts with selected_events.
- Do not rewrite merely for style.
- If the draft is correct, keep it exactly unchanged.
- Be extremely concise.
- Use short issue tags only.
- revision_reason must be under 12 words.
- Output valid JSON only.

STRICT TRANSLATION RULE:
- You MUST translate ALL English proper nouns and speaker names into standard Chinese characters (e.g., Paul -> 保罗, Laura -> 劳拉).
- ABSOLUTELY NO English letters or names should appear in the final Chinese summary.

Conciseness:
- For simple dialogues, prefer 20-50 Chinese characters.
- For complex dialogues, allow up to 80 Chinese characters.

Allowed issue tags:
"hallucination", "wrong_actor", "wrong_action", "wrong_recipient",
"missing_final_outcome", "missing_key_event", "outdated_plan",
"too_verbose", "awkward_chinese", "unsupported_visual_detail", "untranslated_names"

Schema:
{
  "needs_revision": false,
  "issues_identified": [],
  "events_dropped": [],
  "revision_reason": "",
  "summary_zh_final": "Chinese summary"
}

Original English dialogue:
{dialogue}

Draft Chinese summary and selected events:
{summary_points}

JSON output:
"""

# %%
# Cell 6: JSONL utility functions

def append_jsonl(record: Dict[str, Any], path: Path) -> None:
    """Append one record to a JSONL file."""
    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")


def load_jsonl(path: Path) -> List[Dict[str, Any]]:
    """Load a JSONL file into a list of dictionaries."""
    if not path.exists():
        return []

    records = []

    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if line:
                records.append(json.loads(line))

    return records


def load_processed_ids(path: Path) -> set:
    """Return IDs that have already been processed."""
    records = load_jsonl(path)

    return {str(record["id"]) for record in records if "id" in record}

# %%
# Cell 7: Agent functions

import re

def fill_prompt(template: str, replacements: Dict[str, str]) -> str:
    """Replace only named placeholders while keeping JSON braces in the prompt unchanged."""
    prompt = template

    for key, value in replacements.items():
        prompt = prompt.replace("{" + key + "}", value)

    return prompt


def extract_json_object(text: str) -> Dict[str, Any]:
    """Extract and parse a JSON object from a model response.

    This function is intentionally robust because small local models may:
    - wrap JSON in markdown fences,
    - add extra text before or after JSON,
    - output Python-style booleans such as True/False.
    """
    raw = text.strip()

    # Remove markdown fences if present.
    if raw.startswith("```"):
        lines = raw.splitlines()
        raw = "\n".join(
            line for line in lines
            if not line.strip().startswith("```")
        ).strip()

    candidates = [raw]

    # Try extracting the substring between the first "{" and the last "}".
    start = raw.find("{")
    end = raw.rfind("}")

    if start != -1 and end != -1 and end > start:
        candidates.append(raw[start:end + 1])

    for candidate in candidates:
        # First try direct JSON parsing.
        try:
            parsed = json.loads(candidate)
            if isinstance(parsed, dict):
                return parsed
        except json.JSONDecodeError:
            pass

        # Repair common Python-style JSON issues.
        repaired = candidate
        repaired = re.sub(r"\bTrue\b", "true", repaired)
        repaired = re.sub(r"\bFalse\b", "false", repaired)
        repaired = re.sub(r"\bNone\b", "null", repaired)

        try:
            parsed = json.loads(repaired)
            if isinstance(parsed, dict):
                return parsed
        except json.JSONDecodeError:
            pass

    # Safe fallback for debugging.
    return {
        "raw_output": text,
        "parse_error": True,
    }


def format_json(data: Any) -> str:
    """Format Python objects as readable JSON text."""
    return json.dumps(
        data,
        ensure_ascii=False,
        indent=2,
    )


def extract_final_chinese_summary(revision_result: Dict[str, Any]) -> str:
    """Extract the final Chinese summary from Agent 3's revision output."""
    summary = revision_result.get("summary_zh_final", "")

    if isinstance(summary, list):
        return " ".join(str(item).strip() for item in summary if str(item).strip())

    if isinstance(summary, str):
        return summary.strip()

    if summary:
        return str(summary).strip()

    # Backward-compatible fallback.
    summary = revision_result.get("summary_zh", "")

    if isinstance(summary, str):
        return summary.strip()

    raw_output = revision_result.get("raw_output", "")

    if isinstance(raw_output, str):
        return raw_output.strip()

    return ""


def semantic_understanding_agent(dialogue: str) -> Dict[str, Any]:
    """Agent 1: Information Extraction Agent.

    Input:
        Original English dialogue

    Output:
        Structured representation of the dialogue
    """
    prompt = fill_prompt(
        SEMANTIC_UNDERSTANDING_PROMPT,
        {
            "dialogue": dialogue,
        },
    )

    response = call_ollama(
        model=SEMANTIC_UNDERSTANDING_MODEL,
        prompt=prompt,
        temperature=0.1,
        num_ctx=DEFAULT_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)

def summary_generation_agent(
    semantic_representation: Dict[str, Any],
) -> Dict[str, Any]:
    """Agent 2: Summary Generation Agent.

    Input:
        Structured semantic representation from Agent 1

    Output:
        Selected key events and draft Chinese summary
    """
    prompt = fill_prompt(
        SUMMARY_GENERATION_PROMPT,
        {
            "semantic_representation": format_json(semantic_representation),
        },
    )

    response = call_ollama(
        model=SUMMARY_GENERATION_MODEL,
        prompt=prompt,
        temperature=0.2,
        num_ctx=DEFAULT_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)


def revision_agent(
    dialogue: str,
    summary_generation_result: Dict[str, Any],
) -> Dict[str, Any]:
    """Agent 3: Verification and Revision Agent.

    Input:
        Original dialogue, selected events, and draft Chinese summary from Agent 2

    Output:
        Revised final Chinese summary
    """
    prompt = fill_prompt(
        REVISION_PROMPT,
        {
            "dialogue": dialogue,
            "summary_points": format_json(summary_generation_result),
        },
    )

    response = call_ollama(
        model=REVISION_MODEL,
        prompt=prompt,
        temperature=0.1,
        num_ctx=REVISION_NUM_CTX,
        keep_alive="10m",
        json_mode=True,
    )

    return extract_json_object(response)

# %% [markdown]
# ## 2. Agent Functions
#
# Each function corresponds to one agent in the pipeline.

# %%
# Cell 8: Three-agent semantic pipeline

def run_agents_1_2(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run Agent 1 and Agent 2 and save intermediate outputs."""

    sample_id = str(example.get("id", "unknown"))
    dialogue = example["dialogue"]

    reference_english_summary = example.get("reference_english_summary", "")
    reference_chinese_summary = example.get("reference_chinese_summary", "")

    # Agent 1: Semantic Understanding Agent
    semantic_representation = semantic_understanding_agent(dialogue)

    if verbose:
        print("\n" + "=" * 80)
        print(f"Sample ID: {sample_id}")
        print("=== Agent 1 Intermediate Output: Semantic Representation ===")
        print(format_json(semantic_representation))
        print("=" * 80 + "\n")

    # Agent 2: Event Selection and Chinese Summary Generation Agent
    summary_generation = summary_generation_agent(
        semantic_representation=semantic_representation,
    )

    if verbose:
        print("=== Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===")
        print(format_json(summary_generation))
        print("=" * 80 + "\n")

    return {
        "id": sample_id,
        "test_index": example.get("test_index", ""),
        "dialogue": dialogue,

        # References
        "reference_english_summary": reference_english_summary,
        "reference_chinese_summary": reference_chinese_summary,

        # Models
        "agent1_model": SEMANTIC_UNDERSTANDING_MODEL,
        "agent2_model": SUMMARY_GENERATION_MODEL,

        # Intermediate output from Agent 1
        "agent1_semantic_representation": semantic_representation,
        "agent1_semantic_representation_json": format_json(semantic_representation),

        # Intermediate output from Agent 2
        "agent2_summary_generation": summary_generation,
        "agent2_summary_generation_json": format_json(summary_generation),
    }


def run_agent_3_from_intermediate(
    intermediate_record: Dict[str, Any],
    verbose: bool = True,
) -> Dict[str, Any]:
    """Run Agent 3 using saved Agent 1/2 intermediate outputs."""

    dialogue = intermediate_record["dialogue"]
    summary_generation = intermediate_record["agent2_summary_generation"]

    # Agent 3: Verification and Revision Agent
    revision = revision_agent(
        dialogue=dialogue,
        summary_generation_result=summary_generation,
    )

    final_chinese_summary = extract_final_chinese_summary(
        revision_result=revision,
    )

    if verbose:
        print("=== Agent 3 Output: Verification + Revision ===")
        print(format_json(revision))
        print()
        print("=== Final Chinese Summary ===")
        print(final_chinese_summary)
        print("=" * 80 + "\n")

    return {
        **intermediate_record,

        # Model
        "agent3_model": REVISION_MODEL,

        # Agent 3 output
        "agent3_revision": revision,
        "agent3_revision_json": format_json(revision),

        # Final output
        "agent3_final_chinese_summary": final_chinese_summary,
        "final_summary": final_chinese_summary,

        # Metadata
        "pipeline": "semantic_agent",
        "num_model_calls": 3,
    }


def run_three_agent_pipeline(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run the full semantic-agent pipeline for one example."""

    # Since all agents use the same 27B model, load it once.
    load_ollama_model(SEMANTIC_UNDERSTANDING_MODEL)

    # Agent 1 + Agent 2
    intermediate_record = run_agents_1_2(example, verbose=verbose)

    # Agent 3
    final_record = run_agent_3_from_intermediate(
        intermediate_record,
        verbose=verbose,
    )

    return final_record

# %% [markdown]
# ## 3. Test with Examples
#
# Start with five examples before running the full dataset.
# This is the best way to inspect the intermediate outputs between agents.

# %%
# Cell 9: Load first 5 examples from the gold set

def load_examples_from_gold_set(path: Path, n: int = 5) -> List[Dict[str, Any]]:
    """Load the first n examples from the gold-set JSON file."""
    if not path.exists():
        raise FileNotFoundError(f"Gold set not found: {path}")

    with path.open("r", encoding="utf-8") as f:
        raw_data = json.load(f)

    examples = []

    for i, item in enumerate(raw_data[:n]):
        examples.append({
            "id": f"gold_{i+1:05d}",
            "test_index": item.get("test_index", ""),
            "dialogue": item["dialogue"],
            "reference_english_summary": item.get("summary", ""),
            "reference_chinese_summary": item.get("summary_zh", ""),
        })

    return examples


test_data = load_examples_from_gold_set(GOLD_SET_PATH, n=50)

print(f"Loaded {len(test_data)} examples.")
print("First example:")
print(test_data[0])
# Out:
# Loaded 50 examples.
# First example:
# {'id': 'gold_00001', 'test_index': 23, 'dialogue': "Anne: You were right, he was lying to me :/\nIrene: Oh no, what happened?\nJane: who? that Mark guy?\nAnne: yeah, he told me he's 30, today I saw his passport - he's 40\nIrene: You sure it's so important?\nAnne: he lied to me Irene", 'reference_english_summary': 'Mark lied to Anne about his age. Mark is 40.', 'reference_chinese_summary': '马克向安妮隐瞒了自己的年龄。他40岁了。'}

# %%
# Cell 10: Run the semantic-agent pipeline for the first example

result = run_three_agent_pipeline(test_data[4], verbose=True)
result
# Out:
# Loaded model: qwen3.5:27b
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Joyce",
#     "Michael",
#     "Edson"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Joyce",
#       "speech_act": "sharing",
#       "intended_meaning": "Joyce shares a link to a travel deal.",
#       "actor": "Joyce",
#       "action": "shares",
#       "object": "link",
#       "recipient": "Michael and Edson",
#       "evidence": [
#         "Check this out!",
#         "<link>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Michael",
#       "speech_act": "commenting",
#       "intended_meaning": "Michael notes the low price of the deal.",
#       "actor": "Michael",
#       "action": "comments",
#       "object": "price",
#       "recipient": null,
#       "evidence": [
#         "That's cheap!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Edson",
#       "speech_act": "committing",
#       "intended_meaning": "Edson decides to purchase a ticket immediately based on the deal.",
#       "actor": "Edson",
#       "action": "booking",
#       "object": "ticket",
#       "recipient": null,
#       "evidence": [
#         "I'm booking my ticket now!!"
#       ]
#     }
#   ],
#   "final_outcome": "Edson commits to booking a ticket after Joyce shares a cheap deal."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Joyce shares a travel deal link."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Edson decides to book a ticket immediately."
#     }
#   ],
#   "summary_zh": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"
# }
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"
# }
#
# === Final Chinese Summary ===
# 乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。
# ================================================================================
# {'id': 'gold_00005',
#  'test_index': 66,
#  'dialogue': "Joyce: Check this out!\r\nJoyce: <link>\r\nMichael: That's cheap!\r\nEdson: No way! I'm booking my ticket now!! ",
#  'reference_english_summary': 'Edson is booking his ticket now.',
#  'reference_chinese_summary': '埃德森正在订票。',
#  'agent1_model': 'qwen3.5:27b',
#  'agent2_model': 'qwen3.5:27b',
#  'agent1_semantic_representation': {'participants': ['Joyce',
#    'Michael',
#    'Edson'],
#   'semantic_grounding': [{'event_id': 1,
#     'speaker': 'Joyce',
#     'speech_act': 'sharing',
#     'intended_meaning': 'Joyce shares a link to a travel deal.',
#     'actor': 'Joyce',
#     'action': 'shares',
#     'object': 'link',
#     'recipient': 'Michael and Edson',
#     'evidence': ['Check this out!', '<link>']},
#    {'event_id': 2,
#     'speaker': 'Michael',
#     'speech_act': 'commenting',
#     'intended_meaning': 'Michael notes the low price of the deal.',
#     'actor': 'Michael',
#     'action': 'comments',
#     'object': 'price',
#     'recipient': None,
#     'evidence': ["That's cheap!"]},
#    {'event_id': 3,
#     'speaker': 'Edson',
#     'speech_act': 'committing',
#     'intended_meaning': 'Edson decides to purchase a ticket immediately based on the deal.',
#     'actor': 'Edson',
#     'action': 'booking',
#     'object': 'ticket',
#     'recipient': None,
#     'evidence': ["I'm booking my ticket now!!"]}],
#   'final_outcome': 'Edson commits to booking a ticket after Joyce shares a cheap deal.'},
#  'agent1_semantic_representation_json': '{\n  "participants": [\n    "Joyce",\n    "Michael",\n    "Edson"\n  ],\n  "semantic_grounding": [\n    {\n      "event_id": 1,\n      "speaker": "Joyce",\n      "speech_act": "sharing",\n      "intended_meaning": "Joyce shares a link to a travel deal.",\n      "actor": "Joyce",\n      "action": "shares",\n      "object": "link",\n      "recipient": "Michael and Edson",\n      "evidence": [\n        "Check this out!",\n        "<link>"\n      ]\n    },\n    {\n      "event_id": 2,\n      "speaker": "Michael",\n      "speech_act": "commenting",\n      "intended_meaning": "Michael notes the low price of the deal.",\n      "actor": "Michael",\n      "action": "comments",\n      "object": "price",\n      "recipient": null,\n      "evidence": [\n        "That\'s cheap!"\n      ]\n    },\n    {\n      "event_id": 3,\n      "speaker": "Edson",\n      "speech_act": "committing",\n      "intended_meaning": "Edson decides to purchase a ticket immediately based on the deal.",\n      "actor": "Edson",\n      "action": "booking",\n      "object": "ticket",\n      "recipient": null,\n      "evidence": [\n        "I\'m booking my ticket now!!"\n      ]\n    }\n  ],\n  "final_outcome": "Edson commits to booking a ticket after Joyce shares a cheap deal."\n}',
#  'agent2_summary_generation': {'selected_events': [{'event_id': 1,
#     'key_event': 'Joyce shares a travel deal link.'},
#    {'event_id': 3,
#     'key_event': 'Edson decides to book a ticket immediately.'}],
#   'summary_zh': '乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。'},
#  'agent2_summary_generation_json': '{\n  "selected_events": [\n    {\n      "event_id": 1,\n      "key_event": "Joyce shares a travel deal link."\n    },\n    {\n      "event_id": 3,\n      "key_event": "Edson decides to book a ticket immediately."\n    }\n  ],\n  "summary_zh": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"\n}',
#  'agent3_model': 'qwen3.5:27b',
#  'agent3_revision': {'needs_revision': False,
#   'issues_identified': [],
#   'events_dropped': [],
#   'revision_reason': '',
#   'summary_zh_final': '乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。'},
#  'agent3_revision_json': '{\n  "needs_revision": false,\n  "issues_identified": [],\n  "events_dropped": [],\n  "revision_reason": "",\n  "summary_zh_final": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"\n}',
#  'agent3_final_chinese_summary': '乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。',
#  'final_summary': '乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。',
#  'pipeline': 'semantic_agent',
#  'num_model_calls': 3}

# %%
# Cell 11: Print semantic-agent pipeline result clearly

def print_semantic_agent_result(result: Dict[str, Any]) -> None:
    print("=== Original Dialogue ===")
    print(result["dialogue"])
    print()

    print("=== Agent 1 Intermediate Output: Semantic Representation ===")
    print(result["agent1_semantic_representation_json"])
    print()

    print("=== Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===")
    print(result["agent2_summary_generation_json"])
    print()

    print("=== Agent 3 Output: Verification + Revision ===")
    print(result["agent3_revision_json"])
    print()

    print("=== Final Chinese Summary ===")
    print(result["final_summary"])
    print()

    print("=== Reference English Summary ===")
    print(result["reference_english_summary"])
    print()

    print("=== Reference Chinese Summary ===")
    print(result["reference_chinese_summary"])
    print()

    print("=== Metadata ===")
    print("Pipeline:", result["pipeline"])
    print("Agent 1 model:", result["agent1_model"])
    print("Agent 2 model:", result["agent2_model"])
    print("Agent 3 model:", result["agent3_model"])
    print("Model calls:", result["num_model_calls"])


print_semantic_agent_result(result)
# Out:
# === Original Dialogue ===
# Joyce: Check this out!
# Joyce: <link>
# Michael: That's cheap!
# Edson: No way! I'm booking my ticket now!!
#
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Joyce",
#     "Michael",
#     "Edson"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Joyce",
#       "speech_act": "sharing",
#       "intended_meaning": "Joyce shares a link to a travel deal.",
#       "actor": "Joyce",
#       "action": "shares",
#       "object": "link",
#       "recipient": "Michael and Edson",
#       "evidence": [
#         "Check this out!",
#         "<link>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Michael",
#       "speech_act": "commenting",
#       "intended_meaning": "Michael notes the low price of the deal.",
#       "actor": "Michael",
#       "action": "comments",
#       "object": "price",
#       "recipient": null,
#       "evidence": [
#         "That's cheap!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Edson",
#       "speech_act": "committing",
#       "intended_meaning": "Edson decides to purchase a ticket immediately based on the deal.",
#       "actor": "Edson",
#       "action": "booking",
#       "object": "ticket",
#       "recipient": null,
#       "evidence": [
#         "I'm booking my ticket now!!"
#       ]
#     }
#   ],
#   "final_outcome": "Edson commits to booking a ticket after Joyce shares a cheap deal."
# }
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Joyce shares a travel deal link."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Edson decides to book a ticket immediately."
#     }
#   ],
#   "summary_zh": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"
# }
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。"
# }
#
# === Final Chinese Summary ===
# 乔伊斯分享了一个便宜的旅行优惠链接，埃德森随即决定立即预订机票。
#
# === Reference English Summary ===
# Edson is booking his ticket now.
#
# === Reference Chinese Summary ===
# 埃德森正在订票。
#
# === Metadata ===
# Pipeline: semantic_agent
# Agent 1 model: qwen3.5:27b
# Agent 2 model: qwen3.5:27b
# Agent 3 model: qwen3.5:27b
# Model calls: 3

# %% [markdown]
# ## 4. Save Results
#
# This saves all intermediate outputs and the final output.

# %%
# Cell 12: Reset previous outputs before batch inference

INTERMEDIATE_OUTPUT_PATH.unlink(missing_ok=True)
FULL_OUTPUT_PATH.unlink(missing_ok=True)
FINAL_CSV_PATH.unlink(missing_ok=True)
ERROR_OUTPUT_PATH.unlink(missing_ok=True)

print("Previous output files reset.")
print("Intermediate output path:", INTERMEDIATE_OUTPUT_PATH)
print("Final JSONL output path:", FULL_OUTPUT_PATH)
print("CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Previous output files reset.
# Intermediate output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples_intermediate.jsonl
# Final JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples.jsonl
# CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples_errors.jsonl

# %% [markdown]
# ## 5. Batch Inference with Checkpointing
#
# This cell processes examples one by one and appends each completed result to `results/agentic_outputs.jsonl`.
#
# If the notebook stops, already processed examples remain saved.

# %%
# Cell 13: Two-stage batch inference with semantic-agent pipeline
# Time stamp: 9m 9.6s

from datetime import datetime

MAX_EXAMPLES = 50
SLEEP_SECONDS = 0.2

processed_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed: {len(processed_ids)} examples")

subset = test_data[:MAX_EXAMPLES]

print("Batch inference started at:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Semantic-agent pipeline with all 27B agents")
print("Agent 1 model:", SEMANTIC_UNDERSTANDING_MODEL)
print("Agent 2 model:", SUMMARY_GENERATION_MODEL)
print("Agent 3 model:", REVISION_MODEL)

# Load the shared 27B model once
load_ollama_model(SEMANTIC_UNDERSTANDING_MODEL)

# -------------------------
# Stage 1: Agent 1 + Agent 2
# -------------------------

processed_intermediate_ids = load_processed_ids(INTERMEDIATE_OUTPUT_PATH)
print(f"Already processed by Agent 1/2: {len(processed_intermediate_ids)} examples")

for ex in tqdm(
    subset,
    desc=f"Stage 1: Agent 1/2 with {SEMANTIC_UNDERSTANDING_MODEL}",
):
    sample_id = str(ex.get("id", "unknown"))

    if sample_id in processed_intermediate_ids:
        print(f"Skipping Agent 1/2 already processed sample: {sample_id}")
        continue

    try:
        intermediate_record = run_agents_1_2(ex, verbose=True)

        append_jsonl(intermediate_record, INTERMEDIATE_OUTPUT_PATH)
        processed_intermediate_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "stage": "agent_1_2",
            "id": sample_id,
            "test_index": ex.get("test_index", ""),
            "error": repr(e),
            "dialogue": ex.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error in Agent 1/2 on {sample_id}: {repr(e)}")


# -------------------------
# Stage 2: Agent 3
# -------------------------

intermediate_records = load_jsonl(INTERMEDIATE_OUTPUT_PATH)

processed_final_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed by Agent 3: {len(processed_final_ids)} examples")

for intermediate_record in tqdm(
    intermediate_records,
    desc=f"Stage 2: Agent 3 with {REVISION_MODEL}",
):
    sample_id = str(intermediate_record.get("id", "unknown"))

    if sample_id in processed_final_ids:
        print(f"Skipping Agent 3 already processed sample: {sample_id}")
        continue

    try:
        final_record = run_agent_3_from_intermediate(
            intermediate_record,
            verbose=True,
        )

        append_jsonl(final_record, FULL_OUTPUT_PATH)
        processed_final_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "stage": "agent_3",
            "id": sample_id,
            "test_index": intermediate_record.get("test_index", ""),
            "error": repr(e),
            "dialogue": intermediate_record.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error in Agent 3 on {sample_id}: {repr(e)}")

print("Batch inference finished at:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print(f"Finished. Intermediate outputs saved to: {INTERMEDIATE_OUTPUT_PATH}")
print(f"Finished. Final outputs saved to: {FULL_OUTPUT_PATH}")
# Out:
# Already processed: 0 examples
# Batch inference started at: 2026-05-09 17:53:59
# Semantic-agent pipeline with all 27B agents
# Agent 1 model: qwen3.5:27b
# Agent 2 model: qwen3.5:27b
# Agent 3 model: qwen3.5:27b
# Loaded model: qwen3.5:27b
# Already processed by Agent 1/2: 0 examples
# Stage 1: Agent 1/2 with qwen3.5:27b:   0%|          | 0/50 [00:00<?, ?it/s]
# ================================================================================
# Sample ID: gold_00001
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Anne",
#     "Irene",
#     "Jane"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Anne",
#       "speech_act": "disclosure",
#       "intended_meaning": "Anne reveals that Mark lied about his age.",
#       "actor": "Mark",
#       "action": "lied about age",
#       "object": "age",
#       "recipient": "Anne",
#       "evidence": [
#         "he told me he's 30, today I saw his passport - he's 40"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Irene",
#       "speech_act": "questioning",
#       "intended_meaning": "Irene questions the significance of the lie.",
#       "actor": null,
#       "action": "questioning importance",
#       "object": "the lie",
#       "recipient": "Anne",
#       "evidence": [
#         "You sure it's so important?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Anne",
#       "speech_act": "assertion",
#       "intended_meaning": "Anne insists that the lie is a critical issue.",
#       "actor": null,
#       "action": "emphasizing betrayal",
#       "object": "the lie",
#       "recipient": "Irene",
#       "evidence": [
#         "he lied to me Irene"
#       ]
#     }
#   ],
#   "final_outcome": "Anne confirms that Mark lied about his age and asserts that this deception is a significant issue."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Anne reveals Mark lied about his age."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Anne insists the lie is a critical issue."
#     }
#   ],
#   "summary_zh": "安妮揭露马克谎报年龄，尽管艾琳质疑此事的重要性，安妮仍坚持认为这种欺骗是严重问题。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00002
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Mary",
#     "Carter"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Mary",
#       "speech_act": "request",
#       "intended_meaning": "Mary asks Carter to lend her money.",
#       "actor": "Carter",
#       "action": "lend money",
#       "object": "money",
#       "recipient": "Mary",
#       "evidence": [
#         "lend me a few box"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Carter",
#       "speech_act": "commitment",
#       "intended_meaning": "Carter agrees to lend the money but needs an hour to arrive.",
#       "actor": "Carter",
#       "action": "provide money",
#       "object": "money",
#       "recipient": "Mary",
#       "evidence": [
#         "okay, give me an hour"
#       ]
#     }
#   ],
#   "final_outcome": "Carter agreed to lend Mary money after an hour."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Mary asks Carter to lend her money."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Carter agrees to lend money after an hour."
#     }
#   ],
#   "summary_zh": "玛丽向卡特借钱，卡特同意一小时后借给她。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00003
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Tina",
#     "Ala"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Tina",
#       "speech_act": "statement",
#       "intended_meaning": "Tina reports being delayed at the airport and catching a late flight home.",
#       "actor": "Tina",
#       "action": "catching evening flight",
#       "object": "flight",
#       "recipient": null,
#       "evidence": [
#         "they've kept us one hour in the plane and finally I'll catch the evening flight back home"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Ala",
#       "speech_act": "statement",
#       "intended_meaning": "Ala states they are currently traveling to an important meeting.",
#       "actor": "Ala",
#       "action": "going to meeting",
#       "object": "meeting",
#       "recipient": null,
#       "evidence": [
#         "And I'm on my way to a meeting",
#         "Yes, keep your finger crossed"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Tina",
#       "speech_act": "request",
#       "intended_meaning": "Tina asks Ala to provide an update on the meeting's result.",
#       "actor": "Ala",
#       "action": "informing about outcome",
#       "object": "meeting result",
#       "recipient": "Tina",
#       "evidence": [
#         "let me know how did it go"
#       ]
#     }
#   ],
#   "final_outcome": "Tina is returning home on a delayed evening flight while Ala heads to a meeting and agrees to update Tina on the outcome."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Tina delayed at airport, catching evening flight home"
#     },
#     {
#       "event_id": 2,
#       "key_event": "Ala heading to important meeting"
#     },
#     {
#       "event_id": 3,
#       "key_event": "Ala agrees to update Tina on meeting outcome"
#     }
#   ],
#   "summary_zh": "蒂娜因航班延误将乘晚班机回家，阿拉正前往重要会议，并答应告知蒂娜会议结果。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00004
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ana",
#     "Catherine"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Ana",
#       "speech_act": "proposal",
#       "intended_meaning": "Ana suggests visiting their grandmother tomorrow.",
#       "actor": "Ana and Catherine",
#       "action": "visit",
#       "object": "grandma",
#       "recipient": "grandma",
#       "evidence": [
#         "Wanna go visit grandma tomorrow?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Catherine",
#       "speech_act": "acceptance",
#       "intended_meaning": "Catherine agrees to the plan and commits to contacting Ana in the morning.",
#       "actor": "Catherine",
#       "action": "call",
#       "object": null,
#       "recipient": "Ana",
#       "evidence": [
#         "Yeah that would be nice",
#         "I'll call you when I wake up"
#       ]
#     }
#   ],
#   "final_outcome": "Ana and Catherine agreed to visit their grandmother tomorrow, with Catherine planning to call Ana upon waking up."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Ana proposes visiting grandma tomorrow"
#     },
#     {
#       "event_id": 2,
#       "key_event": "Catherine agrees and promises to call Ana in the morning"
#     }
#   ],
#   "summary_zh": "安娜提议明天去探望祖母，凯瑟琳同意并承诺早上醒来后给安娜打电话。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Joyce",
#     "Michael",
#     "Edson"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Joyce",
#       "speech_act": "sharing",
#       "intended_meaning": "Joyce shares a link to a travel deal.",
#       "actor": "Joyce",
#       "action": "shares",
#       "object": "link",
#       "recipient": "Michael and Edson",
#       "evidence": [
#         "Check this out!",
#         "<link>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Michael",
#       "speech_act": "commenting",
#       "intended_meaning": "Michael notes the low price of the deal.",
#       "actor": "Michael",
#       "action": "comments",
#       "object": "price",
#       "recipient": null,
#       "evidence": [
#         "That's cheap!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Edson",
#       "speech_act": "committing",
#       "intended_meaning": "Edson decides to purchase a ticket immediately based on the deal.",
#       "actor": "Edson",
#       "action": "booking",
#       "object": "ticket",
#       "recipient": null,
#       "evidence": [
#         "I'm booking my ticket now!!"
#       ]
#     }
#   ],
#   "final_outcome": "Edson commits to booking a ticket after Joyce shares a cheap deal."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Joyce shares a travel deal link."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Edson decides to book a ticket immediately."
#     }
#   ],
#   "summary_zh": "乔伊斯分享了一个优惠旅行链接，埃德森随即决定立即预订机票。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00006
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Jane",
#     "Steven"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Jane",
#       "speech_act": "proposal",
#       "intended_meaning": "Jane suggests changing the meeting time to 4:30 to avoid stress due to travel distance.",
#       "actor": "Jane",
#       "action": "propose meeting time change",
#       "object": "4:30",
#       "recipient": "Steven",
#       "evidence": [
#         "let's meet at 4:30 instead of 5, ok?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Steven",
#       "speech_act": "acceptance",
#       "intended_meaning": "Steven agrees to the new meeting time of 4:30.",
#       "actor": "Steven",
#       "action": "accept meeting time",
#       "object": "4:30",
#       "recipient": "Jane",
#       "evidence": [
#         "ok, if u reaaly want, we can meet at 4:30"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Jane",
#       "speech_act": "inquiry",
#       "intended_meaning": "Jane asks for confirmation of the meeting location.",
#       "actor": "Jane",
#       "action": "ask for location",
#       "object": "meeting spot",
#       "recipient": "Steven",
#       "evidence": [
#         "I will wait at the main entrance or where?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Steven",
#       "speech_act": "confirmation",
#       "intended_meaning": "Steven confirms the main entrance as the meeting location.",
#       "actor": "Steven",
#       "action": "confirm location",
#       "object": "main entrance",
#       "recipient": "Jane",
#       "evidence": [
#         "main entrance is good for me;-)"
#       ]
#     }
#   ],
#   "final_outcome": "Jane and Steven agreed to meet at 4:30 at the main entrance."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Jane proposes changing the meeting time to 4:30."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Steven agrees to the new time and confirms the main entrance as the location."
#     }
#   ],
#   "summary_zh": "简提议将会议时间改为四点三十分，史蒂文同意，并确认在主入口见面。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00007
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Fiona",
#     "Tina"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Fiona",
#       "speech_act": "request",
#       "intended_meaning": "Fiona asks Tina to assist her in preparing a tart for Chris.",
#       "actor": "Tina",
#       "action": "help prepare tart",
#       "object": "tart",
#       "recipient": "Fiona",
#       "evidence": [
#         "Could help me do it?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Tina",
#       "speech_act": "commitment",
#       "intended_meaning": "Tina agrees to help Fiona with the recipe.",
#       "actor": "Tina",
#       "action": "agree to help",
#       "object": "tart preparation",
#       "recipient": "Fiona",
#       "evidence": [
#         "Sure! It's not difficult."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Fiona",
#       "speech_act": "status_update",
#       "intended_meaning": "Fiona reports that she has already purchased the crust.",
#       "actor": "Fiona",
#       "action": "bought crust",
#       "object": "crust",
#       "recipient": null,
#       "evidence": [
#         "I must admit I bought the crust..."
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Tina",
#       "speech_act": "advice",
#       "intended_meaning": "Tina explains the technique to avoid making scrambled eggs when adding eggs to the filling.",
#       "actor": "Fiona",
#       "action": "mix continuously",
#       "object": "eggs",
#       "recipient": null,
#       "evidence": [
#         "once you start adding eggs you can't stop mixing it, otherwise you'll end up with scrambled eggs."
#       ]
#     }
#   ],
#   "final_outcome": "Tina agrees to help Fiona prepare a tart for Chris and provides advice on mixing the filling to avoid making scrambled eggs."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Tina agrees to help Fiona prepare a tart for Chris."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Tina advises Fiona to mix continuously when adding eggs to avoid scrambled eggs."
#     }
#   ],
#   "summary_zh": "蒂娜同意帮菲奥娜为克里斯准备挞，并建议她在加蛋时持续搅拌，以免做成炒蛋。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00008
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Olafur",
#     "Nathalie",
#     "Zoe"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Nathalie",
#       "speech_act": "proposal",
#       "intended_meaning": "Nathalie suggests a classy event like opera for New Year's Eve.",
#       "actor": null,
#       "action": "suggest",
#       "object": "opera",
#       "recipient": null,
#       "evidence": [
#         "I was thinking about something classy, like opera or sth like that"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Olafur",
#       "speech_act": "rejection",
#       "intended_meaning": "Olafur rejects the opera idea and proposes partying instead.",
#       "actor": null,
#       "action": "propose",
#       "object": "partying",
#       "recipient": null,
#       "evidence": [
#         "opera is not for me",
#         "I was thinking about partying somewhere"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Zoe",
#       "speech_act": "suggestion",
#       "intended_meaning": "Zoe suggests a specific party at Breakfast at Tiffany's.",
#       "actor": null,
#       "action": "suggest",
#       "object": "Breakfast at Tiffany's party",
#       "recipient": null,
#       "evidence": [
#         "Breakfast at Tiffany's party sounds classy"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Olafur",
#       "speech_act": "suggestion",
#       "intended_meaning": "Olafur shares a link to a club in Soho as an alternative.",
#       "actor": null,
#       "action": "suggest",
#       "object": "club in Soho",
#       "recipient": null,
#       "evidence": [
#         "<file_link>",
#         "is it classy enough?"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Nathalie",
#       "speech_act": "decision",
#       "intended_meaning": "Nathalie decides the group will go to the club in Soho.",
#       "actor": "Olafur, Nathalie, Zoe",
#       "action": "go to",
#       "object": "Soho club",
#       "recipient": null,
#       "evidence": [
#         "this club is AMAZING",
#         "we'll going to Soho then"
#       ]
#     },
#     {
#       "event_id": 6,
#       "speaker": "Olafur",
#       "speech_act": "commitment",
#       "intended_meaning": "Olafur commits to buying tickets for the Soho club soon.",
#       "actor": "Olafur",
#       "action": "buy",
#       "object": "tickets",
#       "recipient": null,
#       "evidence": [
#         "we just need to hurry up and buy some tickets soon"
#       ]
#     }
#   ],
#   "final_outcome": "The group decided to attend a party at a club in Soho for New Year's Eve, with Olafur tasked to purchase tickets immediately."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 5,
#       "key_event": "Group decides to go to Soho club"
#     },
#     {
#       "event_id": 6,
#       "key_event": "Olafur commits to buying tickets"
#     }
#   ],
#   "summary_zh": "娜塔莉提议看歌剧被奥拉弗尔拒绝，最终三人决定前往苏豪区俱乐部庆祝，奥拉弗尔负责购票。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00009
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "John",
#     "Joan"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "John",
#       "speech_act": "proposal",
#       "intended_meaning": "John invites Joan to see a movie on Wednesday.",
#       "actor": "John",
#       "action": "invite",
#       "object": "movie 'A Star is Born'",
#       "recipient": "Joan",
#       "evidence": [
#         "wanna go see \"A Star is Born\" on Wed?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Joan",
#       "speech_act": "refusal",
#       "intended_meaning": "Joan declines the Wednesday invitation due to being busy.",
#       "actor": "Joan",
#       "action": "refuse",
#       "object": "Wednesday plan",
#       "recipient": "John",
#       "evidence": [
#         "sorry can't",
#         "super busy"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Joan",
#       "speech_act": "counter-proposal",
#       "intended_meaning": "Joan suggests Thursday as an alternative day.",
#       "actor": "Joan",
#       "action": "propose",
#       "object": "Thursday",
#       "recipient": "John",
#       "evidence": [
#         "I'm free on Thursday"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "John",
#       "speech_act": "acceptance",
#       "intended_meaning": "John agrees to meet on Thursday.",
#       "actor": "John",
#       "action": "accept",
#       "object": "Thursday plan",
#       "recipient": "Joan",
#       "evidence": [
#         "I could do Thursday"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Joan",
#       "speech_act": "scheduling",
#       "intended_meaning": "Joan proposes 8pm as the meeting time.",
#       "actor": "Joan",
#       "action": "propose time",
#       "object": "8pm",
#       "recipient": "John",
#       "evidence": [
#         "so around 8pm?"
#       ]
#     },
#     {
#       "event_id": 6,
#       "speaker": "John",
#       "speech_act": "commitment",
#       "intended_meaning": "John commits to finding the venue and sending details.",
#       "actor": "John",
#       "action": "send details",
#       "object": "movie location",
#       "recipient": "Joan",
#       "evidence": [
#         "I'll see where it's palying and send you the details"
#       ]
#     }
#   ],
#   "final_outcome": "John and Joan agreed to see 'A Star is Born' on Thursday at 8pm, with John to provide the venue details."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Joan refuses Wednesday invitation"
#     },
#     {
#       "event_id": 4,
#       "key_event": "John accepts Thursday proposal"
#     },
#     {
#       "event_id": 6,
#       "key_event": "John commits to sending venue details"
#     }
#   ],
#   "summary_zh": "琼因忙碌拒绝了周三的邀请，提议改到周四。约翰同意，两人定于周四晚八点看电影，由约翰负责发送地点详情。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00010
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Peyton",
#     "Cameron"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Peyton",
#       "speech_act": "request",
#       "intended_meaning": "Peyton requests Cameron to bring a video game.",
#       "actor": "Cameron",
#       "action": "bring",
#       "object": "video game",
#       "recipient": "Peyton",
#       "evidence": [
#         "I have been asking you to bring that video game for me"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Cameron",
#       "speech_act": "refusal",
#       "intended_meaning": "Cameron refuses to bring the game in person due to lack of time and being out of town.",
#       "actor": "Cameron",
#       "action": "refuse to bring",
#       "object": "video game",
#       "recipient": "Peyton",
#       "evidence": [
#         "I am not having enough time to come home",
#         "I will have to stay out of town for another week i guess"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Peyton",
#       "speech_act": "proposal",
#       "intended_meaning": "Peyton suggests delivering the game via courier as an alternative.",
#       "actor": "Cameron",
#       "action": "deliver via courier",
#       "object": "video game",
#       "recipient": "Peyton",
#       "evidence": [
#         "Cant you just deliver that game through the courier?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Peyton",
#       "speech_act": "command",
#       "intended_meaning": "Peyton insists Cameron complete the task and return home immediately.",
#       "actor": "Cameron",
#       "action": "get the job done and come home",
#       "object": null,
#       "recipient": "Peyton",
#       "evidence": [
#         "Get the job done and come to home then. ASAP"
#       ]
#     }
#   ],
#   "final_outcome": "Cameron is unable to bring the video game in person due to being out of town, and Peyton insists he arrange delivery and return home immediately."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Cameron refuses to bring the game in person due to being out of town."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Peyton insists Cameron arrange delivery and return home immediately."
#     }
#   ],
#   "summary_zh": "卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00011
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Paul",
#     "Emma"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Paul",
#       "speech_act": "statement",
#       "intended_meaning": "Paul acknowledges missing his appointment and commits to rescheduling.",
#       "actor": "Paul",
#       "action": "schedule",
#       "object": "new physiotherapy appointment",
#       "recipient": null,
#       "evidence": [
#         "I forgot about my physiotherapy",
#         "I'll schedule a new appointment"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Emma",
#       "speech_act": "statement",
#       "intended_meaning": "Emma informs Paul of her late return time.",
#       "actor": "Emma",
#       "action": "return home",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I'll be home after midnight"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Paul",
#       "speech_act": "offer",
#       "intended_meaning": "Paul offers to prepare food for Emma.",
#       "actor": "Paul",
#       "action": "prepare",
#       "object": "food",
#       "recipient": "Emma",
#       "evidence": [
#         "Do you want me to prepare some food for you?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Emma",
#       "speech_act": "acceptance",
#       "intended_meaning": "Emma accepts Paul's offer to prepare food.",
#       "actor": "Paul",
#       "action": "prepare",
#       "object": "food",
#       "recipient": "Emma",
#       "evidence": [
#         "That would be lovely"
#       ]
#     }
#   ],
#   "final_outcome": "Paul will reschedule his physiotherapy appointment and prepare food for Emma, who will return home after midnight."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "保罗承认错过理疗并决定重新预约"
#     },
#     {
#       "event_id": 4,
#       "key_event": "劳拉接受保罗为其准备食物的提议"
#     }
#   ],
#   "summary_zh": "保罗将重新预约理疗，并同意为深夜回家的劳拉准备食物。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00012
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Harris",
#     "Lena"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Harris",
#       "speech_act": "inform",
#       "intended_meaning": "Harris reveals the death of his friend Aoki.",
#       "actor": "Harris",
#       "action": "discloses",
#       "object": "Aoki's death",
#       "recipient": "Lena",
#       "evidence": [
#         "My friend Aoki died yesterday."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Harris",
#       "speech_act": "speculate",
#       "intended_meaning": "Harris expresses uncertainty about the cause of death but fears the worst.",
#       "actor": "Harris",
#       "action": "speculates",
#       "object": "cause of death",
#       "recipient": "Lena",
#       "evidence": [
#         "Not sure yet. Thinking the worst..."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Harris",
#       "speech_act": "inform",
#       "intended_meaning": "Harris states he has not seen Aoki recently due to distance.",
#       "actor": "Harris",
#       "action": "reports",
#       "object": "lack of recent contact",
#       "recipient": "Lena",
#       "evidence": [
#         "Not for a few months. She lives in Michigan."
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Harris",
#       "speech_act": "terminate",
#       "intended_meaning": "Harris ends the conversation because his mother is calling.",
#       "actor": "Harris",
#       "action": "ends conversation",
#       "object": "chat",
#       "recipient": "Lena",
#       "evidence": [
#         "Got to go, mom's calling."
#       ]
#     }
#   ],
#   "final_outcome": "Harris informs Lena of his friend Aoki's death and ends the conversation to attend to his mother."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Harris informs Lena of Aoki's death"
#     },
#     {
#       "event_id": 4,
#       "key_event": "Harris ends the conversation to answer his mother"
#     }
#   ],
#   "summary_zh": "哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00013
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Yaz",
#     "Mary"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Yaz",
#       "speech_act": "proposal",
#       "intended_meaning": "Yaz proposes picking up Mary to go to the slimming club together.",
#       "actor": "Yaz",
#       "action": "pick up",
#       "object": null,
#       "recipient": "Mary",
#       "evidence": [
#         "See you at 6ish, pick you up!?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Mary",
#       "speech_act": "acceptance",
#       "intended_meaning": "Mary agrees to the plan to meet at 6ish.",
#       "actor": "Mary",
#       "action": "meet",
#       "object": null,
#       "recipient": "Yaz",
#       "evidence": [
#         "Yep! See you then!"
#       ]
#     }
#   ],
#   "final_outcome": "Yaz and Mary agreed to meet at 6ish so Yaz can pick Mary up for the slimming club."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Yaz proposes picking up Mary at 6ish for the slimming club."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Mary agrees to the plan."
#     }
#   ],
#   "summary_zh": "雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00014
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ellie",
#     "Aaliyah",
#     "Camille"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Camille",
#       "speech_act": "announcement",
#       "intended_meaning": "Camille informs the group that she is ill.",
#       "actor": "Camille",
#       "action": "is sick",
#       "object": null,
#       "recipient": null,
#       "evidence": [
#         "I'm sick :/"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Ellie",
#       "speech_act": "inquiry",
#       "intended_meaning": "Ellie asks Aaliyah for the current location of their classes.",
#       "actor": "Aaliyah",
#       "action": "provide location",
#       "object": "class location",
#       "recipient": "Ellie",
#       "evidence": [
#         "Aali, where are we having our classes now?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Aaliyah",
#       "speech_act": "information provision",
#       "intended_meaning": "Aaliyah specifies that the classes are in room 342 on the second floor.",
#       "actor": "Aaliyah",
#       "action": "states location",
#       "object": "room 342 on the second floor",
#       "recipient": "Ellie",
#       "evidence": [
#         "342 on the second floor"
#       ]
#     }
#   ],
#   "final_outcome": "Camille reports being sick, and Aaliyah informs the group that classes are held in room 342 on the second floor."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Camille announces she is sick."
#     },
#     {
#       "event_id": 3,
#       "key_event": "Aaliyah states classes are in room 342 on the second floor."
#     }
#   ],
#   "summary_zh": "卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00015
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Nathan",
#     "Aaron"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Nathan",
#       "speech_act": "sharing content",
#       "intended_meaning": "Nathan shares a video file with Aaron.",
#       "actor": "Nathan",
#       "action": "sends",
#       "object": "video",
#       "recipient": "Aaron",
#       "evidence": [
#         "<file_video>"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Nathan",
#       "speech_act": "providing source",
#       "intended_meaning": "Nathan reveals that Dan was the original sender of the video.",
#       "actor": "Dan",
#       "action": "sent",
#       "object": "video",
#       "recipient": "Nathan",
#       "evidence": [
#         "Dan sent it over"
#       ]
#     }
#   ],
#   "final_outcome": "Nathan and Aaron share a humorous exchange about a video originally sent by Dan."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Nathan sends a video to Aaron."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Nathan reveals Dan originally sent the video."
#     }
#   ],
#   "summary_zh": "内森向亚伦发送了一段视频，并透露该视频最初由丹发送。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00016
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Freddie",
#     "Kelly",
#     "Jim",
#     "Bob",
#     "Greg",
#     "Mike",
#     "Mary",
#     "Nancy",
#     "Alan"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Freddie",
#       "speech_act": "recommendation",
#       "intended_meaning": "Freddie suggests specific shows for Kelly to watch while waiting for new episodes.",
#       "actor": "Kelly",
#       "action": "watch",
#       "object": "Outlander or The Tudors",
#       "recipient": "Kelly",
#       "evidence": [
#         "Try Outlander or The Tudors in the meantime."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Bob",
#       "speech_act": "recommendation",
#       "intended_meaning": "Bob suggests Grimm or Sabrina as viewing options.",
#       "actor": "Jim",
#       "action": "watch",
#       "object": "Grimm or Sabrina",
#       "recipient": "Jim",
#       "evidence": [
#         "try Grimm or Sabrina. They're both great!"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Kelly",
#       "speech_act": "rejection",
#       "intended_meaning": "Kelly rejects the suggested shows as horrible and disgusting.",
#       "actor": "Kelly",
#       "action": "reject",
#       "object": "Grimm or Sabrina",
#       "recipient": "Bob",
#       "evidence": [
#         "they are all horrible and disgusting!"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Mike",
#       "speech_act": "recommendation",
#       "intended_meaning": "Mike recommends The West Wing to Greg as an alternative political drama.",
#       "actor": "Greg",
#       "action": "watch",
#       "object": "The West Wing",
#       "recipient": "Greg",
#       "evidence": [
#         "You should try The West Wing if you enjoy political dramas."
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Greg",
#       "speech_act": "suggestion",
#       "intended_meaning": "Greg mentions Bodyguard as a potentially good show based on hearsay.",
#       "actor": "null",
#       "action": "mention",
#       "object": "Bodyguard",
#       "recipient": "null",
#       "evidence": [
#         "Netflix original Bodyguard is supposed to be good from what I've heard."
#       ]
#     }
#   ],
#   "final_outcome": "Participants exchanged various TV show recommendations and personal viewing preferences without reaching a consensus on a single show to watch together."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Freddie recommends Outlander or The Tudors to Kelly"
#     },
#     {
#       "event_id": 2,
#       "key_event": "Bob suggests Grimm or Sabrina to Jim"
#     },
#     {
#       "event_id": 3,
#       "key_event": "Kelly rejects the suggested shows as horrible"
#     }
#   ],
#   "summary_zh": "弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，鲍勃建议吉姆观看《格林》或《萨布丽娜》，但凯莉拒绝称这些剧很糟糕。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00017
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Jones",
#     "Angelina"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Jones",
#       "speech_act": "proposal",
#       "intended_meaning": "Jones proposes meeting later in the afternoon in town.",
#       "actor": "Jones",
#       "action": "propose meeting",
#       "object": "meeting",
#       "recipient": "Angelina",
#       "evidence": [
#         "You think we can meet today later in the afternoon in town?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Angelina",
#       "speech_act": "acceptance",
#       "intended_meaning": "Angelina agrees to the proposed meeting.",
#       "actor": "Angelina",
#       "action": "accept meeting",
#       "object": "meeting",
#       "recipient": "Jones",
#       "evidence": [
#         "Definitely."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Jones",
#       "speech_act": "commitment",
#       "intended_meaning": "Jones commits to calling Angelina to confirm the specific meeting location.",
#       "actor": "Jones",
#       "action": "call to confirm location",
#       "object": "meeting location",
#       "recipient": "Angelina",
#       "evidence": [
#         "I will call you to confirm where we will meet."
#       ]
#     }
#   ],
#   "final_outcome": "Jones and Angelina agreed to meet later in the afternoon in town, with Jones to call and confirm the specific location."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "琼斯提议下午在镇上见面"
#     },
#     {
#       "event_id": 2,
#       "key_event": "安吉丽娜同意该提议"
#     },
#     {
#       "event_id": 3,
#       "key_event": "琼斯承诺致电确认具体地点"
#     }
#   ],
#   "summary_zh": "琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00018
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Casey",
#     "Amelia",
#     "Kristen"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Casey",
#       "speech_act": "statement",
#       "intended_meaning": "Casey confirms she painted her own nails and describes the process as time-consuming.",
#       "actor": "Casey",
#       "action": "painted nails",
#       "object": "nails",
#       "recipient": null,
#       "evidence": [
#         "yeah i did it myself :D got a new nail polish but damn it took me nearly 4 hours lol"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Amelia",
#       "speech_act": "request",
#       "intended_meaning": "Amelia asks Casey to paint her and Kristen's nails.",
#       "actor": "Casey",
#       "action": "paint nails",
#       "object": "nails",
#       "recipient": "Amelia and Kristen",
#       "evidence": [
#         "can you do it for us too?"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Kristen",
#       "speech_act": "request",
#       "intended_meaning": "Kristen reinforces the request for Casey to paint her nails.",
#       "actor": "Casey",
#       "action": "paint nails",
#       "object": "nails",
#       "recipient": "Kristen",
#       "evidence": [
#         "pretty please!"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Casey",
#       "speech_act": "refusal",
#       "intended_meaning": "Casey declines the request because the process was too difficult and time-consuming.",
#       "actor": "Casey",
#       "action": "refuse request",
#       "object": "painting nails",
#       "recipient": "Amelia and Kristen",
#       "evidence": [
#         "sorry you guys... it was a nightmare :( seriously 4 hours for nails is too much"
#       ]
#     }
#   ],
#   "final_outcome": "Casey refuses to paint Amelia and Kristen's nails due to the excessive time and effort required."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Amelia and Kristen request Casey to paint their nails."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Casey refuses the request due to the time-consuming process."
#     }
#   ],
#   "summary_zh": "凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而拒绝了。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00019
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Sue",
#     "Steve"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Sue",
#       "speech_act": "request",
#       "intended_meaning": "Sue instructs Steve to call her immediately upon receiving the message.",
#       "actor": "Steve",
#       "action": "call",
#       "object": null,
#       "recipient": "Sue",
#       "evidence": [
#         "Call me when you get this."
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Steve",
#       "speech_act": "commitment",
#       "intended_meaning": "Steve confirms he is performing the requested action.",
#       "actor": "Steve",
#       "action": "call",
#       "object": null,
#       "recipient": "Sue",
#       "evidence": [
#         "OK, I'm calling"
#       ]
#     }
#   ],
#   "final_outcome": "Steve agrees to Sue's request and initiates a call to her."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Sue instructs Steve to call her immediately."
#     },
#     {
#       "event_id": 2,
#       "key_event": "Steve confirms and initiates the call."
#     }
#   ],
#   "summary_zh": "苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00020
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Timmy",
#     "Gemma"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Timmy",
#       "speech_act": "inquiry",
#       "intended_meaning": "Timmy asks Gemma for suggestions on who to invite to an event.",
#       "actor": "Gemma",
#       "action": "suggest guests",
#       "object": "guest list",
#       "recipient": "Timmy",
#       "evidence": [
#         "Who do u wanna invite?"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Gemma",
#       "speech_act": "suggestion",
#       "intended_meaning": "Gemma proposes inviting Lona and Michelle to the event.",
#       "actor": "Timmy",
#       "action": "consider inviting",
#       "object": "Lona and Michelle",
#       "recipient": "Timmy",
#       "evidence": [
#         "I was thinking about Lona and Michelle."
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Timmy",
#       "speech_act": "challenge",
#       "intended_meaning": "Timmy teases Gemma about her unrealistic expectation of attending their weddings.",
#       "actor": "Gemma",
#       "action": "admit true intent",
#       "object": "wedding attendance",
#       "recipient": "Timmy",
#       "evidence": [
#         "Still thinking ur getting invites to their weddings?"
#       ]
#     },
#     {
#       "event_id": 4,
#       "speaker": "Gemma",
#       "speech_act": "admission",
#       "intended_meaning": "Gemma admits she wants to attend Lona and Michelle's wedding receptions.",
#       "actor": "Gemma",
#       "action": "express desire",
#       "object": "wedding receptions",
#       "recipient": "Timmy",
#       "evidence": [
#         "Fine! I want to come to their wedding receptions!"
#       ]
#     },
#     {
#       "event_id": 5,
#       "speaker": "Timmy",
#       "speech_act": "inquiry",
#       "intended_meaning": "Timmy asks if Gemma believes she can convince the hosts to invite her.",
#       "actor": "Gemma",
#       "action": "assess feasibility",
#       "object": "changing minds",
#       "recipient": "Timmy",
#       "evidence": [
#         "And u think u can change their minds?"
#       ]
#     },
#     {
#       "event_id": 6,
#       "speaker": "Gemma",
#       "speech_act": "uncertainty",
#       "intended_meaning": "Gemma expresses doubt about her ability to get invited.",
#       "actor": "Gemma",
#       "action": "acknowledge uncertainty",
#       "object": "invitation success",
#       "recipient": "Timmy",
#       "evidence": [
#         "Dunno."
#       ]
#     }
#   ],
#   "final_outcome": "Gemma admits she wants to attend Lona and Michelle's weddings but remains uncertain if she can convince them to invite her."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 2,
#       "key_event": "Gemma suggests inviting Lona and Michelle."
#     },
#     {
#       "event_id": 4,
#       "key_event": "Gemma admits wanting to attend their weddings."
#     },
#     {
#       "event_id": 6,
#       "key_event": "Gemma doubts she can get invited."
#     }
#   ],
#   "summary_zh": "杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00021
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Ann",
#     "Sue",
#     "Julie"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Ann",
#       "speech_act": "proposal",
#       "intended_meaning": "Ann suggests holding a celebration tonight.",
#       "actor": "Ann, Sue, Julie",
#       "action": "have a celebration",
#       "object": "tonight",
#       "recipient": null,
#       "evidence": [
#         "Let's have a little celebration tonight!"
#       ]
#     },
#     {
#       "event_id": 2,
#       "speaker": "Sue",
#       "speech_act": "commitment",
#       "intended_meaning": "Sue agrees to attend the celebration.",
#       "actor": "Sue",
#       "action": "attend",
#       "object": "celebration",
#       "recipient": null,
#       "evidence": [
#         "I'm in"
#       ]
#     },
#     {
#       "event_id": 3,
#       "speaker": "Julie",
#       "speech_act": "commitment",
#       "intended_meaning": "Julie agrees to attend the celebration.",
#       "actor": "Julie",
#       "action": "attend",
#       "object": "celebration",
#       "recipient": null,
#       "evidence": [
#         "me too!!!"
#       ]
#     }
#   ],
#   "final_outcome": "Ann, Sue, and Julie have agreed to celebrate together tonight."
# }
# ================================================================================
#
# === Agent 2 Intermediate Output: Selected Events + Draft Chinese Summary ===
# {
#   "selected_events": [
#     {
#       "event_id": 1,
#       "key_event": "Ann proposes a celebration tonight"
#     },
#     {
#       "event_id": 2,
#       "key_event": "Sue and Julie agree to attend"
#     }
#   ],
#   "summary_zh": "安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。"
# }
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00022
# === Agent 1 Intermediate Output: Semantic Representation ===
# {
#   "participants": [
#     "Steve",
#     "Mum"
#   ],
#   "semantic_grounding": [
#     {
#       "event_id": 1,
#       "speaker": "Steve",
#       "speech_act": "inform",
#       "intended_meaning": "Steve confirms the dishwasher has been delivered and installed.",
#       "actor": "Steve",
# ...
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。"
# }
#
# === Final Chinese Summary ===
# 卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "wrong_recipient",
#     "untranslated_names"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Wrong recipient name and untranslated name.",
#   "summary_zh_final": "保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。"
# }
#
# === Final Chinese Summary ===
# 保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。"
# }
#
# === Final Chinese Summary ===
# 哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。"
# }
#
# === Final Chinese Summary ===
# 雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。"
# }
#
# === Final Chinese Summary ===
# 卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "内森向亚伦发送了一段视频，并透露该视频最初由丹发送。"
# }
#
# === Final Chinese Summary ===
# 内森向亚伦发送了一段视频，并透露该视频最初由丹发送。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "wrong_recipient",
#     "missing_key_event"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Bob建议对象错误，遗漏其他关键推荐。",
#   "summary_zh_final": "弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。"
# }
#
# === Final Chinese Summary ===
# 弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。"
# }
#
# === Final Chinese Summary ===
# 琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而拒绝了。"
# }
#
# === Final Chinese Summary ===
# 凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而拒绝了。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。"
# }
#
# === Final Chinese Summary ===
# 苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。"
# }
#
# === Final Chinese Summary ===
# 杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。"
# }
#
# === Final Chinese Summary ===
# 安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。"
# }
#
# === Final Chinese Summary ===
# 史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。"
# }
#
# === Final Chinese Summary ===
# 玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。"
# }
#
# === Final Chinese Summary ===
# 米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Names must be translated to Chinese characters.",
#   "summary_zh_final": "朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。"
# }
#
# === Final Chinese Summary ===
# 朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。"
# }
#
# === Final Chinese Summary ===
# 迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。"
# }
#
# === Final Chinese Summary ===
# 特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。"
# }
#
# === Final Chinese Summary ===
# 娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Names Meg and Ann must be translated to Chinese.",
#   "summary_zh_final": "安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。"
# }
#
# === Final Chinese Summary ===
# 安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。"
# }
#
# === Final Chinese Summary ===
# 珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。"
# }
#
# === Final Chinese Summary ===
# 克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。"
# }
#
# === Final Chinese Summary ===
# 山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。"
# }
#
# === Final Chinese Summary ===
# 乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。"
# }
#
# === Final Chinese Summary ===
# 史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。"
# }
#
# === Final Chinese Summary ===
# 彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。"
# }
#
# === Final Chinese Summary ===
# 伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。"
# }
#
# === Final Chinese Summary ===
# 布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。"
# }
#
# === Final Chinese Summary ===
# 芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更合适的球员。"
# }
#
# === Final Chinese Summary ===
# 杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更合适的球员。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names",
#     "missing_key_event"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Names untranslated; missing Deana's offer.",
#   "summary_zh_final": "菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。"
# }
#
# === Final Chinese Summary ===
# 菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。"
# }
#
# === Final Chinese Summary ===
# 梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。"
# }
#
# === Final Chinese Summary ===
# 卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "wrong_actor",
#     "wrong_recipient"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Anna has pain, Joanna offers tea, not vice versa.",
#   "summary_zh_final": "安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。"
# }
#
# === Final Chinese Summary ===
# 安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。"
# }
#
# === Final Chinese Summary ===
# 凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "untranslated_names"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Names Karine, Peter, Mia must be translated to Chinese.",
#   "summary_zh_final": "卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。"
# }
#
# === Final Chinese Summary ===
# 卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强大的观点。"
# }
#
# === Final Chinese Summary ===
# 亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强大的观点。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": true,
#   "issues_identified": [
#     "missing_final_outcome"
#   ],
#   "events_dropped": [],
#   "revision_reason": "Ethan agreed to buy, not refused.",
#   "summary_zh_final": "达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。"
# }
#
# === Final Chinese Summary ===
# 达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。"
# }
#
# === Final Chinese Summary ===
# 巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。"
# }
#
# === Final Chinese Summary ===
# 玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。
# ================================================================================
#
# === Agent 3 Output: Verification + Revision ===
# {
#   "needs_revision": false,
#   "issues_identified": [],
#   "events_dropped": [],
#   "revision_reason": "",
#   "summary_zh_final": "琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。"
# }
#
# === Final Chinese Summary ===
# 琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。
# ================================================================================
#
# Batch inference finished at: 2026-05-09 21:10:48
# Finished. Intermediate outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples_intermediate.jsonl
# Finished. Final outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples.jsonl

# %% [markdown]
# ## 6. Export Final Summaries to CSV
#
# This file can be used for ROUGE, BERTScore, OmniScore, or manual analysis.

# %%
# Cell 14: Export semantic-agent summaries to CSV

records = load_jsonl(FULL_OUTPUT_PATH)

rows = []

for record in records:
    if "final_summary" not in record:
        continue

    rows.append({
        "id": record.get("id", ""),
        "test_index": record.get("test_index", ""),
        "dialogue": record.get("dialogue", ""),

        # Final output
        "final_summary": record.get("final_summary", ""),

        # References
        "reference_english_summary": record.get("reference_english_summary", ""),
        "reference_chinese_summary": record.get("reference_chinese_summary", ""),

        # Intermediate outputs
        "agent1_semantic_representation_json": record.get(
            "agent1_semantic_representation_json", ""
        ),
        "agent2_summary_generation_json": record.get(
            "agent2_summary_generation_json", ""
        ),
        "agent3_revision_json": record.get(
            "agent3_revision_json", ""
        ),

        # Agent 3 final
        "agent3_final_chinese_summary": record.get(
            "agent3_final_chinese_summary", ""
        ),

        # Metadata
        "pipeline": record.get("pipeline", "semantic_agent"),
        "agent1_model": record.get("agent1_model", ""),
        "agent2_model": record.get("agent2_model", ""),
        "agent3_model": record.get("agent3_model", ""),
        "num_model_calls": record.get("num_model_calls", 3),
    })

df = pd.DataFrame(rows)

if not df.empty:
    df = df.drop_duplicates(subset=["id"], keep="last")

df.to_csv(FINAL_CSV_PATH, index=False, encoding="utf-8-sig")

print(f"Saved final summaries to: {FINAL_CSV_PATH}")
df
# Out:
# Saved final summaries to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\semantic_qwen27b_50samples.csv
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                                         final_summary  \
# 0           安妮揭露马克谎报年龄，尽管艾琳质疑此事的重要性，安妮仍坚持认为这种欺骗是严重问题。
# 1                                玛丽向卡特借钱，卡特同意一小时后借给她。
# 2               蒂娜因航班延误将乘晚班机回家，阿拉正前往重要会议，并答应告知蒂娜会议结果。
# 3                    安娜提议明天去探望祖母，凯瑟琳同意并承诺早上醒来后给安娜打电话。
# 4                       乔伊斯分享了一个优惠旅行链接，埃德森随即决定立即预订机票。
# 5                    简提议将会议时间改为四点三十分，史蒂文同意，并确认在主入口见面。
# 6                蒂娜同意帮菲奥娜为克里斯准备挞，并建议她在加蛋时持续搅拌，以免做成炒蛋。
# 7          娜塔莉提议看歌剧被奥拉弗尔拒绝，最终三人决定前往苏豪区俱乐部庆祝，奥拉弗尔负责购票。
# 8   琼因忙碌拒绝了周三的邀请，提议改到周四。约翰同意，两人定于周四晚八点看电影，由约翰负责发送地...
# 9                   卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。
# 10                         保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。
# 11                      哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。
# 12                      雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。
# 13                    卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。
# 14                         内森向亚伦发送了一段视频，并透露该视频最初由丹发送。
# 15  弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。
# 16                   琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。
# 17  凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而...
# 18                  苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。
# 19           杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。
# 20                           安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。
# 21                     史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。
# 22                          玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。
# 23                      米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。
# 24       朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。
# 25                 迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。
# 26        特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。
# 27              娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。
# 28                    安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。
# 29                  珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。
# 30                    克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。
# 31           山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。
# 32               乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。
# 33           史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。
# 34                       彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。
# 35         伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。
# 36        布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。
# 37                          芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。
# 38  杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更...
# 39                   菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。
# 40         梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。
# 41        卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。
# 42              安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。
# 43                  凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。
# 44              卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。
# 45  亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强...
# 46                      达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。
# 47           巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。
# 48         玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。
# 49           琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary  \
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
#
#                   agent1_semantic_representation_json  \
# 0   {\n  "participants": [\n    "Anne",\n    "Iren...
# 1   {\n  "participants": [\n    "Mary",\n    "Cart...
# 2   {\n  "participants": [\n    "Tina",\n    "Ala"...
# 3   {\n  "participants": [\n    "Ana",\n    "Cathe...
# 4   {\n  "participants": [\n    "Joyce",\n    "Mic...
# 5   {\n  "participants": [\n    "Jane",\n    "Stev...
# 6   {\n  "participants": [\n    "Fiona",\n    "Tin...
# 7   {\n  "participants": [\n    "Olafur",\n    "Na...
# 8   {\n  "participants": [\n    "John",\n    "Joan...
# 9   {\n  "participants": [\n    "Peyton",\n    "Ca...
# 10  {\n  "participants": [\n    "Paul",\n    "Emma...
# 11  {\n  "participants": [\n    "Harris",\n    "Le...
# 12  {\n  "participants": [\n    "Yaz",\n    "Mary"...
# 13  {\n  "participants": [\n    "Ellie",\n    "Aal...
# 14  {\n  "participants": [\n    "Nathan",\n    "Aa...
# 15  {\n  "participants": [\n    "Freddie",\n    "K...
# 16  {\n  "participants": [\n    "Jones",\n    "Ang...
# 17  {\n  "participants": [\n    "Casey",\n    "Ame...
# 18  {\n  "participants": [\n    "Sue",\n    "Steve...
# 19  {\n  "participants": [\n    "Timmy",\n    "Gem...
# 20  {\n  "participants": [\n    "Ann",\n    "Sue",...
# 21  {\n  "participants": [\n    "Steve",\n    "Mum...
# 22  {\n  "participants": [\n    "Marika",\n    "La...
# 23  {\n  "participants": [\n    "Miranda",\n    "S...
# 24  {\n  "participants": [\n    "Javier",\n    "Ju...
# 25  {\n  "participants": [\n    "Sam",\n    "Jessi...
# 26  {\n  "participants": [\n    "Terence",\n    "D...
# 27  {\n  "participants": [\n    "Natacha",\n    "C...
# 28  {\n  "participants": [\n    "Meg",\n    "Ann"\...
# 29  {\n  "participants": [\n    "Pete",\n    "Jen"...
# 30  {\n  "participants": [\n    "Christie",\n    "...
# 31  {\n  "participants": [\n    "Sam",\n    "Carla...
# 32  {\n  "participants": [\n    "Joana",\n    "San...
# 33  {\n  "participants": [\n    "Steve",\n    "Rob...
# 34  {\n  "participants": [\n    "Peter",\n    "Joy...
# 35  {\n  "participants": [\n    "Ethan",\n    "Noa...
# 36  {\n  "participants": [\n    "Bradley",\n    "J...
# 37  {\n  "participants": [\n    "Barbara",\n    "S...
# 38  {\n  "participants": [\n    "Jake",\n    "Tom"...
# 39  {\n  "participants": [\n    "Phil",\n    "Dean...
# 40  {\n  "participants": [\n    "Mell",\n    "Glor...
# 41  {\n  "participants": [\n    "Callan",\n    "Wa...
# 42  {\n  "participants": [\n    "Anna",\n    "Joan...
# 43  {\n  "participants": [\n    "Sam",\n    "Kate"...
# 44  {\n  "participants": [\n    "Mia",\n    "Jenni...
# 45  {\n  "participants": [\n    "Pedro",\n    "Ale...
# 46  {\n  "participants": [\n    "Damian",\n    "Et...
# 47  {\n  "participants": [\n    "Barry",\n    "Jak...
# 48  {\n  "participants": [\n    "Martha",\n    "Op...
# 49  {\n  "participants": [\n    "Linda",\n    "Mic...
#
#                        agent2_summary_generation_json  \
# 0   {\n  "selected_events": [\n    {\n      "event...
# 1   {\n  "selected_events": [\n    {\n      "event...
# 2   {\n  "selected_events": [\n    {\n      "event...
# 3   {\n  "selected_events": [\n    {\n      "event...
# 4   {\n  "selected_events": [\n    {\n      "event...
# 5   {\n  "selected_events": [\n    {\n      "event...
# 6   {\n  "selected_events": [\n    {\n      "event...
# 7   {\n  "selected_events": [\n    {\n      "event...
# 8   {\n  "selected_events": [\n    {\n      "event...
# 9   {\n  "selected_events": [\n    {\n      "event...
# 10  {\n  "selected_events": [\n    {\n      "event...
# 11  {\n  "selected_events": [\n    {\n      "event...
# 12  {\n  "selected_events": [\n    {\n      "event...
# 13  {\n  "selected_events": [\n    {\n      "event...
# 14  {\n  "selected_events": [\n    {\n      "event...
# 15  {\n  "selected_events": [\n    {\n      "event...
# 16  {\n  "selected_events": [\n    {\n      "event...
# 17  {\n  "selected_events": [\n    {\n      "event...
# 18  {\n  "selected_events": [\n    {\n      "event...
# 19  {\n  "selected_events": [\n    {\n      "event...
# 20  {\n  "selected_events": [\n    {\n      "event...
# 21  {\n  "selected_events": [\n    {\n      "event...
# 22  {\n  "selected_events": [\n    {\n      "event...
# 23  {\n  "selected_events": [\n    {\n      "event...
# 24  {\n  "selected_events": [\n    {\n      "event...
# 25  {\n  "selected_events": [\n    {\n      "event...
# 26  {\n  "selected_events": [\n    {\n      "event...
# 27  {\n  "selected_events": [\n    {\n      "event...
# 28  {\n  "selected_events": [\n    {\n      "event...
# 29  {\n  "selected_events": [\n    {\n      "event...
# 30  {\n  "selected_events": [\n    {\n      "event...
# 31  {\n  "selected_events": [\n    {\n      "event...
# 32  {\n  "selected_events": [\n    {\n      "event...
# 33  {\n  "selected_events": [\n    {\n      "event...
# 34  {\n  "selected_events": [\n    {\n      "event...
# 35  {\n  "selected_events": [\n    {\n      "event...
# 36  {\n  "selected_events": [\n    {\n      "event...
# 37  {\n  "selected_events": [\n    {\n      "event...
# 38  {\n  "selected_events": [\n    {\n      "event...
# 39  {\n  "selected_events": [\n    {\n      "event...
# 40  {\n  "selected_events": [\n    {\n      "event...
# 41  {\n  "selected_events": [\n    {\n      "event...
# 42  {\n  "selected_events": [\n    {\n      "event...
# 43  {\n  "selected_events": [\n    {\n      "event...
# 44  {\n  "selected_events": [\n    {\n      "event...
# 45  {\n  "selected_events": [\n    {\n      "event...
# 46  {\n  "selected_events": [\n    {\n      "event...
# 47  {\n  "selected_events": [\n    {\n      "event...
# 48  {\n  "selected_events": [\n    {\n      "event...
# 49  {\n  "selected_events": [\n    {\n      "event...
#
#                                  agent3_revision_json  \
# 0   {\n  "needs_revision": false,\n  "issues_ident...
# 1   {\n  "needs_revision": false,\n  "issues_ident...
# 2   {\n  "needs_revision": false,\n  "issues_ident...
# 3   {\n  "needs_revision": false,\n  "issues_ident...
# 4   {\n  "needs_revision": false,\n  "issues_ident...
# 5   {\n  "needs_revision": false,\n  "issues_ident...
# 6   {\n  "needs_revision": false,\n  "issues_ident...
# 7   {\n  "needs_revision": false,\n  "issues_ident...
# 8   {\n  "needs_revision": true,\n  "issues_identi...
# 9   {\n  "needs_revision": false,\n  "issues_ident...
# 10  {\n  "needs_revision": true,\n  "issues_identi...
# 11  {\n  "needs_revision": false,\n  "issues_ident...
# 12  {\n  "needs_revision": false,\n  "issues_ident...
# 13  {\n  "needs_revision": false,\n  "issues_ident...
# 14  {\n  "needs_revision": false,\n  "issues_ident...
# 15  {\n  "needs_revision": true,\n  "issues_identi...
# 16  {\n  "needs_revision": false,\n  "issues_ident...
# 17  {\n  "needs_revision": false,\n  "issues_ident...
# 18  {\n  "needs_revision": false,\n  "issues_ident...
# 19  {\n  "needs_revision": false,\n  "issues_ident...
# 20  {\n  "needs_revision": false,\n  "issues_ident...
# 21  {\n  "needs_revision": false,\n  "issues_ident...
# 22  {\n  "needs_revision": false,\n  "issues_ident...
# 23  {\n  "needs_revision": false,\n  "issues_ident...
# 24  {\n  "needs_revision": true,\n  "issues_identi...
# 25  {\n  "needs_revision": false,\n  "issues_ident...
# 26  {\n  "needs_revision": false,\n  "issues_ident...
# 27  {\n  "needs_revision": false,\n  "issues_ident...
# 28  {\n  "needs_revision": true,\n  "issues_identi...
# 29  {\n  "needs_revision": false,\n  "issues_ident...
# 30  {\n  "needs_revision": false,\n  "issues_ident...
# 31  {\n  "needs_revision": false,\n  "issues_ident...
# 32  {\n  "needs_revision": false,\n  "issues_ident...
# 33  {\n  "needs_revision": false,\n  "issues_ident...
# 34  {\n  "needs_revision": false,\n  "issues_ident...
# 35  {\n  "needs_revision": false,\n  "issues_ident...
# 36  {\n  "needs_revision": false,\n  "issues_ident...
# 37  {\n  "needs_revision": false,\n  "issues_ident...
# 38  {\n  "needs_revision": false,\n  "issues_ident...
# 39  {\n  "needs_revision": true,\n  "issues_identi...
# 40  {\n  "needs_revision": false,\n  "issues_ident...
# 41  {\n  "needs_revision": false,\n  "issues_ident...
# 42  {\n  "needs_revision": true,\n  "issues_identi...
# 43  {\n  "needs_revision": false,\n  "issues_ident...
# 44  {\n  "needs_revision": true,\n  "issues_identi...
# 45  {\n  "needs_revision": false,\n  "issues_ident...
# 46  {\n  "needs_revision": true,\n  "issues_identi...
# 47  {\n  "needs_revision": false,\n  "issues_ident...
# 48  {\n  "needs_revision": false,\n  "issues_ident...
# 49  {\n  "needs_revision": false,\n  "issues_ident...
#
#                          agent3_final_chinese_summary        pipeline  \
# 0           安妮揭露马克谎报年龄，尽管艾琳质疑此事的重要性，安妮仍坚持认为这种欺骗是严重问题。  semantic_agent
# 1                                玛丽向卡特借钱，卡特同意一小时后借给她。  semantic_agent
# 2               蒂娜因航班延误将乘晚班机回家，阿拉正前往重要会议，并答应告知蒂娜会议结果。  semantic_agent
# 3                    安娜提议明天去探望祖母，凯瑟琳同意并承诺早上醒来后给安娜打电话。  semantic_agent
# 4                       乔伊斯分享了一个优惠旅行链接，埃德森随即决定立即预订机票。  semantic_agent
# 5                    简提议将会议时间改为四点三十分，史蒂文同意，并确认在主入口见面。  semantic_agent
# 6                蒂娜同意帮菲奥娜为克里斯准备挞，并建议她在加蛋时持续搅拌，以免做成炒蛋。  semantic_agent
# 7          娜塔莉提议看歌剧被奥拉弗尔拒绝，最终三人决定前往苏豪区俱乐部庆祝，奥拉弗尔负责购票。  semantic_agent
# 8   琼因忙碌拒绝了周三的邀请，提议改到周四。约翰同意，两人定于周四晚八点看电影，由约翰负责发送地...  semantic_agent
# 9                   卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。  semantic_agent
# 10                         保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。  semantic_agent
# 11                      哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。  semantic_agent
# 12                      雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。  semantic_agent
# 13                    卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。  semantic_agent
# 14                         内森向亚伦发送了一段视频，并透露该视频最初由丹发送。  semantic_agent
# 15  弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。  semantic_agent
# 16                   琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。  semantic_agent
# 17  凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而...  semantic_agent
# 18                  苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。  semantic_agent
# 19           杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。  semantic_agent
# 20                           安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。  semantic_agent
# 21                     史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。  semantic_agent
# 22                          玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。  semantic_agent
# 23                      米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。  semantic_agent
# 24       朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。  semantic_agent
# 25                 迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。  semantic_agent
# 26        特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。  semantic_agent
# 27              娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。  semantic_agent
# 28                    安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。  semantic_agent
# 29                  珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。  semantic_agent
# 30                    克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。  semantic_agent
# 31           山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。  semantic_agent
# 32               乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。  semantic_agent
# 33           史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。  semantic_agent
# 34                       彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。  semantic_agent
# 35         伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。  semantic_agent
# 36        布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。  semantic_agent
# 37                          芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。  semantic_agent
# 38  杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更...  semantic_agent
# 39                   菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。  semantic_agent
# 40         梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。  semantic_agent
# 41        卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。  semantic_agent
# 42              安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。  semantic_agent
# 43                  凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。  semantic_agent
# 44              卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。  semantic_agent
# 45  亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强...  semantic_agent
# 46                      达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。  semantic_agent
# 47           巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。  semantic_agent
# 48         玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。  semantic_agent
# 49           琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。  semantic_agent
#
#    agent1_model agent2_model agent3_model  num_model_calls
# 0   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 1   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 2   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 3   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 4   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 5   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 6   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 7   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 8   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 9   qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 10  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 11  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 12  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 13  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 14  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 15  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 16  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 17  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 18  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 19  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 20  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 21  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 22  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 23  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 24  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 25  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 26  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 27  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 28  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 29  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 30  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 31  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 32  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 33  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 34  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 35  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 36  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 37  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 38  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 39  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 40  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 41  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 42  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 43  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 44  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 45  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 46  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 47  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 48  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3
# 49  qwen3.5:27b  qwen3.5:27b  qwen3.5:27b                3

# %%
# Cell 15: Compare semantic-agent outputs with references

comparison_columns = [
    "id",
    "test_index",
    "final_summary",
    "reference_chinese_summary",
]

comparison_df = df[comparison_columns].copy()

comparison_df
# Out:
#             id  test_index                                      final_summary  \
# 0   gold_00001          23          安妮揭露马克谎报年龄，尽管艾琳质疑此事的重要性，安妮仍坚持认为这种欺骗是严重问题。
# 1   gold_00002          30                               玛丽向卡特借钱，卡特同意一小时后借给她。
# 2   gold_00003          39              蒂娜因航班延误将乘晚班机回家，阿拉正前往重要会议，并答应告知蒂娜会议结果。
# 3   gold_00004          65                   安娜提议明天去探望祖母，凯瑟琳同意并承诺早上醒来后给安娜打电话。
# 4   gold_00005          66                      乔伊斯分享了一个优惠旅行链接，埃德森随即决定立即预订机票。
# 5   gold_00006          67                   简提议将会议时间改为四点三十分，史蒂文同意，并确认在主入口见面。
# 6   gold_00007          78               蒂娜同意帮菲奥娜为克里斯准备挞，并建议她在加蛋时持续搅拌，以免做成炒蛋。
# 7   gold_00008          86         娜塔莉提议看歌剧被奥拉弗尔拒绝，最终三人决定前往苏豪区俱乐部庆祝，奥拉弗尔负责购票。
# 8   gold_00009         120  琼因忙碌拒绝了周三的邀请，提议改到周四。约翰同意，两人定于周四晚八点看电影，由约翰负责发送地...
# 9   gold_00010         137                  卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。
# 10  gold_00011         139                         保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。
# 11  gold_00012         192                      哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。
# 12  gold_00013         210                      雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。
# 13  gold_00014         211                    卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。
# 14  gold_00015         212                         内森向亚伦发送了一段视频，并透露该视频最初由丹发送。
# 15  gold_00016         215  弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。
# 16  gold_00017         244                   琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。
# 17  gold_00018         285  凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而...
# 18  gold_00019         319                  苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。
# 19  gold_00020         346           杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。
# 20  gold_00021         355                           安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。
# 21  gold_00022         367                     史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。
# 22  gold_00023         393                          玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。
# 23  gold_00024         417                      米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。
# 24  gold_00025         432       朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。
# 25  gold_00026         433                 迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。
# 26  gold_00027         442        特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。
# 27  gold_00028         499              娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。
# 28  gold_00029         528                    安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。
# 29  gold_00030         532                  珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。
# 30  gold_00031         536                    克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。
# 31  gold_00032         537           山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。
# 32  gold_00033         544               乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。
# 33  gold_00034         548           史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。
# 34  gold_00035         551                       彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。
# 35  gold_00036         590         伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。
# 36  gold_00037         598        布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。
# 37  gold_00038         605                          芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。
# 38  gold_00039         616  杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更...
# 39  gold_00040         621                   菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。
# 40  gold_00041         635         梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。
# 41  gold_00042         649        卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。
# 42  gold_00043         676              安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。
# 43  gold_00044         678                  凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。
# 44  gold_00045         690              卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。
# 45  gold_00046         711  亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强...
# 46  gold_00047         737                      达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。
# 47  gold_00048         767           巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。
# 48  gold_00049         799         玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。
# 49  gold_00050         800           琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。

# %%
# Cell 16: Inspect semantic-agent intermediate outputs and final output

if not df.empty:
    inspection_columns = [
        "id",
        "test_index",
        "dialogue",
        "agent1_semantic_representation_json",
        "agent2_summary_generation_json",
        "agent3_revision_json",
        "final_summary",
        "reference_english_summary",
        "reference_chinese_summary",
    ]

    inspection_df = df[inspection_columns].copy()
    display(inspection_df)
else:
    print("No results found.")
# Out:
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                   agent1_semantic_representation_json  \
# 0   {\n  "participants": [\n    "Anne",\n    "Iren...
# 1   {\n  "participants": [\n    "Mary",\n    "Cart...
# 2   {\n  "participants": [\n    "Tina",\n    "Ala"...
# 3   {\n  "participants": [\n    "Ana",\n    "Cathe...
# 4   {\n  "participants": [\n    "Joyce",\n    "Mic...
# 5   {\n  "participants": [\n    "Jane",\n    "Stev...
# 6   {\n  "participants": [\n    "Fiona",\n    "Tin...
# 7   {\n  "participants": [\n    "Olafur",\n    "Na...
# 8   {\n  "participants": [\n    "John",\n    "Joan...
# 9   {\n  "participants": [\n    "Peyton",\n    "Ca...
# 10  {\n  "participants": [\n    "Paul",\n    "Emma...
# 11  {\n  "participants": [\n    "Harris",\n    "Le...
# 12  {\n  "participants": [\n    "Yaz",\n    "Mary"...
# 13  {\n  "participants": [\n    "Ellie",\n    "Aal...
# 14  {\n  "participants": [\n    "Nathan",\n    "Aa...
# 15  {\n  "participants": [\n    "Freddie",\n    "K...
# 16  {\n  "participants": [\n    "Jones",\n    "Ang...
# 17  {\n  "participants": [\n    "Casey",\n    "Ame...
# 18  {\n  "participants": [\n    "Sue",\n    "Steve...
# 19  {\n  "participants": [\n    "Timmy",\n    "Gem...
# 20  {\n  "participants": [\n    "Ann",\n    "Sue",...
# 21  {\n  "participants": [\n    "Steve",\n    "Mum...
# 22  {\n  "participants": [\n    "Marika",\n    "La...
# 23  {\n  "participants": [\n    "Miranda",\n    "S...
# 24  {\n  "participants": [\n    "Javier",\n    "Ju...
# 25  {\n  "participants": [\n    "Sam",\n    "Jessi...
# 26  {\n  "participants": [\n    "Terence",\n    "D...
# 27  {\n  "participants": [\n    "Natacha",\n    "C...
# 28  {\n  "participants": [\n    "Meg",\n    "Ann"\...
# 29  {\n  "participants": [\n    "Pete",\n    "Jen"...
# 30  {\n  "participants": [\n    "Christie",\n    "...
# 31  {\n  "participants": [\n    "Sam",\n    "Carla...
# 32  {\n  "participants": [\n    "Joana",\n    "San...
# 33  {\n  "participants": [\n    "Steve",\n    "Rob...
# 34  {\n  "participants": [\n    "Peter",\n    "Joy...
# 35  {\n  "participants": [\n    "Ethan",\n    "Noa...
# 36  {\n  "participants": [\n    "Bradley",\n    "J...
# 37  {\n  "participants": [\n    "Barbara",\n    "S...
# 38  {\n  "participants": [\n    "Jake",\n    "Tom"...
# 39  {\n  "participants": [\n    "Phil",\n    "Dean...
# 40  {\n  "participants": [\n    "Mell",\n    "Glor...
# 41  {\n  "participants": [\n    "Callan",\n    "Wa...
# 42  {\n  "participants": [\n    "Anna",\n    "Joan...
# 43  {\n  "participants": [\n    "Sam",\n    "Kate"...
# 44  {\n  "participants": [\n    "Mia",\n    "Jenni...
# 45  {\n  "participants": [\n    "Pedro",\n    "Ale...
# 46  {\n  "participants": [\n    "Damian",\n    "Et...
# 47  {\n  "participants": [\n    "Barry",\n    "Jak...
# 48  {\n  "participants": [\n    "Martha",\n    "Op...
# 49  {\n  "participants": [\n    "Linda",\n    "Mic...
#
#                        agent2_summary_generation_json  \
# 0   {\n  "selected_events": [\n    {\n      "event...
# 1   {\n  "selected_events": [\n    {\n      "event...
# 2   {\n  "selected_events": [\n    {\n      "event...
# 3   {\n  "selected_events": [\n    {\n      "event...
# 4   {\n  "selected_events": [\n    {\n      "event...
# 5   {\n  "selected_events": [\n    {\n      "event...
# 6   {\n  "selected_events": [\n    {\n      "event...
# 7   {\n  "selected_events": [\n    {\n      "event...
# 8   {\n  "selected_events": [\n    {\n      "event...
# 9   {\n  "selected_events": [\n    {\n      "event...
# 10  {\n  "selected_events": [\n    {\n      "event...
# 11  {\n  "selected_events": [\n    {\n      "event...
# 12  {\n  "selected_events": [\n    {\n      "event...
# 13  {\n  "selected_events": [\n    {\n      "event...
# 14  {\n  "selected_events": [\n    {\n      "event...
# 15  {\n  "selected_events": [\n    {\n      "event...
# 16  {\n  "selected_events": [\n    {\n      "event...
# 17  {\n  "selected_events": [\n    {\n      "event...
# 18  {\n  "selected_events": [\n    {\n      "event...
# 19  {\n  "selected_events": [\n    {\n      "event...
# 20  {\n  "selected_events": [\n    {\n      "event...
# 21  {\n  "selected_events": [\n    {\n      "event...
# 22  {\n  "selected_events": [\n    {\n      "event...
# 23  {\n  "selected_events": [\n    {\n      "event...
# 24  {\n  "selected_events": [\n    {\n      "event...
# 25  {\n  "selected_events": [\n    {\n      "event...
# 26  {\n  "selected_events": [\n    {\n      "event...
# 27  {\n  "selected_events": [\n    {\n      "event...
# 28  {\n  "selected_events": [\n    {\n      "event...
# 29  {\n  "selected_events": [\n    {\n      "event...
# 30  {\n  "selected_events": [\n    {\n      "event...
# 31  {\n  "selected_events": [\n    {\n      "event...
# 32  {\n  "selected_events": [\n    {\n      "event...
# 33  {\n  "selected_events": [\n    {\n      "event...
# 34  {\n  "selected_events": [\n    {\n      "event...
# 35  {\n  "selected_events": [\n    {\n      "event...
# 36  {\n  "selected_events": [\n    {\n      "event...
# 37  {\n  "selected_events": [\n    {\n      "event...
# 38  {\n  "selected_events": [\n    {\n      "event...
# 39  {\n  "selected_events": [\n    {\n      "event...
# 40  {\n  "selected_events": [\n    {\n      "event...
# 41  {\n  "selected_events": [\n    {\n      "event...
# 42  {\n  "selected_events": [\n    {\n      "event...
# 43  {\n  "selected_events": [\n    {\n      "event...
# 44  {\n  "selected_events": [\n    {\n      "event...
# 45  {\n  "selected_events": [\n    {\n      "event...
# 46  {\n  "selected_events": [\n    {\n      "event...
# 47  {\n  "selected_events": [\n    {\n      "event...
# 48  {\n  "selected_events": [\n    {\n      "event...
# 49  {\n  "selected_events": [\n    {\n      "event...
#
#                                  agent3_revision_json  \
# 0   {\n  "needs_revision": false,\n  "issues_ident...
# 1   {\n  "needs_revision": false,\n  "issues_ident...
# 2   {\n  "needs_revision": false,\n  "issues_ident...
# 3   {\n  "needs_revision": false,\n  "issues_ident...
# 4   {\n  "needs_revision": false,\n  "issues_ident...
# 5   {\n  "needs_revision": false,\n  "issues_ident...
# 6   {\n  "needs_revision": false,\n  "issues_ident...
# 7   {\n  "needs_revision": false,\n  "issues_ident...
# 8   {\n  "needs_revision": true,\n  "issues_identi...
# 9   {\n  "needs_revision": false,\n  "issues_ident...
# 10  {\n  "needs_revision": true,\n  "issues_identi...
# 11  {\n  "needs_revision": false,\n  "issues_ident...
# 12  {\n  "needs_revision": false,\n  "issues_ident...
# 13  {\n  "needs_revision": false,\n  "issues_ident...
# 14  {\n  "needs_revision": false,\n  "issues_ident...
# 15  {\n  "needs_revision": true,\n  "issues_identi...
# 16  {\n  "needs_revision": false,\n  "issues_ident...
# 17  {\n  "needs_revision": false,\n  "issues_ident...
# 18  {\n  "needs_revision": false,\n  "issues_ident...
# 19  {\n  "needs_revision": false,\n  "issues_ident...
# 20  {\n  "needs_revision": false,\n  "issues_ident...
# 21  {\n  "needs_revision": false,\n  "issues_ident...
# 22  {\n  "needs_revision": false,\n  "issues_ident...
# 23  {\n  "needs_revision": false,\n  "issues_ident...
# 24  {\n  "needs_revision": true,\n  "issues_identi...
# 25  {\n  "needs_revision": false,\n  "issues_ident...
# 26  {\n  "needs_revision": false,\n  "issues_ident...
# 27  {\n  "needs_revision": false,\n  "issues_ident...
# 28  {\n  "needs_revision": true,\n  "issues_identi...
# 29  {\n  "needs_revision": false,\n  "issues_ident...
# 30  {\n  "needs_revision": false,\n  "issues_ident...
# 31  {\n  "needs_revision": false,\n  "issues_ident...
# 32  {\n  "needs_revision": false,\n  "issues_ident...
# 33  {\n  "needs_revision": false,\n  "issues_ident...
# 34  {\n  "needs_revision": false,\n  "issues_ident...
# 35  {\n  "needs_revision": false,\n  "issues_ident...
# 36  {\n  "needs_revision": false,\n  "issues_ident...
# 37  {\n  "needs_revision": false,\n  "issues_ident...
# 38  {\n  "needs_revision": false,\n  "issues_ident...
# 39  {\n  "needs_revision": true,\n  "issues_identi...
# 40  {\n  "needs_revision": false,\n  "issues_ident...
# 41  {\n  "needs_revision": false,\n  "issues_ident...
# 42  {\n  "needs_revision": true,\n  "issues_identi...
# 43  {\n  "needs_revision": false,\n  "issues_ident...
# 44  {\n  "needs_revision": true,\n  "issues_identi...
# 45  {\n  "needs_revision": false,\n  "issues_ident...
# 46  {\n  "needs_revision": true,\n  "issues_identi...
# 47  {\n  "needs_revision": false,\n  "issues_ident...
# 48  {\n  "needs_revision": false,\n  "issues_ident...
# 49  {\n  "needs_revision": false,\n  "issues_ident...
#
#                                         final_summary  \
# 0           安妮揭露马克谎报年龄，尽管艾琳质疑此事的重要性，安妮仍坚持认为这种欺骗是严重问题。
# 1                                玛丽向卡特借钱，卡特同意一小时后借给她。
# 2               蒂娜因航班延误将乘晚班机回家，阿拉正前往重要会议，并答应告知蒂娜会议结果。
# 3                    安娜提议明天去探望祖母，凯瑟琳同意并承诺早上醒来后给安娜打电话。
# 4                       乔伊斯分享了一个优惠旅行链接，埃德森随即决定立即预订机票。
# 5                    简提议将会议时间改为四点三十分，史蒂文同意，并确认在主入口见面。
# 6                蒂娜同意帮菲奥娜为克里斯准备挞，并建议她在加蛋时持续搅拌，以免做成炒蛋。
# 7          娜塔莉提议看歌剧被奥拉弗尔拒绝，最终三人决定前往苏豪区俱乐部庆祝，奥拉弗尔负责购票。
# 8   琼因忙碌拒绝了周三的邀请，提议改到周四。约翰同意，两人定于周四晚八点看电影，由约翰负责发送地...
# 9                   卡梅伦因在外地无法亲自带回游戏，佩顿坚持要求其安排快递并立即回家。
# 10                         保罗将重新预约理疗，并同意为深夜回家的艾玛准备食物。
# 11                      哈里斯告知莱娜其朋友阿基已去世，随后因母亲呼唤而结束对话。
# 12                      雅兹提议六点左右接玛丽一起去减肥俱乐部，玛丽同意了该计划。
# 13                    卡米尔告知大家她生病了，阿莉娅随后通知课程地点在二楼342室。
# 14                         内森向亚伦发送了一段视频，并透露该视频最初由丹发送。
# 15  弗雷迪向凯莉推荐《古战场传奇》或《都铎王朝》，凯莉称其糟糕。鲍勃建议吉姆看《格林》或《萨布丽娜》。
# 16                   琼斯提议下午在镇上见面，安吉丽娜同意，琼斯承诺致电确认具体地点。
# 17  凯西表示给自己涂指甲耗时四小时。阿米莉亚和克里斯汀请求凯西帮她们涂指甲，但凯西因过程太繁琐而...
# 18                  苏要求史蒂夫收到消息后立即给她打电话，史蒂夫确认并立即拨通了电话。
# 19           杰玛建议邀请洛娜和米歇尔，并承认想参加她们的婚礼，但不确定能否说服对方邀请自己。
# 20                           安提议今晚举行庆祝活动，苏和朱莉均表示同意参加。
# 21                     史蒂夫确认十二人份洗碗机已安装完毕，并计划每隔一天使用一次。
# 22                          玛丽卡询问劳拉是否参加今天的活动，劳拉确认会出席。
# 23                      米兰达因工作原因请求取消明天的会议，斯特凡妮对此表示质疑。
# 24       朱迪向哈维尔推荐华沙纹身店并告知价格昂贵，哈维尔因此决定放弃本地纹身，改在哥伦比亚进行。
# 25                 迈克尔确认了酒店预订，并与萨姆确认其将于8月15日下午2点抵达酒店。
# 26        特伦斯指控丹尼尔偷钱，丹尼尔予以否认。特伦斯找到钱后撤回指控，但丹尼尔仍对此感到愤怒。
# 27              娜塔莎同意在韦西内站接查尔斯，预计时间为下午五点半，查尔斯承诺到达时致电。
# 28                    安因有额外的数学课无法立即见面，但承诺晚上七点在家与梅格会面。
# 29                  珍妮要求皮特仅在有梨味酸奶时购买，若缺货则什么都不买，皮特已同意。
# 30                    克里斯蒂和凯蒂在派对后都感到疲惫，但两人一致认为派对非常愉快。
# 31           山姆提议明天下午见面，卡拉确认在米恩伍德的咖啡馆两点碰头，山姆最终同意了该计划。
# 32               乔安娜提议玩迪克斯特或卡卡颂，桑迪表示同意，乔安娜承诺将游戏带到桑迪处。
# 33           史蒂夫购买了新的梦剧院专辑，罗伯已拥有该专辑并准备聆听，史蒂夫承诺稍后分享看法。
# 34                       彼得请求乔伊提供美容店链接，乔伊成功发送，彼得同意查看。
# 35         伊森询问索尔斯塔菲尔演唱会出席情况，利奥确认参加，诺亚因工作冲突暂不确定，稍后通知。
# 36        布拉德利告知吉尔和朱莉娅古迪逊球场出现猫，吉尔分享了视频，布拉德利随后补充了解说音频。
# 37                          芭芭拉邀请肖恩来家做客，允许他带狗，肖恩同意留宿。
# 38  杰克获得了一名周最佳球员，但因不适合球队，他决定在试用几场比赛后将其出售，并用所得资金购买更...
# 39                   菲尔确认太阳镜不属于凯瑟琳或阿德里安后，黛娜提议保管，菲尔同意。
# 40         梅尔和格洛里亚商定本周六在梅尔家举办烧烤，梅尔负责准备食物，格洛里亚负责饮料和甜点。
# 41        卡兰的三星S8因过热出现黑屏，韦德警告电池危险后，卡兰决定将手机送往商店进行保修维修。
# 42              安娜胃痛，提议若未好转则看医生，乔安娜同意。随后乔安娜为安娜准备了薄荷茶。
# 43                  凯特描述了楼梯下小房间里一个带有露骨图案的蛋糕，山姆决定前去观看。
# 44              卡琳和彼得确认该人物是危险的战略威胁，米娅承诺将不惜一切代价赢得下次选举。
# 45  亚历克斯表示更喜欢闪电侠，并解释其超光速能穿越多元宇宙。佩德罗最终接受了亚历克斯关于闪电侠强...
# 46                      达米安请求伊森买烤肉串，伊森虽抱怨其依赖，最终仍答应购买。
# 47           巴里邀请杰克和戴夫参加女性罢工游行，两人均同意参加。最终大家商定中午在校园集合。
# 48         玛莎向奥菲莉亚询问隐形眼镜品牌，奥菲莉亚推荐了疯狂隐形眼镜，玛莎随后决定查看该品牌。
# 49           琳达向父亲迈克尔请教为母亲选花，迈克尔推荐了母亲最爱的小苍兰，琳达最终决定购买。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
