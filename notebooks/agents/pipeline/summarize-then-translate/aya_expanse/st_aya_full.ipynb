# %% [markdown]
# # Summarize-then-Translate Pipeline for English-to-Chinese Dialogue Summarization
#
# This notebook implements a local Summarize-then-Translate baseline for English-to-Chinese cross-lingual dialogue summarization.
#
# The ST pipeline uses two local small language model agents. Agent 1 reads the original English dialogue and generates a concise English summary. Agent 2 then translates the English summary into Chinese. The final output is a concise Chinese summary.
#
# ```text
# English Dialogue
# → Agent 1: English Summarization Agent
# → Agent 2: Chinese Translation Agent
# → Final Chinese Summary
# ```
#
# The pipeline consists of two agents:
#
# ```text
# Agent 1: English Summarization Agent
# Input: original English dialogue
# Output: concise English summary
#
# Agent 2: Chinese Translation Agent
# Input: English summary from Agent 1
# Output: final Chinese summary
# ```
# This setup is used as a Summarize-then-Translate baseline. Unlike the Direct pipeline, ST explicitly creates an intermediate English summary before producing the Chinese summary. This allows us to inspect whether errors come from the summarization stage or the translation stage.
#
# The local small language model is served through Ollama. The notebook controls the prompt design, agent workflow, input/output processing, intermediate output inspection, and result saving.

# %% [markdown]
# ## 0. Local Ollama Setup
#
# Before running this notebook, install Ollama and download the local model used for the Summarize-then-Translate baseline.
#
# ### Recommended model setup
#
# This notebook uses one local small language model through Ollama for both agents:
#
# - Agent 1: English Summarization Agent
# - Agent 2: Chinese Translation Agent
#
# ```bash
# ollama pull aya-expanse:32b
# ```
#
# If qwen3.5:27b is too slow on your machine, you can use a smaller model for testing:
#
# ```bash
# ollama pull "aya-expanse:32b"
# ```
#
# Make sure the model names in the notebook match the models installed in Ollama:
#
# ```bash
# SUMMARIZATION_MODEL = "aya-expanse:32b"
# TRANSLATION_MODEL = "aya-expanse:32b"
# ```
#
# You can check downloaded models with:
#
# ```bash
# ollama list
# ```
#
# You can check currently loaded models with:
#
# ```bash
# ollama ps
# ```
#
# If the Ollama server is not running, start it with:
#
# ```bash
# ollama serve
# ```
#
# On macOS, opening the Ollama app usually starts the local server automatically.

# %%
# Cell 1: Install required Python packages.
# Run this only once if the packages are not installed

# !pip install requests pandas tqdm
# Out:
# Requirement already satisfied: requests in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.33.1)
# Requirement already satisfied: pandas in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: colorama in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Cell 2: Imports and global configuration

import json
import time
from pathlib import Path
from typing import Any, Dict, List, Optional

import requests
import pandas as pd
from tqdm.auto import tqdm

OLLAMA_HOST = "http://localhost:11434"

# ST models
SUMMARIZATION_MODEL = "aya-expanse:32b"
TRANSLATION_MODEL = "aya-expanse:32b"

DEFAULT_TEMPERATURE = 0.2
DEFAULT_NUM_CTX = 8192

# window project path
PROJECT_ROOT = Path(
    r"C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu"
)

# Gold set path
GOLD_SET_PATH = PROJECT_ROOT / "gold_set_50_zh_XSAMSum_bart.json"

# Output directory
OUTPUT_DIR = PROJECT_ROOT
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Output files for ST baseline
FULL_OUTPUT_PATH = OUTPUT_DIR / "st_aya32b_50samples.jsonl"
FINAL_CSV_PATH = OUTPUT_DIR / "st_aya32b_50samples.csv"
ERROR_OUTPUT_PATH = OUTPUT_DIR / "st_aya32b_50samples_errors.jsonl"

print("Gold set path:", GOLD_SET_PATH)
print("Output directory:", OUTPUT_DIR)
print("Full JSONL output path:", FULL_OUTPUT_PATH)
print("Final CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Gold set path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\gold_set_50_zh_XSAMSum_bart.json
# Output directory: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu
# Full JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.jsonl
# Final CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples_errors.jsonl

# %%
print(GOLD_SET_PATH.exists())
# Out:
# True

# %%
# Cell 3: Check whether Ollama is running

def check_ollama_server() -> bool:
    try:
        response = requests.get(f"{OLLAMA_HOST}/api/tags", timeout=10)
        response.raise_for_status()
        models = response.json().get("models", [])

        print("Ollama server is running.")
        print(f"Downloaded models: {[m.get('name') for m in models]}")

        return True

    except Exception as e:
        print("Could not connect to Ollama.")
        print("Make sure Ollama is installed and running.")
        print("Try running this in Terminal:")
        print("  ollama serve")
        print()
        print("Error:", repr(e))

        return False


_ = check_ollama_server()
# Out:
# Ollama server is running.
# Downloaded models: ['aya-expanse:32b', 'gemma3:27b', 'qwen3.5:27b']

# %%
# Cell 4: Ollama API helper

def call_ollama(
    model: str,
    prompt: str,
    system: Optional[str] = None,
    temperature: float = DEFAULT_TEMPERATURE,
    num_ctx: int = DEFAULT_NUM_CTX,
    timeout: int = 900,
) -> str:
    """Call Ollama's local chat API and return the assistant content."""

    messages = []

    if system:
        messages.append({"role": "system", "content": system})

    messages.append({"role": "user", "content": prompt})

    payload = {
        "model": model,
        "messages": messages,
        "stream": False,
        "options": {
            "temperature": temperature,
            "num_ctx": num_ctx,
            "num_predict": 1024,
        },
        "think": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=timeout,
    )
    response.raise_for_status()

    data = response.json()
    content = data.get("message", {}).get("content", "")

    if content is None:
        content = ""

    return content.strip()

# %% [markdown]
# ## 1. Prompt Templates
#
# Each agent is defined as:
#
# ```text
# Agent = model + role-specific prompt + input/output format
# ```
#
# In the first version, we use a fixed workflow rather than a fully autonomous agent system.

# %%
# Cell 5: ST prompt templates

ENGLISH_SUMMARIZATION_PROMPT = """You are an English dialogue summarization agent.

Your task is to read the following English dialogue and generate a concise English summary.

Requirements:
- Summarize the main information in the dialogue.
- Write the summary in English.
- Keep the summary concise and faithful to the dialogue.
- Do not translate into Chinese.
- Do not add information that is not stated or clearly implied.
- Do not explain your reasoning.
- Output only the English summary.

Conciseness: 
- For simple dialogues, write one short English sentence.
- For complex dialogues, write at most two short English sentences.

English dialogue:
{dialogue}

English summary:
"""


CHINESE_TRANSLATION_PROMPT = """You are a Chinese translation agent.

Your task is to translate the English summary into Chinese.

Requirements:
- Translate the English summary into natural Chinese.
- Preserve the meaning of the English summary.
- Do not add new information.
- Do not remove important information.
- Do not explain your reasoning.
- Output only the final Chinese summary.
- Translate all English proper nouns, including speaker names, into standard Chinese transliteration.

STRICT TRANSLATION RULE:
- You MUST translate ALL English proper nouns and speaker names into standard Chinese characters.
- ABSOLUTELY NO English letters or names should appear in the final Chinese summary.

English summary:
{english_summary}

Chinese summary:
"""

# %%
# Cell 6: JSONL utility functions

def append_jsonl(record: Dict[str, Any], path: Path) -> None:
    """Append one record to a JSONL file."""
    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")


def load_jsonl(path: Path) -> List[Dict[str, Any]]:
    """Load a JSONL file into a list of dictionaries."""
    if not path.exists():
        return []

    records = []

    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if line:
                records.append(json.loads(line))

    return records


def load_processed_ids(path: Path) -> set:
    """Return IDs that have already been processed."""
    records = load_jsonl(path)

    return {str(record["id"]) for record in records if "id" in record}

# %%
# Cell 7: ST agent functions

def fill_prompt(template: str, replacements: Dict[str, str]) -> str:
    """Replace named placeholders in the prompt."""
    prompt = template

    for key, value in replacements.items():
        prompt = prompt.replace("{" + key + "}", value)

    return prompt


def english_summarization_agent(dialogue: str) -> str:
    """Agent 1: English dialogue -> English summary."""
    prompt = fill_prompt(
        ENGLISH_SUMMARIZATION_PROMPT,
        {
            "dialogue": dialogue,
        },
    )

    response = call_ollama(
        model=SUMMARIZATION_MODEL,
        prompt=prompt,
        temperature=0.2,
    )

    return response.strip()


def chinese_translation_agent(english_summary: str) -> str:
    """Agent 2: English summary -> Chinese summary."""
    prompt = fill_prompt(
        CHINESE_TRANSLATION_PROMPT,
        {
            "english_summary": english_summary,
        },
    )

    response = call_ollama(
        model=TRANSLATION_MODEL,
        prompt=prompt,
        temperature=0.2,
    )

    return response.strip()

# %% [markdown]
# ## 2. Agent Functions
#
# Each function corresponds to one agent in the pipeline.

# %%
# Cell 8: ST pipeline

def run_st_pipeline(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run the Summarize-then-Translate pipeline."""

    sample_id = str(example.get("id", "unknown"))
    dialogue = example["dialogue"]

    reference_english_summary = example.get("reference_english_summary", "")
    reference_chinese_summary = example.get("reference_chinese_summary", "")

    # Agent 1: English dialogue -> English summary
    english_summary = english_summarization_agent(dialogue)

    if verbose:
        print("\n" + "=" * 80)
        print(f"Sample ID: {sample_id}")
        print("=== Agent 1 Output: English Summary ===")
        print(english_summary)
        print("=" * 80 + "\n")

    # Agent 2: English summary -> Chinese summary
    final_chinese_summary = chinese_translation_agent(english_summary)

    if verbose:
        print("=== Agent 2 Output: Chinese Summary ===")
        print(final_chinese_summary)
        print("=" * 80 + "\n")

    return {
        "id": sample_id,
        "test_index": example.get("test_index", ""),
        "dialogue": dialogue,

        # Intermediate output from Agent 1
        "english_summary": english_summary,

        # Final output from Agent 2
        "final_summary": final_chinese_summary,

        # References
        "reference_english_summary": reference_english_summary,
        "reference_chinese_summary": reference_chinese_summary,

        # Metadata
        "pipeline": "summarize_then_translate",
        "summarization_model": SUMMARIZATION_MODEL,
        "translation_model": TRANSLATION_MODEL,
        "num_model_calls": 2,
    }

# %% [markdown]
# ## 3. Test with Examples
#
# Start with five examples before running the full dataset.
# This is the best way to inspect whether errors come from the English summarization stage or the Chinese translation stage.

# %%
# Cell 9: Load first 5 examples from the gold set

def load_examples_from_gold_set(path: Path, n: int = 5) -> List[Dict[str, Any]]:
    """Load the first n examples from the gold-set JSON file."""
    if not path.exists():
        raise FileNotFoundError(f"Gold set not found: {path}")

    with path.open("r", encoding="utf-8") as f:
        raw_data = json.load(f)

    examples = []

    for i, item in enumerate(raw_data[:n]):
        examples.append({
            "id": f"gold_{i+1:05d}",
            "test_index": item.get("test_index", ""),
            "dialogue": item["dialogue"],
            "reference_english_summary": item.get("summary", ""),
            "reference_chinese_summary": item.get("summary_zh", ""),
        })

    return examples


test_data = load_examples_from_gold_set(GOLD_SET_PATH, n=50)

print(f"Loaded {len(test_data)} examples.")
print("First example:")
print(test_data[0])
# Out:
# Loaded 50 examples.
# First example:
# {'id': 'gold_00001', 'test_index': 23, 'dialogue': "Anne: You were right, he was lying to me :/\nIrene: Oh no, what happened?\nJane: who? that Mark guy?\nAnne: yeah, he told me he's 30, today I saw his passport - he's 40\nIrene: You sure it's so important?\nAnne: he lied to me Irene", 'reference_english_summary': 'Mark lied to Anne about his age. Mark is 40.', 'reference_chinese_summary': '马克向安妮隐瞒了自己的年龄。他40岁了。'}

# %%
# Cell 10: Run the ST pipeline for the first example

result = run_st_pipeline(test_data[4], verbose=True)
result
# Out:
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Output: English Summary ===
# Joyce shares a link to cheap tickets; Michael expresses surprise, while Edson immediately books one.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 乔伊斯分享了一个廉价机票的链接；迈克尔表示惊讶，而埃德森立即预订了一张。
# ================================================================================
# {'id': 'gold_00005',
#  'test_index': 66,
#  'dialogue': "Joyce: Check this out!\r\nJoyce: <link>\r\nMichael: That's cheap!\r\nEdson: No way! I'm booking my ticket now!! ",
#  'english_summary': 'Joyce shares a link to cheap tickets; Michael expresses surprise, while Edson immediately books one.',
#  'final_summary': '乔伊斯分享了一个廉价机票的链接；迈克尔表示惊讶，而埃德森立即预订了一张。',
#  'reference_english_summary': 'Edson is booking his ticket now.',
#  'reference_chinese_summary': '埃德森正在订票。',
#  'pipeline': 'summarize_then_translate',
#  'summarization_model': 'aya-expanse:32b',
#  'translation_model': 'aya-expanse:32b',
#  'num_model_calls': 2}

# %%
# Cell 11: Print ST pipeline result clearly

def print_st_result(result: Dict[str, Any]) -> None:
    print("=== Original Dialogue ===")
    print(result["dialogue"])
    print()

    print("=== Agent 1 Intermediate Output: English Summary ===")
    print(result["english_summary"])
    print()

    print("=== Agent 2 Final Output: Chinese Summary ===")
    print(result["final_summary"])
    print()

    print("=== Reference English Summary ===")
    print(result["reference_english_summary"])
    print()

    print("=== Reference Chinese Summary ===")
    print(result["reference_chinese_summary"])
    print()

    print("=== Metadata ===")
    print("Pipeline:", result["pipeline"])
    print("Summarization model:", result["summarization_model"])
    print("Translation model:", result["translation_model"])
    print("Model calls:", result["num_model_calls"])


print_st_result(result)
# Out:
# === Original Dialogue ===
# Joyce: Check this out!
# Joyce: <link>
# Michael: That's cheap!
# Edson: No way! I'm booking my ticket now!!
#
# === Agent 1 Intermediate Output: English Summary ===
# Joyce shares a link to cheap tickets; Michael expresses surprise, while Edson immediately books one.
#
# === Agent 2 Final Output: Chinese Summary ===
# 乔伊斯分享了一个廉价机票的链接；迈克尔表示惊讶，而埃德森立即预订了一张。
#
# === Reference English Summary ===
# Edson is booking his ticket now.
#
# === Reference Chinese Summary ===
# 埃德森正在订票。
#
# === Metadata ===
# Pipeline: summarize_then_translate
# Summarization model: aya-expanse:32b
# Translation model: aya-expanse:32b
# Model calls: 2

# %% [markdown]
# ## 4. Save Results
#
# This saves the intermediate English summary and the final Chinese summary.

# %%
# Cell 12: Reset previous outputs before batch inference

FULL_OUTPUT_PATH.unlink(missing_ok=True)
FINAL_CSV_PATH.unlink(missing_ok=True)
ERROR_OUTPUT_PATH.unlink(missing_ok=True)

print("Previous output files reset.")
print("JSONL output path:", FULL_OUTPUT_PATH)
print("CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Previous output files reset.
# JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.jsonl
# CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples_errors.jsonl

# %% [markdown]
# ## 5. Batch Inference with Checkpointing
#
# This cell processes examples one by one and appends each completed ST result to the JSONL output file.
#
# If the notebook stops, already processed examples remain saved.

# %%
# Cell 13: Batch inference with ST pipeline
# Time stamp: 1m 29.8s

MAX_EXAMPLES = 50
SLEEP_SECONDS = 0.2

processed_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed: {len(processed_ids)} examples")

subset = test_data[:MAX_EXAMPLES]

for ex in tqdm(subset, desc="Running ST pipeline"):
    sample_id = str(ex.get("id", "unknown"))

    if sample_id in processed_ids:
        print(f"Skipping already processed sample: {sample_id}")
        continue

    try:
        record = run_st_pipeline(ex, verbose=True)

        append_jsonl(record, FULL_OUTPUT_PATH)
        processed_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "id": sample_id,
            "test_index": ex.get("test_index", ""),
            "error": repr(e),
            "dialogue": ex.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error on {sample_id}: {repr(e)}")

print(f"Finished. Outputs saved to: {FULL_OUTPUT_PATH}")
# Out:
# Already processed: 0 examples
# Running ST pipeline:   0%|          | 0/50 [00:00<?, ?it/s]
# ================================================================================
# Sample ID: gold_00001
# === Agent 1 Output: English Summary ===
# Anne discovered that Mark, whom she thought was 30, is actually 40, revealing a lie that upsets her. Irene tries to downplay the significance of the age difference.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 安妮发现她以为三十岁的马克实际上已经四十岁了，这让她很不高兴。艾琳试图淡化年龄差异的重要性。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00002
# === Agent 1 Output: English Summary ===
# Mary asks Carter for money, and Carter agrees to meet her in an hour at the train station.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 玛丽向卡特要钱，卡特同意一小时后在火车站见面。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00003
# === Agent 1 Output: English Summary ===
# Tina compliments the appearance of Emirates staff while expressing frustration about her delayed flight and talkative pilot. Ala sympathizes and mentions an upcoming important meeting, asking Tina to keep her updated.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 蒂娜（Tina）在表达对航班延误和健谈飞行员的沮丧的同时，也赞扬了阿联酋航空（Emirates）员工的外表。阿拉（Ala）表示同情，并提到即将召开的重要会议，请蒂娜随时向她通报情况。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00004
# === Agent 1 Output: English Summary ===
# Ana and Catherine plan to visit their grandmother tomorrow as Ana misses her. Catherine will call Ana when she wakes up.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 安娜和凯瑟琳计划明天去看望她们的祖母，因为安娜想念她。凯瑟琳会在醒来时给安娜打电话。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Output: English Summary ===
# Joyce shares a link to cheap tickets; Michael expresses surprise, while Edson immediately books one.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 乔伊斯分享了一个便宜门票的链接；迈克尔表达了惊讶，而埃德森立即预订了一个。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00006
# === Agent 1 Output: English Summary ===
# Jane and Steven agree to meet at 4:30 instead of 5 due to a potentially longer travel time, with Steven assuring Jane that the road is new and they should make it on time. They plan to meet at the main entrance.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 简（Jane）和史蒂文（Steven）因可能路程时间较长，同意将见面时间从五点改为四点半。史蒂文向简保证道路是新的，他们应该能准时到达。他们计划在正门见面。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00007
# === Agent 1 Output: English Summary ===
# Fiona asks Tina for help in preparing a tart for Chris. Tina agrees to help, but notes that Fiona should not overmix the filling or it will turn into scrambled eggs.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 菲奥娜（Fiona）请蒂娜（Tina）帮忙准备一个馅饼给克里斯（Chris）。蒂娜同意帮忙，但指出菲奥娜不要将馅料搅拌过度，否则会变成炒鸡蛋。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00008
# === Agent 1 Output: English Summary ===
# Olafur, Nathalie, and Zoe are planning a New Year's Eve party. They decide on a classy club event in Soho after considering opera and a themed party. They need to buy tickets soon.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 奥拉弗、娜塔莉和佐伊正在计划一个跨年派对。他们在考虑了歌剧和主题派对之后，决定在苏荷区举办一个高档的俱乐部活动。他们需要尽快购买门票。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00009
# === Agent 1 Output: English Summary ===
# John and Joan plan to watch "A Star is Born" on Thursday at 8 pm after Joan indicates she is free that day. John will send Joan the movie's location details.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 约翰和琼计划在周四晚上八点观看《一个明星的诞生》，因为琼表示那天她有空。约翰会给琼发送电影地点的详细信息。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00010
# === Agent 1 Output: English Summary ===
# Peyton requests Cameron bring a video game, but Cameron is out of town for another week. Peyton suggests using a courier, but Cameron refuses.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 佩顿要求卡梅伦带一个电子游戏，但卡梅伦要再出差一周。佩顿建议使用快递，但卡梅伦拒绝了。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00011
# === Agent 1 Output: English Summary ===
# Paul forgot about his physiotherapy appointment and will reschedule. Emma will be home late, and Paul offered to prepare food for her.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 保罗忘记了生理治疗的预约，将重新安排。艾玛会晚回家，保罗主动提出为她准备食物。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00012
# === Agent 1 Output: English Summary ===
# Harris informs Lena about his friend Aoki's recent passing and expresses his sadness. Lena offers her condolences and inquires about their last interaction.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 哈里斯告知莱娜他的朋友青木最近去世了，并表达了他的悲伤。莱娜表示慰问，并询问了他们最后一次互动的情况。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00013
# === Agent 1 Output: English Summary ===
# Yaz and Mary plan to attend their slimming club meeting despite indulging in unhealthy foods. They anticipate a scolding from their former cookery teacher who runs the club. Yaz will pick Mary up at 6 pm.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 亚兹和玛丽计划参加他们的减肥俱乐部会议，尽管他们吃了不健康的食物。他们预计会受到他们前烹饪老师的训斥，而她经营着这个俱乐部。亚兹将会在晚上六点接玛丽。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00014
# === Agent 1 Output: English Summary ===
# Ellie and Aaliyah are at the university while Camille is sick. Their class is in room 342 on the second floor.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 艾莉和阿里耶在大学里，而卡米尔生病了。它们的课在二楼342室。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00015
# === Agent 1 Output: English Summary ===
# Nathan shares a video of a woman having an intense spiritual experience with Aaron, who finds it humorous and compares it to his cat's facial expression while defecating. They both agree it's amusing and tragic.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 纳森与亚伦分享了一个视频，视频中一名女子正在经历强烈的宗教体验。亚伦觉得好笑，并将之与他的猫在排便时的表情相比较。他们都认为这既有趣又悲剧。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00016
# === Agent 1 Output: English Summary ===
# The group discusses their favorite Netflix shows. Recommendations include *Outlander*, *The Tudors*, *Grimm*, *Sabrina*, *The West Wing*, and *Bodyguard*. Some also admit to enjoying lighter fare like *Pretty Little Liars*, *Gossip Girl*, and *Desperate Housewives*.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 小组讨论他们最喜欢的Netflix节目。推荐包括《异乡人》、《都铎王朝》、《格林童话》、 《萨布里娜》、《白宫群英》和《守护者》。有些人也承认喜欢轻松的节目，如《挺身而进》、《绯闻女孩》和《绝望主妇》。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00017
# === Agent 1 Output: English Summary ===
# Jones and Angelina agree to meet in town later that afternoon. Jones will call Angelina to confirm the exact location.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 琼斯（Jones）和安吉丽娜（Angelina）同意当天下午在镇上见面。琼斯会给安吉丽娜打电话确认具体地点。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00018
# === Agent 1 Output: English Summary ===
# Casey shows off her new nail art, which she did herself, but it took nearly four hours. Amelia and Kristen compliment the nails and ask Casey to do theirs, but Casey declines due to the time-consuming process.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 凯西展示了她自己完成的新的指甲艺术，但花了近四个小时。阿米莉亚和克里斯汀赞美了指甲，并让凯西给她们做，但凯西因为耗时太长而拒绝了。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00019
# === Agent 1 Output: English Summary ===
# Sue urges Steve to call her back immediately as she has something important to discuss. Steve acknowledges and initiates the call.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 苏（Sū）催促史蒂夫（Shǐdìfū）立即回电，因为她有重要事情需要讨论。史蒂夫表示同意并拨通了电话。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00020
# === Agent 1 Output: English Summary ===
# Gemma wants to invite Timmy, his date, Lona, and Michelle to an event, but she's unsure if they'll accept, especially since she wants to attend their wedding receptions. Timmy teases her about the invitations.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 杰玛想邀请蒂米、他的约会对象罗娜和米歇尔参加一个活动，但她不确定他们是否会接受邀请，尤其是因为她也想参加他们的婚礼。蒂米调侃她关于这些邀请。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00021
# === Agent 1 Output: English Summary ===
# Ann congratulates Sue and Julie on their success and suggests a celebration, to which both Sue and Julie agree enthusiastically.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 安恩祝贺苏和朱莉取得的成功，并建议庆祝一下，苏和朱莉热情同意。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00022
# === Agent 1 Output: English Summary ===
# Steve informs his mum that the new dishwasher has been installed and is functioning well. He mentions it's a 12-place setting model, but he doesn't usually need to use all the space. His mum is glad he's pleased with it.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 史蒂夫告知他妈妈，新的洗碗机已经安装好并正常运行。他提到这是一个可容纳12个餐具的型号，但他通常不需要用到所有空间。他妈妈很高兴他满意这个洗碗机。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00023
# === Agent 1 Output: English Summary ===
# Marika asks Lara if she is coming today, and Lara confirms that she is.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 玛丽卡问拉拉今天是否来，拉拉确认她会来。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00024
# === Agent 1 Output: English Summary ===
# Miranda asks to cancel tomorrow's meeting due to work commitments, expressing the demands of being a young doctor. Stephanie humorously comments on Miranda's busy schedule.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 米兰达因工作承诺要求取消明天的会议，表达了年轻医生的压力。斯蒂芬妮幽默地调侃了米兰达的繁忙日程。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00025
# === Agent 1 Output: English Summary ===
# Javier is looking for an English-speaking tattoo parlor. Judie recommends Warsaw Ink, where her girlfriend got a tattoo that cost $1000. Javier decides to get a tattoo in Colombia instead.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 哈维埃尔正在寻找一家会说英语的纹身店。朱迪推荐华沙墨水，她的女朋友在那里纹了个花了1000美元的纹身。哈维埃尔决定在哥伦比亚纹身。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00026
# === Agent 1 Output: English Summary ===
# Sam, Jessica, and Michael are looking forward to staying in their friends' hotel next month, arriving on August 15th at 2 p.m. They express excitement about the accommodation and seeing each other again.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 山姆、杰西卡和迈克尔期待着下个月入住朋友的酒店，他们将于8月15日下午2点抵达。他们对住宿和再次见到彼此表示兴奋。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00027
# === Agent 1 Output: English Summary ===
# Terence accuses Daniel of stealing his money, but later realizes he had misplaced it himself. Daniel is upset by the accusation.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 特伦斯指责丹尼尔偷了他的钱，但后来发现自己把钱弄丢了。丹尼尔对这种指控感到难过。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00028
# === Agent 1 Output: English Summary ===
# Natacha offers to pick up Charles from the RER station. Charles will arrive around 5:30 pm and will call Natacha when he reaches Vesinet station.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 纳塔莎（Natacha）主动提出去RER车站接查尔斯（Charles）。查尔斯将于下午5点半左右到达，并在抵达维西奈（Vesinet）车站时给纳塔莎打电话。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00029
# === Agent 1 Output: English Summary ===
# Ann has extra math classes and will be home at 7, so Meg can meet her then.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 安有额外的数学课，会在七点回家，所以梅格可以在那时见她。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00030
# === Agent 1 Output: English Summary ===
# Pete is buying yogurt for Jen, who wants pear flavor if available; otherwise, she doesn't want any. Pete will look for pear yogurt and won't get another flavor if it's not available.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 彼得为詹购买酸奶。如果有梨味，她想要；否则，她不要任何口味。彼得会寻找梨味酸奶，如果没有就不会选其他口味。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00031
# === Agent 1 Output: English Summary ===
# Both Christie and Katie are tired after the party, which they enjoyed.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 克里斯蒂和凯蒂都享受了派对，但现在很累。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00032
# === Agent 1 Output: English Summary ===
# Sam and Carla plan to meet in Meanwood at 2 pm tomorrow, as Carla has the day off from work. They will go to a cafe known for its delicious cakes.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 山姆和卡拉计划明天下午两点在米恩伍德见面，因为卡拉那天休假。他们将去一家以美味蛋糕闻名的咖啡馆。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00033
# === Agent 1 Output: English Summary ===
# Joana and Sandy plan to play board games, specifically Dixit or Carcassonne, with Joana bringing the games to Sandy.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 乔安娜和桑迪计划玩棋盘游戏，具体是《迪克西特》或《卡卡颂》，乔安娜将把游戏带到桑迪家。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00034
# === Agent 1 Output: English Summary ===
# Steve recently purchased the new Dream Theater album and plans to share his thoughts on it with Rob, who already has the album and is preparing to listen to it.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 史蒂夫最近购买了新的梦剧院专辑，并计划与罗布分享他对专辑的看法。罗布已经拥有这张专辑，并且正在准备聆听它。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00035
# === Agent 1 Output: English Summary ===
# Joy sends Peter the link to her beauty shop, which he intends to review.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 乔伊给彼得发送了她美容店的链接，他打算进行评价。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00036
# === Agent 1 Output: English Summary ===
# The group discusses attending a Solstafir concert on November 21st. Noah is unsure if he can attend due to work commitments but will try to make it as he really wants to see the band. Archie thinks there are better concerts.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 这个小组讨论是否参加11月21日的Solstafir音乐会。诺亚因为工作原因不确定能否出席，但会尽力抽空，因为他非常想看这个乐队的表演。阿奇认为还有更好的音乐会。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00037
# === Agent 1 Output: English Summary ===
# The group discusses a cat invading the pitch at an Everton game, finding it amusing and sharing videos and commentary. Bradley jokes that it's the best entertainment Everton fans have had all season.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 这个小组讨论了一只猫在埃弗顿比赛期间入侵球场的事件，他们觉得很有趣，并分享了视频和评论。布拉德利开玩笑说，这是埃弗顿球迷本赛季享受的最佳娱乐。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00038
# === Agent 1 Output: English Summary ===
# Barbara invites Sean and Zac over; Sean asks if he can bring his dog and stay overnight, to which Barbara agrees.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 芭芭拉邀请肖恩和扎克来家里；肖恩问能不能带他的狗一起过夜，芭芭拉同意了。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00039
# === Agent 1 Output: English Summary ===
# Jake pulled a TOTW (Team of the Week) card for the first time this year and plans to sell it as it doesn't fit his team. Tom congratulates him but laments his own bad luck with pulls.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 杰克今年第一次抽到了一张“本周最佳阵容”（TOTW）卡，并计划出售它，因为它不适合他的球队。汤姆祝贺了他，但抱怨自己抽卡运气不佳。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00040
# === Agent 1 Output: English Summary ===
# Phil thanks Deana for a card and sunglasses, which neither Cathreen nor Deana recognize as theirs. They agree to keep the sunglasses, speculating they might belong to Adrian.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 菲尔（Fēi ěr）感谢迪安娜（Dī ān nà）送的卡片和太阳镜，但凯特琳（Kǎi tè lín）和迪安娜都不认识这副太阳镜是谁的。他们同意保留太阳镜，猜测它可能属于埃德里安（Ài dé lín）。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00041
# === Agent 1 Output: English Summary ===
# Mell and Gloria plan a barbecue at Mell's house on Saturday. They discuss the peacefulness of their lives now that their children have moved out, and Mell expresses relief that Tad's sister has moved away.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 梅尔和格洛丽亚计划在周六于梅尔的家里举行一场烧烤派对。他们讨论了孩子们搬出去后他们现在平静的生活，梅尔表达了他对塔德妹妹已经搬走的如释重负之情。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00042
# === Agent 1 Output: English Summary ===
# Callan's Samsung S8 is malfunctioning due to overheating, causing a black screen. Callan plans to take it to the store for warranty repair and assures Wade that their data is backed up.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 卡兰的三星S8由于过热而出现故障，导致屏幕变黑。卡兰打算将其送到商店进行保修维修，并向韦德保证他们的数据已备份。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00043
# === Agent 1 Output: English Summary ===
# Anna complains to her mother about a persistent stomachache that began at night. They discuss possible causes, including spoiled food, but no clear reason is found. Anna suggests seeing a doctor if the pain doesn't subside, and her mother agrees.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 安娜向母亲抱怨夜间开始的持续胃痛。她们讨论了可能的原因，包括变质的食物，但没有找到明确的原因。如果疼痛不减轻，安娜建议去看医生，母亲同意了。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00044
# === Agent 1 Output: English Summary ===
# Kate and Jeff are downstairs in a small room near the reception. Kate noticed a woman making a cake with a large marzipan penis, which made her laugh. Sam wants to see the cake.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 凯特和杰夫在接待处附近的一个小房间里。凯特看到一个女人正在用大块的杏仁糖做一个蛋糕，蛋糕上有一根巨大的“香蕉”，这让她笑了起来。山姆想看看这个蛋糕。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00045
# === Agent 1 Output: English Summary ===
# The group discusses Trump's behavior, agreeing that his tactics are manipulative and dangerous, and possibly driven by a desire for power rather than senility. They express hope for change and resolve to work towards winning the next elections.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 小组讨论特朗普的行为，一致认为他的手段具有操纵性和危险性，可能是由对权力的渴望而非痴呆所驱动。他们表达了对变化的希望，并决心努力赢得下一次选举。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00046
# === Agent 1 Output: English Summary ===
# Alex prefers The Flash over Batman or Superman due to his superhuman speed, which grants him access to the multiverse and makes him incredibly powerful. Pedro concedes that Alex's point about The Flash's abilities is valid.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 艾力克斯更喜欢闪电侠而非蝙蝠侠或超人，因为他拥有超人的速度，这使他能够进入多元宇宙并变得极其强大。佩德罗承认艾力克斯关于闪电侠能力的说法是有效的。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00047
# === Agent 1 Output: English Summary ===
# Damian asks Ethan, who is downtown, to buy him a kebab as he is hungry and had a bad day. Ethan agrees but expresses frustration at Damian's reliance on him. Damian promises to change his ways.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 达米安（Damian）向在市中心的伊森（Ethan）要一个烤肉串，因为他饿了，而且今天过得很糟糕。伊森同意了，但对达米安总是依赖他表示不满。达米安承诺会改变自己的行为。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00048
# === Agent 1 Output: English Summary ===
# Barry, Jake, and Dave plan to meet on campus at noon to march in the Women's Strike together. Jake and Dave will bring friends.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 巴里、杰克和戴夫计划在中午在校园里见面，一起参加妇女罢工游行。杰克和戴夫会带上朋友。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00049
# === Agent 1 Output: English Summary ===
# Martha inquires about Ophelia's contact lenses from her profile picture, which Ophelia reveals are from Crazy Lenses, offering affordable prices and swift delivery. Martha expresses gratitude and intends to explore the brand.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 玛尔塔询问了奥菲利亚在个人主页图片中佩戴的隐形眼镜，奥菲利亚透露这些镜头来自“疯狂镜头”品牌，价格实惠，送货迅速。玛尔塔表示感谢，并打算了解该品牌。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00050
# === Agent 1 Output: English Summary ===
# Linda wants to buy flowers for her mum but doesn't remember her preferences. Her dad, Michael, suggests tulips, roses, and freesias after seeing photos of the flower market; he discourages carnations. Linda decides on the freesias.
# ================================================================================
#
# === Agent 2 Output: Chinese Summary ===
# 琳达想给她妈妈买花，但记不住她妈妈的喜好。她的爸爸，迈克尔，在看了花市的照片后，建议买郁金香、玫瑰和风信子，并劝阻购买康乃馨。琳达最终决定买风信子。
# ================================================================================
#
# Finished. Outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.jsonl

# %% [markdown]
# ## 6. Export Final Summaries to CSV
#
# This file can be used for ROUGE, BERTScore, OmniScore, or manual analysis.
#
# For the ST pipeline, the CSV also includes the intermediate English summary from Agent 1.

# %%
# Cell 14: Export ST summaries to CSV

records = load_jsonl(FULL_OUTPUT_PATH)

rows = []

for record in records:
    if "final_summary" not in record:
        continue

    rows.append({
        "id": record.get("id", ""),
        "test_index": record.get("test_index", ""),
        "dialogue": record.get("dialogue", ""),

        # Intermediate output from Agent 1
        "english_summary": record.get("english_summary", ""),

        # Final output from Agent 2
        "final_summary": record.get("final_summary", ""),

        # References
        "reference_english_summary": record.get("reference_english_summary", ""),
        "reference_chinese_summary": record.get("reference_chinese_summary", ""),

        # Metadata
        "pipeline": record.get("pipeline", "summarize_then_translate"),
        "summarization_model": record.get("summarization_model", ""),
        "translation_model": record.get("translation_model", ""),
        "num_model_calls": record.get("num_model_calls", 2),
    })

df = pd.DataFrame(rows)

if not df.empty:
    df = df.drop_duplicates(subset=["id"], keep="last")

df.to_csv(FINAL_CSV_PATH, index=False, encoding="utf-8-sig")

print(f"Saved final summaries to: {FINAL_CSV_PATH}")
df
# Out:
# Saved final summaries to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\st_aya32b_50samples.csv
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 34  Joy sends Peter the link to her beauty shop, w...
# 35  The group discusses attending a Solstafir conc...
# 36  The group discusses a cat invading the pitch a...
# 37  Barbara invites Sean and Zac over; Sean asks i...
# 38  Jake pulled a TOTW (Team of the Week) card for...
# 39  Phil thanks Deana for a card and sunglasses, w...
# 40  Mell and Gloria plan a barbecue at Mell's hous...
# 41  Callan's Samsung S8 is malfunctioning due to o...
# 42  Anna complains to her mother about a persisten...
# 43  Kate and Jeff are downstairs in a small room n...
# 44  The group discusses Trump's behavior, agreeing...
# 45  Alex prefers The Flash over Batman or Superman...
# 46  Damian asks Ethan, who is downtown, to buy him...
# 47  Barry, Jake, and Dave plan to meet on campus a...
# 48  Martha inquires about Ophelia's contact lenses...
# 49  Linda wants to buy flowers for her mum but doe...
#
#                                         final_summary  \
# 0      安妮发现她以为三十岁的马克实际上已经四十岁了，这让她很不高兴。艾琳试图淡化年龄差异的重要性。
# 1                             玛丽向卡特要钱，卡特同意一小时后在火车站见面。
# 2   蒂娜（Tina）在表达对航班延误和健谈飞行员的沮丧的同时，也赞扬了阿联酋航空（Emirate...
# 3          安娜和凯瑟琳计划明天去看望她们的祖母，因为安娜想念她。凯瑟琳会在醒来时给安娜打电话。
# 4               乔伊斯分享了一个便宜门票的链接；迈克尔表达了惊讶，而埃德森立即预订了一个。
# 5   简（Jane）和史蒂文（Steven）因可能路程时间较长，同意将见面时间从五点改为四点半。史...
# 6   菲奥娜（Fiona）请蒂娜（Tina）帮忙准备一个馅饼给克里斯（Chris）。蒂娜同意帮忙，...
# 7   奥拉弗、娜塔莉和佐伊正在计划一个跨年派对。他们在考虑了歌剧和主题派对之后，决定在苏荷区举办一...
# 8   约翰和琼计划在周四晚上八点观看《一个明星的诞生》，因为琼表示那天她有空。约翰会给琼发送电影地...
# 9         佩顿要求卡梅伦带一个电子游戏，但卡梅伦要再出差一周。佩顿建议使用快递，但卡梅伦拒绝了。
# 10            保罗忘记了生理治疗的预约，将重新安排。艾玛会晚回家，保罗主动提出为她准备食物。
# 11  哈里斯告知莱娜他的朋友青木最近去世了，并表达了他的悲伤。莱娜表示慰问，并询问了他们最后一次互...
# 12  亚兹和玛丽计划参加他们的减肥俱乐部会议，尽管他们吃了不健康的食物。他们预计会受到他们前烹饪老...
# 13                    艾莉和阿里耶在大学里，而卡米尔生病了。它们的课在二楼342室。
# 14  纳森与亚伦分享了一个视频，视频中一名女子正在经历强烈的宗教体验。亚伦觉得好笑，并将之与他的猫...
# 15  小组讨论他们最喜欢的Netflix节目。推荐包括《异乡人》、《都铎王朝》、《格林童话》、 《...
# 16  琼斯（Jones）和安吉丽娜（Angelina）同意当天下午在镇上见面。琼斯会给安吉丽娜打电...
# 17  凯西展示了她自己完成的新的指甲艺术，但花了近四个小时。阿米莉亚和克里斯汀赞美了指甲，并让凯西...
# 18  苏（Sū）催促史蒂夫（Shǐdìfū）立即回电，因为她有重要事情需要讨论。史蒂夫表示同意并拨...
# 19  杰玛想邀请蒂米、他的约会对象罗娜和米歇尔参加一个活动，但她不确定他们是否会接受邀请，尤其是因...
# 20                    安恩祝贺苏和朱莉取得的成功，并建议庆祝一下，苏和朱莉热情同意。
# 21  史蒂夫告知他妈妈，新的洗碗机已经安装好并正常运行。他提到这是一个可容纳12个餐具的型号，但他...
# 22                               玛丽卡问拉拉今天是否来，拉拉确认她会来。
# 23   米兰达因工作承诺要求取消明天的会议，表达了年轻医生的压力。斯蒂芬妮幽默地调侃了米兰达的繁忙日程。
# 24  哈维埃尔正在寻找一家会说英语的纹身店。朱迪推荐华沙墨水，她的女朋友在那里纹了个花了1000美...
# 25  山姆、杰西卡和迈克尔期待着下个月入住朋友的酒店，他们将于8月15日下午2点抵达。他们对住宿和...
# 26           特伦斯指责丹尼尔偷了他的钱，但后来发现自己把钱弄丢了。丹尼尔对这种指控感到难过。
# 27  纳塔莎（Natacha）主动提出去RER车站接查尔斯（Charles）。查尔斯将于下午5点半...
# 28                       安有额外的数学课，会在七点回家，所以梅格可以在那时见她。
# 29  彼得为詹购买酸奶。如果有梨味，她想要；否则，她不要任何口味。彼得会寻找梨味酸奶，如果没有就不...
# 30                               克里斯蒂和凯蒂都享受了派对，但现在很累。
# 31   山姆和卡拉计划明天下午两点在米恩伍德见面，因为卡拉那天休假。他们将去一家以美味蛋糕闻名的咖啡馆。
# 32        乔安娜和桑迪计划玩棋盘游戏，具体是《迪克西特》或《卡卡颂》，乔安娜将把游戏带到桑迪家。
# 33  史蒂夫最近购买了新的梦剧院专辑，并计划与罗布分享他对专辑的看法。罗布已经拥有这张专辑，并且正...
# 34                           乔伊给彼得发送了她美容店的链接，他打算进行评价。
# 35  这个小组讨论是否参加11月21日的Solstafir音乐会。诺亚因为工作原因不确定能否出席，...
# 36  这个小组讨论了一只猫在埃弗顿比赛期间入侵球场的事件，他们觉得很有趣，并分享了视频和评论。布拉...
# 37               芭芭拉邀请肖恩和扎克来家里；肖恩问能不能带他的狗一起过夜，芭芭拉同意了。
# 38  杰克今年第一次抽到了一张“本周最佳阵容”（TOTW）卡，并计划出售它，因为它不适合他的球队。...
# 39  菲尔（Fēi ěr）感谢迪安娜（Dī ān nà）送的卡片和太阳镜，但凯特琳（Kǎi tè ...
# 40  梅尔和格洛丽亚计划在周六于梅尔的家里举行一场烧烤派对。他们讨论了孩子们搬出去后他们现在平静的...
# 41  卡兰的三星S8由于过热而出现故障，导致屏幕变黑。卡兰打算将其送到商店进行保修维修，并向韦德保...
# 42  安娜向母亲抱怨夜间开始的持续胃痛。她们讨论了可能的原因，包括变质的食物，但没有找到明确的原因...
# 43  凯特和杰夫在接待处附近的一个小房间里。凯特看到一个女人正在用大块的杏仁糖做一个蛋糕，蛋糕上有...
# 44  小组讨论特朗普的行为，一致认为他的手段具有操纵性和危险性，可能是由对权力的渴望而非痴呆所驱动...
# 45  艾力克斯更喜欢闪电侠而非蝙蝠侠或超人，因为他拥有超人的速度，这使他能够进入多元宇宙并变得极其...
# 46  达米安（Damian）向在市中心的伊森（Ethan）要一个烤肉串，因为他饿了，而且今天过得很...
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
#
#                     pipeline summarization_model translation_model  \
# 0   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 1   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 2   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 3   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 4   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 5   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 6   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 7   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 8   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 9   summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 10  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 11  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 12  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 13  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 14  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 15  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 16  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 17  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 18  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 19  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 20  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 21  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 22  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 23  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 24  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 25  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 26  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 27  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 28  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 29  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 30  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 31  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 32  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 33  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 34  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 35  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 36  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 37  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 38  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 39  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 40  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 41  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 42  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 43  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 44  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 45  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 46  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 47  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 48  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
# 49  summarize_then_translate     aya-expanse:32b   aya-expanse:32b
#
#     num_model_calls
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# 5                 2
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                2
# 11                2
# 12                2
# 13                2
# 14                2
# 15                2
# 16                2
# 17                2
# 18                2
# 19                2
# 20                2
# 21                2
# 22                2
# 23                2
# 24                2
# 25                2
# 26                2
# 27                2
# 28                2
# 29                2
# 30                2
# 31                2
# 32                2
# 33                2
# 34                2
# 35                2
# 36                2
# 37                2
# 38                2
# 39                2
# 40                2
# 41                2
# 42                2
# 43                2
# 44                2
# 45                2
# 46                2
# 47                2
# 48                2
# 49                2

# %%
# Cell 15: Compare ST outputs with references

comparison_columns = [
    "id",
    "test_index",
    "english_summary",
    "reference_english_summary",
    "final_summary",
    "reference_chinese_summary",
]

comparison_df = df[comparison_columns].copy()

comparison_df
# Out:
#             id  test_index                                    english_summary  \
# 0   gold_00001          23  Anne discovered that Mark, whom she thought wa...
# 1   gold_00002          30  Mary asks Carter for money, and Carter agrees ...
# 2   gold_00003          39  Tina compliments the appearance of Emirates st...
# 3   gold_00004          65  Ana and Catherine plan to visit their grandmot...
# 4   gold_00005          66  Joyce shares a link to cheap tickets; Michael ...
# 5   gold_00006          67  Jane and Steven agree to meet at 4:30 instead ...
# 6   gold_00007          78  Fiona asks Tina for help in preparing a tart f...
# 7   gold_00008          86  Olafur, Nathalie, and Zoe are planning a New Y...
# 8   gold_00009         120  John and Joan plan to watch "A Star is Born" o...
# 9   gold_00010         137  Peyton requests Cameron bring a video game, bu...
# 10  gold_00011         139  Paul forgot about his physiotherapy appointmen...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                                         final_summary  \
# 0      安妮发现她以为三十岁的马克实际上已经四十岁了，这让她很不高兴。艾琳试图淡化年龄差异的重要性。
# 1                             玛丽向卡特要钱，卡特同意一小时后在火车站见面。
# 2   蒂娜（Tina）在表达对航班延误和健谈飞行员的沮丧的同时，也赞扬了阿联酋航空（Emirate...
# 3          安娜和凯瑟琳计划明天去看望她们的祖母，因为安娜想念她。凯瑟琳会在醒来时给安娜打电话。
# 4               乔伊斯分享了一个便宜门票的链接；迈克尔表达了惊讶，而埃德森立即预订了一个。
# 5   简（Jane）和史蒂文（Steven）因可能路程时间较长，同意将见面时间从五点改为四点半。史...
# 6   菲奥娜（Fiona）请蒂娜（Tina）帮忙准备一个馅饼给克里斯（Chris）。蒂娜同意帮忙，...
# 7   奥拉弗、娜塔莉和佐伊正在计划一个跨年派对。他们在考虑了歌剧和主题派对之后，决定在苏荷区举办一...
# 8   约翰和琼计划在周四晚上八点观看《一个明星的诞生》，因为琼表示那天她有空。约翰会给琼发送电影地...
# 9         佩顿要求卡梅伦带一个电子游戏，但卡梅伦要再出差一周。佩顿建议使用快递，但卡梅伦拒绝了。
# 10            保罗忘记了生理治疗的预约，将重新安排。艾玛会晚回家，保罗主动提出为她准备食物。
# 11  哈里斯告知莱娜他的朋友青木最近去世了，并表达了他的悲伤。莱娜表示慰问，并询问了他们最后一次互...
# 12  亚兹和玛丽计划参加他们的减肥俱乐部会议，尽管他们吃了不健康的食物。他们预计会受到他们前烹饪老...
# 13                    艾莉和阿里耶在大学里，而卡米尔生病了。它们的课在二楼342室。
# 14  纳森与亚伦分享了一个视频，视频中一名女子正在经历强烈的宗教体验。亚伦觉得好笑，并将之与他的猫...
# 15  小组讨论他们最喜欢的Netflix节目。推荐包括《异乡人》、《都铎王朝》、《格林童话》、 《...
# 16  琼斯（Jones）和安吉丽娜（Angelina）同意当天下午在镇上见面。琼斯会给安吉丽娜打电...
# 17  凯西展示了她自己完成的新的指甲艺术，但花了近四个小时。阿米莉亚和克里斯汀赞美了指甲，并让凯西...
# 18  苏（Sū）催促史蒂夫（Shǐdìfū）立即回电，因为她有重要事情需要讨论。史蒂夫表示同意并拨...
# 19  杰玛想邀请蒂米、他的约会对象罗娜和米歇尔参加一个活动，但她不确定他们是否会接受邀请，尤其是因...
# 20                    安恩祝贺苏和朱莉取得的成功，并建议庆祝一下，苏和朱莉热情同意。
# 21  史蒂夫告知他妈妈，新的洗碗机已经安装好并正常运行。他提到这是一个可容纳12个餐具的型号，但他...
# 22                               玛丽卡问拉拉今天是否来，拉拉确认她会来。
# 23   米兰达因工作承诺要求取消明天的会议，表达了年轻医生的压力。斯蒂芬妮幽默地调侃了米兰达的繁忙日程。
# 24  哈维埃尔正在寻找一家会说英语的纹身店。朱迪推荐华沙墨水，她的女朋友在那里纹了个花了1000美...
# 25  山姆、杰西卡和迈克尔期待着下个月入住朋友的酒店，他们将于8月15日下午2点抵达。他们对住宿和...
# 26           特伦斯指责丹尼尔偷了他的钱，但后来发现自己把钱弄丢了。丹尼尔对这种指控感到难过。
# 27  纳塔莎（Natacha）主动提出去RER车站接查尔斯（Charles）。查尔斯将于下午5点半...
# 28                       安有额外的数学课，会在七点回家，所以梅格可以在那时见她。
# 29  彼得为詹购买酸奶。如果有梨味，她想要；否则，她不要任何口味。彼得会寻找梨味酸奶，如果没有就不...
# 30                               克里斯蒂和凯蒂都享受了派对，但现在很累。
# 31   山姆和卡拉计划明天下午两点在米恩伍德见面，因为卡拉那天休假。他们将去一家以美味蛋糕闻名的咖啡馆。
# 32        乔安娜和桑迪计划玩棋盘游戏，具体是《迪克西特》或《卡卡颂》，乔安娜将把游戏带到桑迪家。
# 33  史蒂夫最近购买了新的梦剧院专辑，并计划与罗布分享他对专辑的看法。罗布已经拥有这张专辑，并且正...
# 34                           乔伊给彼得发送了她美容店的链接，他打算进行评价。
# 35  这个小组讨论是否参加11月21日的Solstafir音乐会。诺亚因为工作原因不确定能否出席，...
# 36  这个小组讨论了一只猫在埃弗顿比赛期间入侵球场的事件，他们觉得很有趣，并分享了视频和评论。布拉...
# 37               芭芭拉邀请肖恩和扎克来家里；肖恩问能不能带他的狗一起过夜，芭芭拉同意了。
# 38  杰克今年第一次抽到了一张“本周最佳阵容”（TOTW）卡，并计划出售它，因为它不适合他的球队。...
# 39  菲尔（Fēi ěr）感谢迪安娜（Dī ān nà）送的卡片和太阳镜，但凯特琳（Kǎi tè ...
# 40  梅尔和格洛丽亚计划在周六于梅尔的家里举行一场烧烤派对。他们讨论了孩子们搬出去后他们现在平静的...
# 41  卡兰的三星S8由于过热而出现故障，导致屏幕变黑。卡兰打算将其送到商店进行保修维修，并向韦德保...
# 42  安娜向母亲抱怨夜间开始的持续胃痛。她们讨论了可能的原因，包括变质的食物，但没有找到明确的原因...
# 43  凯特和杰夫在接待处附近的一个小房间里。凯特看到一个女人正在用大块的杏仁糖做一个蛋糕，蛋糕上有...
# 44  小组讨论特朗普的行为，一致认为他的手段具有操纵性和危险性，可能是由对权力的渴望而非痴呆所驱动...
# 45  艾力克斯更喜欢闪电侠而非蝙蝠侠或超人，因为他拥有超人的速度，这使他能够进入多元宇宙并变得极其...
# 46  达米安（Damian）向在市中心的伊森（Ethan）要一个烤肉串，因为他饿了，而且今天过得很...
# 47         巴里、杰克和戴夫计划在中午在校园里见面，一起参加妇女罢工游行。杰克和戴夫会带上朋友。
# 48  玛尔塔询问了奥菲利亚在个人主页图片中佩戴的隐形眼镜，奥菲利亚透露这些镜头来自“疯狂镜头”品牌...
# 49  琳达想给她妈妈买花，但记不住她妈妈的喜好。她的爸爸，迈克尔，在看了花市的照片后，建议买郁金香...
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。

# %%
# Cell 16: Inspect ST outputs

if not df.empty:
    inspection_columns = [
        "id",
        "test_index",
        "dialogue",
        "english_summary",
        "reference_english_summary",
        "final_summary",
        "reference_chinese_summary",
    ]

    inspection_df = df[inspection_columns].copy()
    display(inspection_df)
else:
    print("No results found.")
# Out:
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 7   奥拉弗、娜塔莉和佐伊正在计划一个跨年派对。他们在考虑了歌剧和主题派对之后，决定在苏荷区举办一...
# 8   约翰和琼计划在周四晚上八点观看《一个明星的诞生》，因为琼表示那天她有空。约翰会给琼发送电影地...
# 9         佩顿要求卡梅伦带一个电子游戏，但卡梅伦要再出差一周。佩顿建议使用快递，但卡梅伦拒绝了。
# 10            保罗忘记了生理治疗的预约，将重新安排。艾玛会晚回家，保罗主动提出为她准备食物。
# 11  哈里斯告知莱娜他的朋友青木最近去世了，并表达了他的悲伤。莱娜表示慰问，并询问了他们最后一次互...
# 12  亚兹和玛丽计划参加他们的减肥俱乐部会议，尽管他们吃了不健康的食物。他们预计会受到他们前烹饪老...
# 13                    艾莉和阿里耶在大学里，而卡米尔生病了。它们的课在二楼342室。
# 14  纳森与亚伦分享了一个视频，视频中一名女子正在经历强烈的宗教体验。亚伦觉得好笑，并将之与他的猫...
# 15  小组讨论他们最喜欢的Netflix节目。推荐包括《异乡人》、《都铎王朝》、《格林童话》、 《...
# 16  琼斯（Jones）和安吉丽娜（Angelina）同意当天下午在镇上见面。琼斯会给安吉丽娜打电...
# 17  凯西展示了她自己完成的新的指甲艺术，但花了近四个小时。阿米莉亚和克里斯汀赞美了指甲，并让凯西...
# 18  苏（Sū）催促史蒂夫（Shǐdìfū）立即回电，因为她有重要事情需要讨论。史蒂夫表示同意并拨...
# 19  杰玛想邀请蒂米、他的约会对象罗娜和米歇尔参加一个活动，但她不确定他们是否会接受邀请，尤其是因...
# 20                    安恩祝贺苏和朱莉取得的成功，并建议庆祝一下，苏和朱莉热情同意。
# 21  史蒂夫告知他妈妈，新的洗碗机已经安装好并正常运行。他提到这是一个可容纳12个餐具的型号，但他...
# 22                               玛丽卡问拉拉今天是否来，拉拉确认她会来。
# 23   米兰达因工作承诺要求取消明天的会议，表达了年轻医生的压力。斯蒂芬妮幽默地调侃了米兰达的繁忙日程。
# 24  哈维埃尔正在寻找一家会说英语的纹身店。朱迪推荐华沙墨水，她的女朋友在那里纹了个花了1000美...
# 25  山姆、杰西卡和迈克尔期待着下个月入住朋友的酒店，他们将于8月15日下午2点抵达。他们对住宿和...
# 26           特伦斯指责丹尼尔偷了他的钱，但后来发现自己把钱弄丢了。丹尼尔对这种指控感到难过。
# 27  纳塔莎（Natacha）主动提出去RER车站接查尔斯（Charles）。查尔斯将于下午5点半...
# 28                       安有额外的数学课，会在七点回家，所以梅格可以在那时见她。
# 29  彼得为詹购买酸奶。如果有梨味，她想要；否则，她不要任何口味。彼得会寻找梨味酸奶，如果没有就不...
# 30                               克里斯蒂和凯蒂都享受了派对，但现在很累。
# 31   山姆和卡拉计划明天下午两点在米恩伍德见面，因为卡拉那天休假。他们将去一家以美味蛋糕闻名的咖啡馆。
# 32        乔安娜和桑迪计划玩棋盘游戏，具体是《迪克西特》或《卡卡颂》，乔安娜将把游戏带到桑迪家。
# 33  史蒂夫最近购买了新的梦剧院专辑，并计划与罗布分享他对专辑的看法。罗布已经拥有这张专辑，并且正...
# 34                           乔伊给彼得发送了她美容店的链接，他打算进行评价。
# 35  这个小组讨论是否参加11月21日的Solstafir音乐会。诺亚因为工作原因不确定能否出席，...
# 36  这个小组讨论了一只猫在埃弗顿比赛期间入侵球场的事件，他们觉得很有趣，并分享了视频和评论。布拉...
# 37               芭芭拉邀请肖恩和扎克来家里；肖恩问能不能带他的狗一起过夜，芭芭拉同意了。
# 38  杰克今年第一次抽到了一张“本周最佳阵容”（TOTW）卡，并计划出售它，因为它不适合他的球队。...
# 39  菲尔（Fēi ěr）感谢迪安娜（Dī ān nà）送的卡片和太阳镜，但凯特琳（Kǎi tè ...
# 40  梅尔和格洛丽亚计划在周六于梅尔的家里举行一场烧烤派对。他们讨论了孩子们搬出去后他们现在平静的...
# 41  卡兰的三星S8由于过热而出现故障，导致屏幕变黑。卡兰打算将其送到商店进行保修维修，并向韦德保...
# 42  安娜向母亲抱怨夜间开始的持续胃痛。她们讨论了可能的原因，包括变质的食物，但没有找到明确的原因...
# 43  凯特和杰夫在接待处附近的一个小房间里。凯特看到一个女人正在用大块的杏仁糖做一个蛋糕，蛋糕上有...
# 44  小组讨论特朗普的行为，一致认为他的手段具有操纵性和危险性，可能是由对权力的渴望而非痴呆所驱动...
# 45  艾力克斯更喜欢闪电侠而非蝙蝠侠或超人，因为他拥有超人的速度，这使他能够进入多元宇宙并变得极其...
# 46  达米安（Damian）向在市中心的伊森（Ethan）要一个烤肉串，因为他饿了，而且今天过得很...
# 47         巴里、杰克和戴夫计划在中午在校园里见面，一起参加妇女罢工游行。杰克和戴夫会带上朋友。
# 48  玛尔塔询问了奥菲利亚在个人主页图片中佩戴的隐形眼镜，奥菲利亚透露这些镜头来自“疯狂镜头”品牌...
# 49  琳达想给她妈妈买花，但记不住她妈妈的喜好。她的爸爸，迈克尔，在看了花市的照片后，建议买郁金香...
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
