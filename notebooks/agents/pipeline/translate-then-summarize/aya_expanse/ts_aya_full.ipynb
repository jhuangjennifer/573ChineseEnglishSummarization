# %% [markdown]
# # Translate-then-Summarize Pipeline for English-to-Chinese Dialogue Summarization
#
# This notebook implements a local Translate-then-Summarize baseline for English-to-Chinese cross-lingual dialogue summarization.
#
# The TS pipeline uses two local small language model agents. Agent 1 reads the original English dialogue and translates the full dialogue into Chinese while preserving speaker names, turn order, placeholders, and dialogue structure. Agent 2 then reads the translated Chinese dialogue and generates a concise Chinese summary.
#
# ```text
# English Dialogue
# → Agent 1: Chinese Translation Agent
# → Agent 2: Chinese Summarization Agent
# → Final Chinese Summary
# ```
#
# The pipeline consists of two agents:
#
# ```text
# Agent 1: Chinese Translation Agent
# Input: original English dialogue
# Output: translated Chinese dialogue
#
# Agent 2: Chinese Summarization Agent
# Input: translated Chinese dialogue from Agent 1
# Output: final Chinese summary
# ```
# This setup is used as a Translate-then-Summarize baseline. Unlike the Direct pipeline, TS explicitly creates an intermediate Chinese dialogue translation before summarization. This allows us to inspect whether errors come from the translation stage or the summarization stage.
#
# The local small language model is served through Ollama. The notebook controls the prompt design, agent workflow, input/output processing, intermediate output inspection, and result saving.

# %% [markdown]
# ## 0. Local Ollama Setup
#
# Before running this notebook, install Ollama and download the local model used for the Translate-then-Summarize baseline.
#
# ### Recommended model setup
#
# This notebook uses one local small language model through Ollama for both agents:
#
# - Agent 1: Chinese Translation Agent
# - Agent 2: Chinese Summarization Agent
#
# ```bash
# ollama pull aya-expanse:32b
# ```
#
# If qwen3.5:27b is too slow on your machine, you can use a smaller model for testing:
#
# ```bash
# ollama pull "aya-expanse:32b"
# ```
#
# Make sure the model names in the notebook match the models installed in Ollama:
#
# ```bash
# TRANSLATION_MODEL = "aya-expanse:32b"
# SUMMARIZATION_MODEL = "aya-expanse:32b"
# ```
#
# You can check downloaded models with:
#
# ```bash
# ollama list
# ```
#
# You can check currently loaded models with:
#
# ```bash
# ollama ps
# ```
#
# If the Ollama server is not running, start it with:
#
# ```bash
# ollama serve
# ```
#
# On macOS, opening the Ollama app usually starts the local server automatically.

# %%
# Cell 1: Install required Python packages.
# Run this only once if the packages are not installed

# !pip install requests pandas tqdm
# Out:
# Requirement already satisfied: requests in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.33.1)
# Requirement already satisfied: pandas in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: colorama in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\flexboy\anaconda3\envs\yunu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Cell 2: Imports and global configuration

import json
import time
from pathlib import Path
from typing import Any, Dict, List, Optional

import requests
import pandas as pd
from tqdm.auto import tqdm

OLLAMA_HOST = "http://localhost:11434"

# TS models
TRANSLATION_MODEL = "aya-expanse:32b"
SUMMARIZATION_MODEL = "aya-expanse:32b"

DEFAULT_TEMPERATURE = 0.2
DEFAULT_NUM_CTX = 8192

# window project path
PROJECT_ROOT = Path(
    r"C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu"
)

# Gold set path
GOLD_SET_PATH = PROJECT_ROOT / "gold_set_50_zh_XSAMSum_bart.json"

# Output directory
OUTPUT_DIR = PROJECT_ROOT
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Output files for TS baseline
FULL_OUTPUT_PATH = OUTPUT_DIR / "ts_aya32b_50samples.jsonl"
FINAL_CSV_PATH = OUTPUT_DIR / "ts_aya32b_50samples.csv"
ERROR_OUTPUT_PATH = OUTPUT_DIR / "ts_aya32b_50samples_errors.jsonl"

print("Gold set path:", GOLD_SET_PATH)
print("Output directory:", OUTPUT_DIR)
print("Full JSONL output path:", FULL_OUTPUT_PATH)
print("Final CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Gold set path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\gold_set_50_zh_XSAMSum_bart.json
# Output directory: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu
# Full JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.jsonl
# Final CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples_errors.jsonl

# %%
print(GOLD_SET_PATH.exists())
# Out:
# True

# %%
# Cell 3: Check whether Ollama is running

def check_ollama_server() -> bool:
    try:
        response = requests.get(f"{OLLAMA_HOST}/api/tags", timeout=10)
        response.raise_for_status()
        models = response.json().get("models", [])

        print("Ollama server is running.")
        print(f"Downloaded models: {[m.get('name') for m in models]}")

        return True

    except Exception as e:
        print("Could not connect to Ollama.")
        print("Make sure Ollama is installed and running.")
        print("Try running this in Terminal:")
        print("  ollama serve")
        print()
        print("Error:", repr(e))

        return False


_ = check_ollama_server()
# Out:
# Ollama server is running.
# Downloaded models: ['aya-expanse:32b', 'gemma3:27b', 'qwen3.5:27b']

# %%
# Cell 4: Ollama API helper

def call_ollama(
    model: str,
    prompt: str,
    system: Optional[str] = None,
    temperature: float = DEFAULT_TEMPERATURE,
    num_ctx: int = DEFAULT_NUM_CTX,
    timeout: int = 900,
) -> str:
    """Call Ollama's local chat API and return the assistant content."""

    messages = []

    if system:
        messages.append({"role": "system", "content": system})

    messages.append({"role": "user", "content": prompt})

    payload = {
        "model": model,
        "messages": messages,
        "stream": False,
        "options": {
            "temperature": temperature,
            "num_ctx": num_ctx,
            "num_predict": 1024,
        },
        "think": False,
    }

    response = requests.post(
        f"{OLLAMA_HOST}/api/chat",
        json=payload,
        timeout=timeout,
    )
    response.raise_for_status()

    data = response.json()
    content = data.get("message", {}).get("content", "")

    if content is None:
        content = ""

    return content.strip()

# %% [markdown]
# ## 1. Prompt Templates
#
# Each agent is defined as:
#
# ```text
# Agent = model + role-specific prompt + input/output format
# ```
#
# In the first version, we use a fixed workflow rather than a fully autonomous agent system.

# %%
# Cell 5: TS prompt templates

CHINESE_TRANSLATION_PROMPT = """You are a dialogue translation agent.

Your task is to translate the following English dialogue into Chinese.

Requirements:
- Translate the full dialogue into Chinese.
- Preserve the speaker names.
- Preserve the dialogue structure and turn order.
- Preserve placeholders such as <file_photo>, <file_other>, <location>, or emojis if they appear.
- Do not summarize the dialogue.
- Do not omit any important information.
- Do not add information that is not in the original dialogue.
- Output only the translated Chinese dialogue.

STRICT TRANSLATION RULE:
- You MUST translate ALL English proper nouns and speaker names into standard Chinese characters.
- ABSOLUTELY NO English letters or names should appear in the final Chinese summary.

English dialogue:
{dialogue}

Chinese translation:
"""


CHINESE_SUMMARIZATION_PROMPT = """You are a Chinese dialogue summarization agent.

Your task is to read the translated Chinese dialogue and generate a concise Chinese summary.

Requirements:
- Summarize the main information in the dialogue.
- Write the summary in Chinese.
- Keep the summary concise and faithful to the dialogue.
- Do not add information that is not stated or clearly implied.
- Do not explain your reasoning.
- Output only the final Chinese summary.

Conciseness: 
- For simple dialogues, prefer 20-50 Chinese characters. 
- For complex dialogues, allow up to 80 Chinese characters.

Chinese dialogue:
{translated_dialogue}

Chinese summary:
"""

# %%
# Cell 6: JSONL utility functions

def append_jsonl(record: Dict[str, Any], path: Path) -> None:
    """Append one record to a JSONL file."""
    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")


def load_jsonl(path: Path) -> List[Dict[str, Any]]:
    """Load a JSONL file into a list of dictionaries."""
    if not path.exists():
        return []

    records = []

    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if line:
                records.append(json.loads(line))

    return records


def load_processed_ids(path: Path) -> set:
    """Return IDs that have already been processed."""
    records = load_jsonl(path)

    return {str(record["id"]) for record in records if "id" in record}

# %%
# Cell 7: TS agent functions

def fill_prompt(template: str, replacements: Dict[str, str]) -> str:
    """Replace named placeholders in the prompt."""
    prompt = template

    for key, value in replacements.items():
        prompt = prompt.replace("{" + key + "}", value)

    return prompt


def chinese_translation_agent(dialogue: str) -> str:
    """Agent 1: English dialogue -> translated Chinese dialogue."""
    prompt = fill_prompt(
        CHINESE_TRANSLATION_PROMPT,
        {
            "dialogue": dialogue,
        },
    )

    response = call_ollama(
        model=TRANSLATION_MODEL,
        prompt=prompt,
        temperature=0.2,
    )

    return response.strip()


def chinese_summarization_agent(translated_dialogue: str) -> str:
    """Agent 2: translated Chinese dialogue -> Chinese summary."""
    prompt = fill_prompt(
        CHINESE_SUMMARIZATION_PROMPT,
        {
            "translated_dialogue": translated_dialogue,
        },
    )

    response = call_ollama(
        model=SUMMARIZATION_MODEL,
        prompt=prompt,
        temperature=0.2,
    )

    return response.strip()

# %% [markdown]
# ## 2. Agent Functions
#
# Each function corresponds to one agent in the pipeline.

# %%
# Cell 8: TS pipeline

def run_ts_pipeline(example: Dict[str, Any], verbose: bool = True) -> Dict[str, Any]:
    """Run the Translate-then-Summarize pipeline."""

    sample_id = str(example.get("id", "unknown"))
    dialogue = example["dialogue"]

    reference_english_summary = example.get("reference_english_summary", "")
    reference_chinese_summary = example.get("reference_chinese_summary", "")

    # Agent 1: English dialogue -> translated Chinese dialogue
    translated_dialogue = chinese_translation_agent(dialogue)

    if verbose:
        print("\n" + "=" * 80)
        print(f"Sample ID: {sample_id}")
        print("=== Agent 1 Intermediate Output: Translated Chinese Dialogue ===")
        print(translated_dialogue)
        print("=" * 80 + "\n")

    # Agent 2: translated Chinese dialogue -> Chinese summary
    final_chinese_summary = chinese_summarization_agent(translated_dialogue)

    if verbose:
        print("=== Agent 2 Final Output: Chinese Summary ===")
        print(final_chinese_summary)
        print("=" * 80 + "\n")

    return {
        "id": sample_id,
        "test_index": example.get("test_index", ""),
        "dialogue": dialogue,

        # Intermediate output from Agent 1
        "translated_dialogue": translated_dialogue,

        # Final output from Agent 2
        "final_summary": final_chinese_summary,

        # References
        "reference_english_summary": reference_english_summary,
        "reference_chinese_summary": reference_chinese_summary,

        # Metadata
        "pipeline": "translate_then_summarize",
        "translation_model": TRANSLATION_MODEL,
        "summarization_model": SUMMARIZATION_MODEL,
        "num_model_calls": 2,
    }

# %% [markdown]
# ## 3. Test with Examples
#
# Start with five examples before running the full dataset.
# This is the best way to inspect whether errors come from the English summarization stage or the Chinese translation stage.

# %%
# Cell 9: Load first 5 examples from the gold set

def load_examples_from_gold_set(path: Path, n: int = 5) -> List[Dict[str, Any]]:
    """Load the first n examples from the gold-set JSON file."""
    if not path.exists():
        raise FileNotFoundError(f"Gold set not found: {path}")

    with path.open("r", encoding="utf-8") as f:
        raw_data = json.load(f)

    examples = []

    for i, item in enumerate(raw_data[:n]):
        examples.append({
            "id": f"gold_{i+1:05d}",
            "test_index": item.get("test_index", ""),
            "dialogue": item["dialogue"],
            "reference_english_summary": item.get("summary", ""),
            "reference_chinese_summary": item.get("summary_zh", ""),
        })

    return examples


test_data = load_examples_from_gold_set(GOLD_SET_PATH, n=50)

print(f"Loaded {len(test_data)} examples.")
print("First example:")
print(test_data[0])
# Out:
# Loaded 50 examples.
# First example:
# {'id': 'gold_00001', 'test_index': 23, 'dialogue': "Anne: You were right, he was lying to me :/\nIrene: Oh no, what happened?\nJane: who? that Mark guy?\nAnne: yeah, he told me he's 30, today I saw his passport - he's 40\nIrene: You sure it's so important?\nAnne: he lied to me Irene", 'reference_english_summary': 'Mark lied to Anne about his age. Mark is 40.', 'reference_chinese_summary': '马克向安妮隐瞒了自己的年龄。他40岁了。'}

# %%
# Cell 10: Run the TS pipeline for the first example

result = run_ts_pipeline(test_data[4], verbose=True)
result
# Out:
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 乔伊丝：看看这个！
# 乔伊丝：<链接>
# 迈克尔：好便宜啊！
# 埃德森：不信！我现在就订票去！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 乔伊丝分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
# ================================================================================
# {'id': 'gold_00005',
#  'test_index': 66,
#  'dialogue': "Joyce: Check this out!\r\nJoyce: <link>\r\nMichael: That's cheap!\r\nEdson: No way! I'm booking my ticket now!! ",
#  'translated_dialogue': '乔伊丝：看看这个！\n乔伊丝：<链接>\n迈克尔：好便宜啊！\n埃德森：不信！我现在就订票去！',
#  'final_summary': '乔伊丝分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。',
#  'reference_english_summary': 'Edson is booking his ticket now.',
#  'reference_chinese_summary': '埃德森正在订票。',
#  'pipeline': 'translate_then_summarize',
#  'translation_model': 'aya-expanse:32b',
#  'summarization_model': 'aya-expanse:32b',
#  'num_model_calls': 2}

# %%
# Cell 11: Print TS pipeline result clearly

def print_ts_result(result: Dict[str, Any]) -> None:
    print("=== Original Dialogue ===")
    print(result["dialogue"])
    print()

    print("=== Agent 1 Intermediate Output: Translated Chinese Dialogue ===")
    print(result["translated_dialogue"])
    print()

    print("=== Agent 2 Final Output: Chinese Summary ===")
    print(result["final_summary"])
    print()

    print("=== Reference English Summary ===")
    print(result["reference_english_summary"])
    print()

    print("=== Reference Chinese Summary ===")
    print(result["reference_chinese_summary"])
    print()

    print("=== Metadata ===")
    print("Pipeline:", result["pipeline"])
    print("Translation model:", result["translation_model"])
    print("Summarization model:", result["summarization_model"])
    print("Model calls:", result["num_model_calls"])


print_ts_result(result)
# Out:
# === Original Dialogue ===
# Joyce: Check this out!
# Joyce: <link>
# Michael: That's cheap!
# Edson: No way! I'm booking my ticket now!!
#
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 乔伊丝：看看这个！
# 乔伊丝：<链接>
# 迈克尔：好便宜啊！
# 埃德森：不信！我现在就订票去！
#
# === Agent 2 Final Output: Chinese Summary ===
# 乔伊丝分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
#
# === Reference English Summary ===
# Edson is booking his ticket now.
#
# === Reference Chinese Summary ===
# 埃德森正在订票。
#
# === Metadata ===
# Pipeline: translate_then_summarize
# Translation model: aya-expanse:32b
# Summarization model: aya-expanse:32b
# Model calls: 2

# %% [markdown]
# ## 4. Save Results
#
# This saves the intermediate English summary and the final Chinese summary.

# %%
# Cell 12: Reset previous outputs before batch inference

FULL_OUTPUT_PATH.unlink(missing_ok=True)
FINAL_CSV_PATH.unlink(missing_ok=True)
ERROR_OUTPUT_PATH.unlink(missing_ok=True)

print("Previous output files reset.")
print("JSONL output path:", FULL_OUTPUT_PATH)
print("CSV output path:", FINAL_CSV_PATH)
print("Error output path:", ERROR_OUTPUT_PATH)
# Out:
# Previous output files reset.
# JSONL output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.jsonl
# CSV output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.csv
# Error output path: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples_errors.jsonl

# %% [markdown]
# ## 5. Batch Inference with Checkpointing
#
# This cell processes examples one by one and appends each completed ST result to the JSONL output file.
#
# If the notebook stops, already processed examples remain saved.

# %%
# Cell 13: Batch inference with TS pipeline
# Time stamp: 2m 51.7s

MAX_EXAMPLES = 50
SLEEP_SECONDS = 0.2

processed_ids = load_processed_ids(FULL_OUTPUT_PATH)
print(f"Already processed: {len(processed_ids)} examples")

subset = test_data[:MAX_EXAMPLES]

for ex in tqdm(subset, desc="Running TS pipeline"):
    sample_id = str(ex.get("id", "unknown"))

    if sample_id in processed_ids:
        print(f"Skipping already processed sample: {sample_id}")
        continue

    try:
        record = run_ts_pipeline(ex, verbose=True)

        append_jsonl(record, FULL_OUTPUT_PATH)
        processed_ids.add(sample_id)

        time.sleep(SLEEP_SECONDS)

    except Exception as e:
        error_record = {
            "id": sample_id,
            "test_index": ex.get("test_index", ""),
            "error": repr(e),
            "dialogue": ex.get("dialogue", ""),
        }

        append_jsonl(error_record, ERROR_OUTPUT_PATH)
        print(f"Error on {sample_id}: {repr(e)}")

print(f"Finished. Outputs saved to: {FULL_OUTPUT_PATH}")
# Out:
# Already processed: 0 examples
# Running TS pipeline:   0%|          | 0/50 [00:00<?, ?it/s]
# ================================================================================
# Sample ID: gold_00001
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 安妮：你说的对，他骗了我：/
# 艾琳：哦不，发生了什么？
# 简：谁？那马克家伙？
# 安妮：是的，他告诉我他30岁，今天我看了他的护照——他40岁。
# 艾琳：你确定这很重要吗？
# 安妮：他骗了我，艾琳。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 安妮发现马克撒谎了，他实际比他说的年龄大10岁。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00002
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 玛丽：嘿，我有点没钱了，借我几盒好吗？
# 卡特：好的，给我一个小时，我在火车站。
# 玛丽：好，谢谢。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 玛丽向卡特借钱，卡特答应了，一小时后会在火车站见面。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00003
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 蒂娜：我要告诉你一件事，这个阿联酋航空的空乘人员看起来像电影明星一样。
# 阿拉：哦，是的，我知道，这是为了工作需要。
# 阿拉：这就是他们应该有的样子。
# 阿拉：他们非常注重形象。
# 蒂娜：看上去很漂亮，让人很享受观察。
# 蒂娜：而在机场我过得很糟糕，他们在飞机上让我们等了一个小时，最后我只能赶晚上回家的航班。
# 蒂娜：你能想象吗？
# 蒂娜：而且你知道的，这样我们就有了这么一个健谈的飞行员。😉
# 阿拉：哦，可怜的你。
# 阿拉：唉。
# 阿拉：我正在去开会的路上。
# 蒂娜：那个重要的会议吗？
# 阿拉：是的，请为我祈祷。
# 蒂娜：好的，一定要告诉我结果怎么样。
# 阿拉：好的，亲爱的，我们保持联系。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 蒂娜向阿拉诉说在机场的不愉快经历，包括空乘人员的外表和等待时间。阿拉安慰她，并提及自己正前往重要会议。两人约定保持联系。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00004
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 安娜：你睡着了吗？
# 凯瑟琳：还没有。
# 安娜：明天想去看外婆吗？我想她了。
# 凯瑟琳：是啊，那会很好的 :) 我起床时给你打电话。
# 安娜：好吧 :) 睡个好觉，晚安。
# 凯瑟琳：晚安，你也一样。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 安娜和凯瑟琳讨论明天去看外婆，凯瑟琳同意了，并约定起床后打电话给安娜。她们互道晚安。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00005
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 乔伊斯：看看这个！
# 乔伊斯：<链接>
# 迈克尔：好便宜啊！
# 埃德森：不信！我现在就订票去！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 乔伊斯分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00006
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 简：谷歌地图显示至少需要3小时<文件_其他>
# 史蒂文：我以前开车2小时就到了，相信我😄
# 简：但是距离差不多300公里呢...
# 史蒂文：路是新的，我们一定会准时到的^^
# 简：我不想太紧张，我们4点半见面吧，5点太晚了。
# 史蒂文：好吧，如果你真的想，我们可以4点半见。
# 简：谢谢！
# 简：我在正门等吗？
# 史蒂文：正门对我来说很方便；-)
# 史蒂文：再见~
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 简和史蒂文讨论了前往目的地的时间和路线。简担心需要3小时，但史蒂文坚持2小时足够，并保证会准时到达。他们最终约定4点半见面，在正门等待。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00007
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 菲奥娜：你有空吗？
# 蒂娜：有啊，怎么了？
# 菲奥娜：我想为克里斯准备一顿美味的晚餐，想着或许我可以做你那道塔特（馅饼）呢 :)
# 蒂娜：太荣幸了！
# 菲奥娜：是啊，这道菜确实很美味 :) 你能帮我做吗？
# 蒂娜：当然可以！这道菜不难。你准备好了什么吗？
# 菲奥娜：我必须承认，我买了饼皮...
# 蒂娜：哦，也行：P 有点可惜，不过现在太迟了。
# 菲奥娜：我曾经尝试做过馅料，但最后变成了柠檬炒蛋...
# 蒂娜：这种事经常发生，别担心。问题是，一旦你开始加鸡蛋，就不能停下搅拌，不然就会变成炒蛋。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 菲奥娜想做塔特馅饼给克里斯，向蒂娜求助。蒂娜同意帮忙，并解释了制作过程，提到加入鸡蛋需不断搅拌以免成炒蛋。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00008
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 奥拉弗：我们春节有什么安排吗？
# 娜塔莉：我在想一些高雅的活动，比如歌剧之类的。
# 佐伊：要花多少钱？
# 奥拉弗：歌剧不是我的菜。
# 娜塔莉：那你有什么建议？
# 娜塔莉：这张票100美元。
# 奥拉弗：我在想去哪里狂欢。
# 娜塔莉：狂欢听起来很有趣，只要是高雅的就行。
# 佐伊：<文件链接>
# 佐伊：蒂芙尼早餐派对听起来很高雅。
# 奥拉弗：<文件链接>
# 奥拉弗：这样够高雅吗？
# 娜塔莉：：O
# 娜塔莉：这家俱乐部太棒了！
# 佐伊：哇！
# 娜塔莉：我们去苏荷区吧。
# 奥拉弗：我们得赶紧买票。
# 佐伊：好啊。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 奥拉弗询问春节安排，娜塔莉提议高雅活动，如歌剧。后经讨论，三人决定参加蒂芙尼早餐派对，并计划尽快购买门票，地点在苏荷区。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00009
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 约翰：想周三去看《一个明星的诞生》吗？
# 乔安：抱歉，不能。
# 乔安：非常忙。
# 乔安：什么都没时间。
# 约翰：真遗憾。
# 乔安：我周四有空。
# 约翰：我也可以周四。
# 乔安：好！那晚上八点左右？
# 约翰：当然，听起来很棒。
# 约翰：我会看看在哪里放映，然后给你发详情。
# 乔安：好，太好了！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 约翰邀请乔安周三看电影《一个明星的诞生》，但乔安因忙无法前往。两人商定周四晚上八点左右一起看，约翰会告知具体地点。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00010
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 佩顿：我一直让你给我带那个电子游戏。
# 卡梅伦：亲爱的，我没有足够的时间回家。
# 佩顿：你什么时候能回家？
# 卡梅伦：我想我还要再出差一周。
# 佩顿：你不能通过快递把游戏送到吗？：P
# 卡梅伦：别这么刻薄：/
# 佩顿：把工作完成然后尽快回家吧。：P
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 佩顿让卡梅伦带电子游戏，但卡梅伦因出差无暇。佩顿建议快递，卡梅伦表示工作繁忙。佩顿催促他尽快回家。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00011
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 保罗：我刚到家。
#
# 保罗：今天真忙。
#
# 保罗：我把理疗的事给忘了。
#
# 艾玛：哦，不！
#
# 保罗：没关系，我再约个新时间。
#
# 艾玛：我半夜才到家。
#
# 保罗：要我为你准备点吃的吗？
#
# 艾玛：那太好了。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 保罗刚到家，觉得今天很忙，把理疗的事忘了。他想再约新时间，并提议为半夜才到家的艾玛准备食物，艾玛表示同意。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00012
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 哈里斯：你好吗？
# 莱娜：还好，你呢？
# 哈里斯：可以更好。
# 莱娜：怎么了？
# 哈里斯：我朋友青木昨天去世了。
# 莱娜：哎呀！
# 哈里斯：是的。
# 莱娜：发生了什么事？
# 哈里斯：还不确定，我在想最坏的情况...
# 莱娜：太可怕了！
# 哈里斯：是的。
# 莱娜：你永远不知道会发生什么。
# 哈里斯：没错。
# 莱娜：你最近见过她吗？
# 哈里斯：几个月前见过，她在密歇根州生活。
# 莱娜：哦，那很远啊。
# 哈里斯：不算太远，但足够远了。
# 莱娜：是的。
# 哈里斯：我得挂了，妈妈在叫我。
# 莱娜：好吧，再见！保重！
# 哈里斯：好，会注意的。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 哈里斯告诉莱娜他的朋友青木昨天去世了，原因不明。哈里斯感到难过，莱娜安慰他，并提到他们几个月前在密歇根州见面。哈里斯需离开，莱娜告别并表达关心。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00013
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 雅兹：今晚去减肥俱乐部吗？
# 玛丽：嗯，我不想去，但我真的应该去。我最近真是太放纵自己了！
# 雅兹：我也是，巧克力、红酒、蛋糕，你说什么都有！
# 玛丽：好吧，我们还是咬牙去吧。她可能会责备我们，我想。感觉像回到了学校！
# 雅兹：是啊，她就是我们以前的烹饪老师！六点左右见，我来接你！
# 玛丽：好！见了再说！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 雅兹和玛丽讨论今晚是否去减肥俱乐部。两人都承认最近放纵自己，决定去参加，尽管有些不情愿。雅兹会六点左右接玛丽，感觉像回到了学校时代。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00014
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 艾莉：嗨，你在大学吗？
# 阿丽亚：是的。
# 卡米尔：我生病了：/
# 艾莉：糟糕……真不好。
# 艾莉：阿丽亚，我们现在在哪里上课？
# 阿丽亚：二楼的342室。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 艾莉询问阿丽亚是否在大学，并表达了对卡米尔生病的关心。她还问了当前的上课地点，阿丽亚回答是在二楼342室。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00015
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 奈森：<文件_视频>
#
# 艾伦：天啊!!!
#
# 艾伦：😂😂😂😂
#
# 艾伦：哈哈哈哈
#
# 艾伦：你认识她吗？🤣🤣
#
# 艾伦：我猫咪拉屎时的表情就是这样...🤣🤣🤣
#
# 艾伦：<文件_gif>
#
# 艾伦：天使们一定在哭泣 🤭🤭🤭
#
# 艾伦：<文件_gif>
#
# 艾伦：<文件_gif>
#
# 奈森：哈哈哈哈
#
# 奈森：她正在经历一场精神旅程 😉
#
# 奈森：完全不知道，是丹发给我的
#
# 奈森：至少可以说是一场悲剧 😂😂
#
# 艾伦：<文件_gif>
#
# 艾伦：寻找耶稣
#
# 奈森：😂😂😂
#
# 艾伦：太好笑了...哈哈哈哈
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 奈森向艾伦展示了一个视频，艾伦觉得非常好笑，并用一系列GIF表达了自己的反应。他们讨论了视频中女子的表情和行为，认为很滑稽，同时提到猫咪拉屎时的表情相似。奈森透露该视频是丹发送的，并将其描述为一种精神旅程和悲剧。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00016
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 弗雷迪：你在Netflix上看什么？我刚刚看完《广告狂人》。
#
# 凯利：我刚刚看完《王冠》。
#
# 弗雷迪：新剧集应该很快就会来了。
#
# 凯利：天啊！我等不及了！😊
#
# 弗雷迪：同时可以试试《异乡人》或《都铎王朝》。
#
# 吉姆：我在看《我，僵尸》。
#
# 鲍勃：试试《格林》或《萨布里娜》，它们都很棒！
#
# 凯利：它们都太可怕和恶心了！
#
# 鲍勃：我觉得它们很有趣。它们只是电视节目，不要太认真。×
#
# 格雷格：我在看《纸牌屋》，虽然必须承认新系列很无聊。
#
# 迈克：我同意。没有凯文·斯派西就不是同一个节目了！如果你喜欢政治剧，应该试试《白宫群英》。
#
# 格雷格：根据我听说的，Netflix原创的《保镖》很好看。
#
# 玛丽：我有点羞愧地承认我喜欢像《挺身而进》或《绯闻女孩》这样的节目；)
#
# 南希：别羞愧，我也喜欢！我最喜欢的是《绝望主妇》!!!
#
# 玛丽：我知道！我看了两次！
#
# 艾伦：我正在追《老友记》。
#
# 南希：天啊！我以前很喜欢《老友记》！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 群友们在讨论他们在Netflix上观看的节目。弗雷迪刚看完《广告狂人》，凯利看完《王冠》，并期待新剧集。吉姆看《我，僵尸》，鲍勃推荐《格林》和《萨布里娜》，但凯利觉得太可怕。格雷格看《纸牌屋》，迈克建议看《白宫群英》。玛丽喜欢《挺身而进》和《绯闻女孩》，南希也喜欢并推荐《绝望主妇》。艾伦正在看《老友记》。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00017
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 琼斯：嗨。
# 安吉丽娜：嗨。
# 安吉丽娜：好久不见。你最近怎么样？
# 琼斯：我很好。
# 琼斯：你呢？
# 安吉丽娜：我也很好。
# 琼斯：你觉得我们今天下午可以在镇上见面吗？
# 安吉丽娜：当然可以。
# 琼斯：好吧。我会打电话给你确认我们见面的地点。
# 安吉丽娜：好啊。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 琼斯与安吉丽娜久别重逢，约定下午在镇上见面，琼斯将电话确认地点。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00018
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 凯西：<文件_照片>
# 阿米莉亚：这些太漂亮了!!! 你自己做的吗？
# 克里斯汀：哇哦，太棒了
# 阿米莉亚：我也想让我的指甲这样做！
# 凯西：是的，我自己做的：D 买了一款新的指甲油，但天啊，花了我近四个小时，哈哈
# 阿米莉亚：你能给我们也做吗？
# 克里斯汀：求求你！
# 凯西：抱歉，各位... 真是噩梦一样：( 老实说，指甲花四个小时太长了
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 凯西展示了她自己花费四个小时完成的美丽指甲。阿米莉亚和克里斯汀很喜欢，希望凯西也能为她们做，但凯西觉得时间太长，无法满足她们的请求。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00019
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 苏：收到后给我打电话。
# 苏：很重要。
# 史蒂夫：好，我正在打电话。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 苏提醒史蒂夫收到东西后立即打电话，并强调此事重要性。史蒂夫回应正在拨打电话。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00020
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 蒂米：你想邀请谁？
# 杰玛：嗯，有你和你的约会对象:)
# 蒂米：约会对象还不确定，但我会去:) 还有别人吗？
# 杰玛：我在想洛娜和米歇尔。
# 蒂米：还在想着你能收到她们婚礼的邀请吗？
# 杰玛：不是这样的。
# 蒂米：当然是这样；) 只是不想承认；)
# 杰玛：好吧！我想去参加她们的婚宴！
# 蒂米：这样就好:) 有那么难吗？
# 杰玛：是的。
# 蒂米：你觉得你能改变她们的想法吗？
# 杰玛：不知道。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 蒂米和杰玛讨论参加婚礼邀请。杰玛想邀请蒂米、他的约会对象、洛娜和米歇尔。蒂米质疑杰玛是否想收到婚礼邀请，杰玛承认想去参加婚宴，但担心改变不了她们的想法。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00021
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 安：恭喜！！
#
# 安：你们两个都做得很棒！
#
# 苏：谢谢，安。
#
# 朱莉：我很高兴一切结束了！
#
# 朱莉：你真可爱，女孩！
#
# 安：今晚我们来点小庆祝吧！
#
# 苏：我参加。
#
# 朱莉：我也参加!!! 啊
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 安祝贺苏和朱莉，称赞他们表现出色。朱莉高兴一切结束，并赞扬安可爱。大家决定今晚小聚庆祝。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00022
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 史蒂夫：嗨，洗碗机到了。
# 妈妈：好极了，他们给你安装了吗？
# 史蒂夫：是的，他们干得不错。
# 史蒂夫：<文件_照片>
# 妈妈：看起来真不错。
# 史蒂夫：是啊，还很安静。
# 妈妈：这是十二人份的吗？
# 史蒂夫：我觉得是，不过我从来没一次性摆过十二人的晚餐，哈哈。
# 妈妈：不用天天用啦。
# 史蒂夫：每隔一天吧。
# 妈妈：很高兴你喜欢，亲爱的。💕
# 史蒂夫：我很喜欢，谢谢妈妈。💖
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 史蒂夫向妈妈展示了新安装的洗碗机，并分享了其安静和高效的特点。妈妈很开心，认为这是一次好的购买。他们讨论了使用频率，史蒂夫表示每隔一天用一次。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00023
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 玛丽卡：你今天来吗？
# 拉拉：来！
# 玛丽卡：太好了！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 玛丽卡问拉拉今天是否会来，拉拉回答会来，玛丽卡很高兴。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00024
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 米兰达：嗨，S，我们能取消明天的会议吗？
# 斯蒂芬妮：又是吗？发生了什么事？
# 米兰达：我必须工作。
# 斯蒂芬妮：你一天工作20个小时！
# 米兰达：这就是年轻医生所做的事情。
# 斯蒂芬妮：他们把自己活活干死。
# 米兰达：不，他们接近死亡但幸存下来，这使他们永生。
# 斯蒂芬妮：只要你有解释就好了：D
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 米兰达想取消明天的会议，因为她需要工作。斯蒂芬妮表达了对年轻医生过度工作的担忧，但米兰达认为这是他们的选择，并用“接近死亡而幸存”来解释他们的奉献精神。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00025
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 哈维尔：嘿，你知道这附近有没有纹身店的员工会说英语？
# 朱迪：哦，有华沙墨水（Warsaw Ink）。
# 哈维尔：这个名字听起来很酷...你在那里纹过身吗？
# 朱迪：没有，但我女朋友纹过。
# 哈维尔：有照片吗？
# 朱迪：<文件_照片>
# 哈维尔：哇，看起来很棒。
# 哈维尔：她付了多少钱？
# 朱迪：1000。
# 哈维尔：靠！
# 哈维尔：我还是回哥伦比亚纹吧，谢谢。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 哈维尔询问附近有无英语流利的纹身店员工，朱迪推荐华沙墨水，并分享了女友的纹身照片。哈维尔对设计和价格感到惊讶，最终决定在哥伦比亚纹身。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00026
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 山姆：你们拥有一家真的很棒的酒店，伙计们😊
# 杰西卡：谢谢你，山姆😊
# 迈克尔：谢谢，兄弟
# 山姆：我们下个月的酒店房间安排得怎么样了？希望经理能为我们安排最好的房间；)
# 迈克尔：你说得对，山姆
# 迈克尔：你8月15日会来吗？
# 山姆：是的！我们大约下午2点到酒店。
# 杰西卡：我好高兴再见到你们！
# 山姆：我也是😊
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 山姆赞扬了酒店，并询问下个月的房间安排。迈克尔确认了8月15日的入住，山姆表示下午2点抵达。杰西卡期待再次见面。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00027
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 特伦斯：靠，丹尼。你拿了我的钱，对吧？:/
# 丹尼尔：什么，你的钱？！为什么要拿我啊？
# 特伦斯：别装傻。
# 丹尼尔：你是不是把我当成说谎的人了，特里？！
# 特伦斯：我又不是傻子，丹尼。
# 丹尼尔：我也不是小偷！这不酷，兄弟：/
# 特伦斯：……靠，对不起，我刚刚找到了。忘记上个月我放到别处了。
# 丹尼尔：那对你来说是好事。
# 特伦斯：你生气了吗？
# 丹尼尔：你觉得呢？当然，他妈的，我生气了！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 特伦斯指责丹尼尔偷了他的钱，但后来发现是自己记错了位置。丹尼尔感到生气和委屈。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00028
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 娜塔莎：你好，我可以去RER接你。
# 查尔斯：太好了。我刚落地。我想我大约5点半到。我会给你打电话。
# 娜塔莎：好，等你在韦西内特车站时给我打电话。
# 查尔斯：谢谢。见！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 娜塔莎将去RER接查尔斯，他预计下午5点半到达，并在到达韦西内特车站时联系她。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00029
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 梅格：还在学校吗？
# 安：我有额外的数学课。
# 梅格：那什么时候能见你？
# 安：我七点钟到家。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 梅格问安是否还在学校，安说有额外数学课，七点钟到家。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00030
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 皮特：你要哪种口味的酸奶来着？我今天脑子像筛子一样。
# 珍：梨味的，但只有他们有才行。否则不要紧。
# 皮特：我会四处看看。如果没有梨味的，能不能换个别的口味？
# 珍：我不喜欢别的口味。如果没有梨味的，那就什么都不买吧。
# 皮特：好吧。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 皮特询问珍想要哪种口味的酸奶，珍指定梨味，但表示如果没有也可以不买。皮特提议找其他口味，但珍坚持如果没有梨味就不买。最终，皮特同意了。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00031
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 克里斯蒂：派对后你怎么样？
# 凯蒂：真的很累......你呢？
# 克里斯蒂：一样。
# 克里斯蒂：派对很棒！
# 凯蒂：是的，我们玩得很开心！😊
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 克里斯蒂和凯蒂在聚会后感到很累，但她们都认为聚会很棒，玩得很开心。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00032
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 山姆：你明天工作吗？
# 卡拉：不，我放假。
# 山姆：我下午有空，想见面吗？
# 卡拉：嗯，可以。
# 山姆：好，太好了！去米恩伍德怎么样？
# 卡拉：好，那边有家咖啡馆，蛋糕很美味。2点见你吧？
# 山姆：好的，期待中！
# 卡拉：明天见！❤️❤️
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 山姆和卡拉约定明天下午在米恩木德的咖啡馆见面，品尝那里的美味蛋糕。具体时间定在下午2点。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00033
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 乔安娜：想玩点游戏吗？
# 桑迪：什么游戏？
# 乔安娜：也许是迪西特？
# 乔安娜：或者卡卡松？
# 桑迪：为什么不呢？
# 乔安娜：好吧，我会把它们带给你。
# 桑迪：太棒了 :)
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 乔安娜邀请桑迪玩游戏，建议玩《迪西特》或《卡卡松》。桑迪同意，乔安娜将带来游戏。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00034
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 史蒂夫：五分钟前买了新的梦想剧院专辑。希望它不错。
# 罗布：我这儿桌子上就有，准备第一次听了。
# 史蒂夫：好，我晚点告诉你我对它的看法。
# 罗布：我也是。再见！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 史蒂夫刚买了梦想剧院的新专辑，期待中。罗布已有专辑，两人将分享听后感。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00035
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 彼得：你能给我你的美容店链接吗？
# 乔伊：当然可以。
# 乔伊：是这个：https:// *********
# 乔伊：希望你会喜欢，有任何问题都可以问我。
# 彼得：好，让我看看。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 彼得向乔伊索要了她的美容店链接，乔伊提供了网址并表示可随时询问问题。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00036
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 伊森：谁要去看索拉斯特法？
# 诺亚：索拉斯特法！什么时候？
# 诺亚：我完全不知道他们要演出。
# 阿奇：我不去：D。
# 里奥：我当然要去了！
# 伊森：11月21日。
# 诺亚：那是星期三... 嗯...
# 诺亚：我得看看，可能得加班...
# 里奥：别啊！你一定要来。
# 伊森：对，你必须来！
# 阿奇：还有更好的演唱会：P。
# 诺亚：我知道，我真的很想去看他们，但是...
# 里奥：阿奇...：P
# 伊森：别理他：P。
# 诺亚：我会看看，然后告诉你们，错过他们真是太遗憾了。
# 里奥：对！
# 伊森：对！×2
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 伊森邀请大家11月21日去看索拉斯特法的演唱会，诺亚可能因加班无法参加，里奥强烈要求他出席。阿奇不感兴趣，建议其他演唱会。诺亚表示遗憾，会再做决定。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00037
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 布拉德利：哈哈，看，一只猫入侵了古迪逊球场。<文件_其他>
# 吉尔：哈哈哈哈
# 朱莉娅：多可爱的小黑球。
# 吉尔：这是视频：D <文件_其他>
# 朱莉娅：哈哈
# 布拉德利：还有解说：D
# 布拉德利：这是埃弗顿球迷本赛季最精彩的娱乐：D
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 布拉德利、吉尔和朱莉娅讨论了一只入侵古迪逊球场的猫，他们认为这是埃弗顿球迷本赛季最精彩的娱乐。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00038
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 芭芭拉：我已经到家了，你可以过来。
# 肖恩：我能带狗来吗？
# 扎克：我正在来的路上。
# 芭芭拉：当然可以，肖恩。
# 芭芭拉：你想留宿吗？
# 肖恩：太好了！
# 肖恩：我已经考虑过了。
# 芭芭拉：太棒了！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 芭芭拉邀请肖恩和扎克到家里，肖恩可以带狗来，并决定留宿。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00039
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 杰克：兄弟，我刚抽到一个TOTW！
# 杰克：今年第一个！
# 汤姆：恭喜啊！
# 汤姆：要卖掉吗？
# 杰克：是的。
# 杰克：我会让他打一两场比赛。
# 杰克：他不适合我的阵容。
# 汤姆：你会有很多币来买合适的球员。
# 杰克：就是这个计划。
# 杰克：这次我很幸运。
# 汤姆：我今年抽签运气不好。
# 汤姆：一个优秀的球员都没有。
# 杰克：你玩游戏很厉害。
# 杰克：你不需要帮助：P
# 汤姆：我喜欢闪亮的东西：P
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 杰克抽到了今年的第一个TOTW，打算卖掉因为不适合他的阵容。汤姆祝贺了他，并提到自己今年运气不好，没有抽到优秀球员。杰克认为汤姆游戏技巧很好，不需要帮助。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00040
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 菲尔：晚上好，迪娜！非常感谢你寄来这张漂亮卡片。康斯坦丁很高兴！
# 菲尔：这些太阳镜也是你送的吗？
# 迪娜：我以为它们是属于你的凯特里娜！
# 菲尔：不是。她说不是她的。
# 迪娜：也不是我的。看，也许你想要留着它们？
# 迪娜：我好像有太多太阳镜了...
# 迪娜：8-D
# 菲尔：你在哪里找到的？可能属于阿德里安吗？
# 迪娜：在收音机上面的空地方。最里面。
# 迪娜：如果阿德里安想要，没问题！
# 迪娜：:)
# 菲尔：:))
# 迪娜：对的！
# 菲尔：好吧，它们不属于我们任何人，也只有我们开你的车。但我们可以照看这些太阳镜。
# 迪娜：听到很高兴！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 菲尔和迪娜讨论了一副太阳镜的所有权。迪娜在收音机上发现它，可能属于阿德里安。最终，他们决定保管这副太阳镜，如果阿德里安需要可以给他。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00041
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 梅尔：你好！你最近怎么样？
#
# 格洛丽亚：你好，梅尔！我们还好，就是日常的忙碌啦;) 你们呢？
#
# 梅尔：也没什么特别的事。偶尔和孩子们通个电话，或者塔德的妹妹：(( 就这些了。
#
# 格洛丽亚：是啊... 自从孩子们离开家后，生活变得安静了许多。我们需要一些时间去适应。但对你来说一定不容易，尤其是你。
#
# 梅尔：我也不知道。有时候我甚至忘记了我应该想念他们。现在这种宁静的感觉我还挺喜欢的。
#
# 格洛丽亚：也难怪。他们在上大学之前给你带来了不少麻烦。我觉得你现在需要好好恢复一下。
#
# 梅尔：你说得对。但或许我应该感到内疚才对？
#
# 格洛丽亚：别傻了！你是个非常棒的妈妈。
#
# 梅尔：谢谢，格洛丽亚。
#
# 格洛丽亚：反正我很高兴再次听到你的消息。我们真的应该再聚一聚。
#
# 梅尔：太好了！太棒了！
#
# 格洛丽亚：天气正好，很适合烧烤。你觉得呢？
#
# 梅尔：我完全赞同。在我家怎么样？我很乐意。
#
# 格洛丽亚：太好了。我喜欢你的花园。
#
# 梅尔：我们正在考虑扩建露台。我必须给你看看我的设计图，只是几个想法。听听你的看法会很有帮助。
#
# 格洛丽亚：我很乐意。但你知道我对园艺设计之类的事情一无所知。
#
# 梅尔：我们一起看看吧。现在来说说烧烤。周末怎么样？
#
# 格洛丽亚：让我看看日历。这是我们的家庭计划表。名字有点糟糕，不过这个周末我们没问题。下个周末，周六，马克好像写了什么，但我看不清。那这个周六怎么样？
#
# 梅尔：完美。至少我们知道天气会很好。我负责食物，你负责饮料怎么样？
#
# 格洛丽亚：我还会准备一些甜点。
#
# 梅尔：太好了。和你一起总是很轻松。
#
# 格洛丽亚：谢谢！你在想塔德的妹妹吗？
#
# 梅尔：是的，我很担心她。我很高兴她搬到了苏格兰，我不用再忍受她试图管我的家务事了。塔德也感到如释重负。
#
# 格洛丽亚：太好了！我从来没喜欢过她。
#
# 梅尔：没有人喜欢她！反正她已经走了，我们要举办一场非常棒的烧烤聚会。没有她。
#
# 格洛丽亚：是的，我们会很开心的。哦，我太高兴你打来了！
#
# 梅尔：期待周六的烧烤聚会！
#
# 格洛丽亚：再见！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 梅尔和格洛丽亚聊天，讨论各自近况。孩子们离开家后，梅尔享受宁静的生活，格洛丽亚安慰她别内疚。她们计划周末在梅尔家烧烤，并谈到塔德的妹妹搬走后，期待一场愉快的聚会。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00042
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 卡兰：我的三星S8出问题了。
# 韦德：具体是什么问题？
# 卡兰：我只看到黑屏。
# 韦德：你是不是把它掉在地上了？
# 卡兰：我想我知道是怎么回事，之前发生过一次。
# 韦德：真的吗？之前发生了什么？
# 卡兰：它会过热，然后需要一段时间才能重新启动。
# 韦德：这真麻烦。要小心电池，可能会有危险。
# 卡兰：确实会，但我要去商店让他们看看。还在保修期内。
# 韦德：你会不会丢失所有数据？
# 卡兰：不会，我一直备份我的文件。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 卡兰的三星S8出现黑屏问题，可能因过热导致。他计划去商店维修，因仍在保修期内。韦德提醒要注意电池安全，并询问数据备份情况，卡兰表示已定期备份。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00043
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 安娜：妈妈，我肚子疼得厉害。
# 乔安娜：哦，亲爱的，什么时候开始的？
# 安娜：晚上，而且一直没停过：-(
# 乔安娜：是不是你吃了什么不对的东西？
# 安娜：可能吧。我也不确定。
# 乔安娜：早餐吃了什么？
# 安娜：平常吃的那种，麦片加牛奶和一根香蕉。
# 乔安娜：可能是牛奶坏了。
# 安娜：闻起来没什么异味。
# 乔安娜：那可能是香蕉坏了。
# 安娜：不，香蕉很甜。
# 乔安娜：也许你只是需要去上厕所。
# 安娜：不是这个问题。
# 乔安娜：可能过一会儿就会好了。
# 安娜：希望如此：-(
# 安娜：希望是这样。如果不行，我们可能应该去看医生。
# 乔安娜：是的，我觉得也是……
# 安娜：我给你泡一杯热茶，加点新鲜薄荷叶，希望对你有帮助。
# 乔安娜：好啊，我在房间里……
# 安娜：十分钟后就到：-)
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 安娜告诉乔安娜她从晚上开始肚子疼，可能与早餐有关。乔安娜猜测可能是食物变质，建议观察一下。安娜希望自己能好转，否则将去看医生。乔安娜同意并让安娜泡热茶缓解症状。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00044
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 山姆：你在哪里？
# 凯特：楼下。
# 山姆：已经到了吗？
# 凯特：是的，快下来吧。
# 杰夫：我们在接待处旁边的小房间里。
# 凯特：你有没有注意到那个做蛋糕的女人？
# 山姆：有。
# 凯特：你看到了蛋糕吗？
# 山姆：我没太注意，为什么？
# 凯特：上面有一个巨大的阴茎，用杏仁糖或什么的做的。
# 山姆：哈哈哈，真的吗？
# 凯特：当我注意到的时候，我开始笑了，她也笑了。
# 山姆：不错。
# 凯特：我问她做什么，有人订了一个有巨大阴茎、睾丸和巧克力头发蛋糕。
# 山姆：哈哈哈，我一定要看看！
# 凯特：她在楼梯下的小厨房里工作。
# 山姆：对，那里有一个厨房。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 山姆和凯特在讨论楼下的一个聚会。凯特注意到一个做蛋糕的女人，蛋糕上有一个巨大的阴茎。山姆表示好奇并想去看看。他们还在小房间里等待，杰夫提供了更具体的位置。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00045
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 米娅：天啊，他一直谈论那愚蠢的墙。
# 詹妮弗：我觉得他只是老糊涂了。
# 卡琳：不幸的是，这远不止如此。
# 卡琳：这是民粹主义策略，用少数群体来吓唬人们，然后把自己当作唯一的救世主。
# 彼得：卡琳说得对，我认为他并不像我们想象的那样老糊涂和愚蠢。
# 米娅：所以更糟糕了——他是纯粹的邪恶。
# 彼得：可能吧。
# 卡琳：我真的这么认为，因为这已经不只是政治问题了。
# 卡琳：他在破坏地球，试图动摇世界秩序。
# 詹妮弗：但他也很愚蠢。
# 詹妮弗：危险的是他的自信、坚持和无知。
# 卡琳：但我们有机会改变它。
# 卡琳：也许特朗普很快就会下台？
# 米娅：我们拭目以待。
# 米娅：但我们应该竭尽全力赢得下一届选举。
# 卡琳：一切都得做！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 对话中，大家讨论了特朗普的行为和动机。卡琳认为他不仅仅是糊涂，而是利用民粹主义策略来恐吓人们，并自视为救世主。彼得和米娅同意他的行为更邪恶，且在破坏地球和世界秩序。詹妮弗指出他的危险在于自信和无知。他们一致认为需要努力改变现状，包括赢得下一届选举，并希望特朗普很快下台。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00046
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 佩德罗：蝙蝠侠还是超人？
# 亚历克斯：老实说... 都不是。
# 佩德罗：什么？！
# 亚历克斯：我真心喜欢闪灵。
# 佩德罗：闪灵有什么好？：P
# 亚历克斯：兄弟，他几乎可以做任何事。
# 佩德罗：不是任何事。
# 亚历克斯：是的，我确定蝙蝠侠可以跑得同样快——-_-
# 佩德罗：超人类速度？这就是你的论点？
# 亚历克斯：那种速度让他可以进入整个多元宇宙... 你真的不理解他能多强大。
# 佩德罗：是的，我明白你的观点。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 佩德罗和亚历克斯讨论超级英雄。亚历克斯认为闪灵比蝙蝠侠和超人更强，因为他几乎能做任何事，包括拥有超人类的速度，可以进入多元宇宙。佩德罗表示理解但不同意。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00047
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 达米安：你在市中心吗？
# 伊森：是的
# 伊森：怎么了？
# 达米安：能不能帮我买个烤肉串？
# 达米安：我饿得要命
# 伊森：为什么你不给我们俩做点东西吃，嗯？
# 达米安：兄弟，给我点面子，我今天过得很艰难
# 伊森：好吧，好吧
# 伊森：但我真的希望你不要像寄生虫一样
# 达米安：我会改变的，童子军荣誉保证
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 达米安向伊森求助，请求他帮忙买烤肉串，因为他很饿。伊森同意了，但希望达米安不要总是依赖他人。达米安承诺会改变。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00048
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 巴里：我要去参加妇女罢工游行，有没有人感兴趣？
# 杰克：我有兴趣，已经和一些朋友做了计划，你想加入吗？
# 戴夫：我也行，凯利会和我一起来。
# 巴里：我们在校园周围中午见吧。
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 巴里发起妇女罢工游行邀请，杰克、戴夫及凯利响应，午间在校园周边集合。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00049
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 玛莎：嗨，可以问你一个问题吗？
# 奥菲莉亚：我们认识吗？
# 玛莎：不认识，但我可以问你关于你头像中那副隐形眼镜的问题吗？它们很酷，我想买类似的一副。
# 奥菲莉亚：这是来自疯狂隐形眼镜（Crazy Lenses）的产品。他们的价格相当合理，而且发货速度很快。
# 玛莎：谢谢!!! 我会去看看的:)
# 奥菲莉亚：没问题:)
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 玛莎向奥菲莉亚询问了她头像中隐形眼镜的品牌，奥菲莉亚推荐了疯狂隐形眼镜（Crazy Lenses），并称赞其价格合理、发货迅速。玛莎表示感谢并将考虑购买。
# ================================================================================
#
#
# ================================================================================
# Sample ID: gold_00050
# === Agent 1 Intermediate Output: Translated Chinese Dialogue ===
# 琳达：爸爸，我想给妈妈买花！但是我不记得她喜欢哪种了 :(
# 迈克尔：嗯，我相信她喜欢所有的花
# 琳达：这没用啊！我现在在花市呢！
# 迈克尔：那就发几张照片给我看呗
# 琳达：<文件_照片>
# 迈克尔：郁金香不错，玫瑰也行
# 琳达：那康乃馨呢？
# 迈克尔：不，康乃馨太普通了 :D
# 琳达：谢谢爸爸，真的…
# 迈克尔：那自由花呢？她很喜欢这种，这里有吗？
# 琳达：<文件_照片>
# 迈克尔：就选这些吧！
# ================================================================================
#
# === Agent 2 Final Output: Chinese Summary ===
# 琳达想给妈妈买花，向父亲迈克尔求助。迈克尔建议她发照片选择，最终确定了郁金香、玫瑰和自由花。
# ================================================================================
#
# Finished. Outputs saved to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.jsonl

# %% [markdown]
# ## 6. Export Final Summaries to CSV
#
# This file can be used for ROUGE, BERTScore, OmniScore, or manual analysis.
#
# For the ST pipeline, the CSV also includes the intermediate English summary from Agent 1.

# %%
# Cell 14: Export TS summaries to CSV

records = load_jsonl(FULL_OUTPUT_PATH)

rows = []

for record in records:
    if "final_summary" not in record:
        continue

    rows.append({
        "id": record.get("id", ""),
        "test_index": record.get("test_index", ""),
        "dialogue": record.get("dialogue", ""),

        # Intermediate output from Agent 1
        "translated_dialogue": record.get("translated_dialogue", ""),

        # Final output from Agent 2
        "final_summary": record.get("final_summary", ""),

        # References
        "reference_english_summary": record.get("reference_english_summary", ""),
        "reference_chinese_summary": record.get("reference_chinese_summary", ""),

        # Metadata
        "pipeline": record.get("pipeline", "translate_then_summarize"),
        "translation_model": record.get("translation_model", ""),
        "summarization_model": record.get("summarization_model", ""),
        "num_model_calls": record.get("num_model_calls", 2),
    })

df = pd.DataFrame(rows)

if not df.empty:
    df = df.drop_duplicates(subset=["id"], keep="last")

df.to_csv(FINAL_CSV_PATH, index=False, encoding="utf-8-sig")

print(f"Saved final summaries to: {FINAL_CSV_PATH}")
df
# Out:
# Saved final summaries to: C:\Users\FLEXBOY\OneDrive\바탕 화면\yunu\ts_aya32b_50samples.csv
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                                   translated_dialogue  \
# 0   安妮：你说的对，他骗了我：/\n艾琳：哦不，发生了什么？\n简：谁？那马克家伙？\n安妮：是...
# 1   玛丽：嘿，我有点没钱了，借我几盒好吗？\n卡特：好的，给我一个小时，我在火车站。\n玛丽：好...
# 2   蒂娜：我要告诉你一件事，这个阿联酋航空的空乘人员看起来像电影明星一样。\n阿拉：哦，是的，我...
# 3   安娜：你睡着了吗？\n凯瑟琳：还没有。\n安娜：明天想去看外婆吗？我想她了。\n凯瑟琳：是啊...
# 4     乔伊斯：看看这个！\n乔伊斯：<链接>\n迈克尔：好便宜啊！\n埃德森：不信！我现在就订票去！
# 5   简：谷歌地图显示至少需要3小时<文件_其他>\n史蒂文：我以前开车2小时就到了，相信我😄\n...
# 6   菲奥娜：你有空吗？\r\n蒂娜：有啊，怎么了？\r\n菲奥娜：我想为克里斯准备一顿美味的晚餐...
# 7   奥拉弗：我们春节有什么安排吗？\n娜塔莉：我在想一些高雅的活动，比如歌剧之类的。\n佐伊：要...
# 8   约翰：想周三去看《一个明星的诞生》吗？\n乔安：抱歉，不能。\n乔安：非常忙。\n乔安：什么...
# 9   佩顿：我一直让你给我带那个电子游戏。\n卡梅伦：亲爱的，我没有足够的时间回家。\n佩顿：你什...
# 10  保罗：我刚到家。\n\n保罗：今天真忙。\n\n保罗：我把理疗的事给忘了。\n\n艾玛：哦，...
# 11  哈里斯：你好吗？\n莱娜：还好，你呢？\n哈里斯：可以更好。\n莱娜：怎么了？\n哈里斯：我...
# 12  雅兹：今晚去减肥俱乐部吗？\n玛丽：嗯，我不想去，但我真的应该去。我最近真是太放纵自己了！\...
# 13  艾莉：嗨，你在大学吗？\n阿丽亚：是的。\n卡米尔：我生病了：/\n艾莉：糟糕……真不好。\...
# 14  奈森：<文件_视频>\n\n艾伦：天啊!!!\n\n艾伦：😂😂😂😂\n\n艾伦：哈哈哈哈\n...
# 15  弗雷迪：你在Netflix上看什么？我刚刚看完《广告狂人》。\n\n凯利：我刚刚看完《王冠》...
# 16  琼斯：嗨。\n安吉丽娜：嗨。\n安吉丽娜：好久不见。你最近怎么样？\n琼斯：我很好。\n琼斯...
# 17  凯西：<文件_照片>\n阿米莉亚：这些太漂亮了!!! 你自己做的吗？\n克里斯汀：哇哦，太棒...
# 18                 苏：收到后给我打电话。\n苏：很重要。\n史蒂夫：好，我正在打电话。
# 19  蒂米：你想邀请谁？\n杰玛：嗯，有你和你的约会对象:)\n蒂米：约会对象还不确定，但我会去:...
# 20  安：恭喜！！\n\n安：你们两个都做得很棒！\n\n苏：谢谢，安。\n\n朱莉：我很高兴一切...
# 21  史蒂夫：嗨，洗碗机到了。\n妈妈：好极了，他们给你安装了吗？\n史蒂夫：是的，他们干得不错。...
# 22                        玛丽卡：你今天来吗？\n拉拉：来！\n玛丽卡：太好了！
# 23  米兰达：嗨，S，我们能取消明天的会议吗？\n斯蒂芬妮：又是吗？发生了什么事？\n米兰达：我必...
# 24  哈维尔：嘿，你知道这附近有没有纹身店的员工会说英语？\n朱迪：哦，有华沙墨水（Warsaw ...
# 25  山姆：你们拥有一家真的很棒的酒店，伙计们😊\n杰西卡：谢谢你，山姆😊\n迈克尔：谢谢，兄弟\...
# 26  特伦斯：靠，丹尼。你拿了我的钱，对吧？:/\n丹尼尔：什么，你的钱？！为什么要拿我啊？\n特...
# 27  娜塔莎：你好，我可以去RER接你。\n查尔斯：太好了。我刚落地。我想我大约5点半到。我会给你...
# 28    梅格：还在学校吗？\n安：我有额外的数学课。\n梅格：那什么时候能见你？\n安：我七点钟到家。
# 29  皮特：你要哪种口味的酸奶来着？我今天脑子像筛子一样。\n珍：梨味的，但只有他们有才行。否则不...
# 30  克里斯蒂：派对后你怎么样？\n凯蒂：真的很累......你呢？\n克里斯蒂：一样。\n克里斯...
# 31  山姆：你明天工作吗？\n卡拉：不，我放假。\n山姆：我下午有空，想见面吗？\n卡拉：嗯，可以...
# 32  乔安娜：想玩点游戏吗？\n桑迪：什么游戏？\n乔安娜：也许是迪西特？\n乔安娜：或者卡卡松？...
# 33  史蒂夫：五分钟前买了新的梦想剧院专辑。希望它不错。\n罗布：我这儿桌子上就有，准备第一次听了...
# 34  彼得：你能给我你的美容店链接吗？\n乔伊：当然可以。\n乔伊：是这个：https:// **...
# 35  伊森：谁要去看索拉斯特法？\n诺亚：索拉斯特法！什么时候？\n诺亚：我完全不知道他们要演出。...
# 36  布拉德利：哈哈，看，一只猫入侵了古迪逊球场。<文件_其他>\n吉尔：哈哈哈哈\n朱莉娅：多可...
# 37  芭芭拉：我已经到家了，你可以过来。\n肖恩：我能带狗来吗？\n扎克：我正在来的路上。\n芭芭...
# 38  杰克：兄弟，我刚抽到一个TOTW！\n杰克：今年第一个！\n汤姆：恭喜啊！\n汤姆：要卖掉吗...
# 39  菲尔：晚上好，迪娜！非常感谢你寄来这张漂亮卡片。康斯坦丁很高兴！\n菲尔：这些太阳镜也是你送...
# 40  梅尔：你好！你最近怎么样？\n\n格洛丽亚：你好，梅尔！我们还好，就是日常的忙碌啦;) 你们...
# 41  卡兰：我的三星S8出问题了。\n韦德：具体是什么问题？\n卡兰：我只看到黑屏。\n韦德：你是...
# 42  安娜：妈妈，我肚子疼得厉害。\n乔安娜：哦，亲爱的，什么时候开始的？\n安娜：晚上，而且一直...
# 43  山姆：你在哪里？\n凯特：楼下。\n山姆：已经到了吗？\n凯特：是的，快下来吧。\n杰夫：我...
# 44  米娅：天啊，他一直谈论那愚蠢的墙。\n詹妮弗：我觉得他只是老糊涂了。\n卡琳：不幸的是，这远...
# 45  佩德罗：蝙蝠侠还是超人？\n亚历克斯：老实说... 都不是。\n佩德罗：什么？！\n亚历克斯...
# 46  达米安：你在市中心吗？\n伊森：是的\n伊森：怎么了？\n达米安：能不能帮我买个烤肉串？\n...
# 47  巴里：我要去参加妇女罢工游行，有没有人感兴趣？\n杰克：我有兴趣，已经和一些朋友做了计划，你...
# 48  玛莎：嗨，可以问你一个问题吗？\n奥菲莉亚：我们认识吗？\n玛莎：不认识，但我可以问你关于你...
# 49  琳达：爸爸，我想给妈妈买花！但是我不记得她喜欢哪种了 :(\n迈克尔：嗯，我相信她喜欢所有的...
#
#                                         final_summary  \
# 0                            安妮发现马克撒谎了，他实际比他说的年龄大10岁。
# 1                          玛丽向卡特借钱，卡特答应了，一小时后会在火车站见面。
# 2   蒂娜向阿拉诉说在机场的不愉快经历，包括空乘人员的外表和等待时间。阿拉安慰她，并提及自己正前往...
# 3          安娜和凯瑟琳讨论明天去看外婆，凯瑟琳同意了，并约定起床后打电话给安娜。她们互道晚安。
# 4               乔伊斯分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
# 5   简和史蒂文讨论了前往目的地的时间和路线。简担心需要3小时，但史蒂文坚持2小时足够，并保证会准...
# 6   菲奥娜想做塔特馅饼给克里斯，向蒂娜求助。蒂娜同意帮忙，并解释了制作过程，提到加入鸡蛋需不断搅...
# 7   奥拉弗询问春节安排，娜塔莉提议高雅活动，如歌剧。后经讨论，三人决定参加蒂芙尼早餐派对，并计划...
# 8   约翰邀请乔安周三看电影《一个明星的诞生》，但乔安因忙无法前往。两人商定周四晚上八点左右一起看...
# 9   佩顿让卡梅伦带电子游戏，但卡梅伦因出差无暇。佩顿建议快递，卡梅伦表示工作繁忙。佩顿催促他尽快回家。
# 10  保罗刚到家，觉得今天很忙，把理疗的事忘了。他想再约新时间，并提议为半夜才到家的艾玛准备食物，...
# 11  哈里斯告诉莱娜他的朋友青木昨天去世了，原因不明。哈里斯感到难过，莱娜安慰他，并提到他们几个月...
# 12  雅兹和玛丽讨论今晚是否去减肥俱乐部。两人都承认最近放纵自己，决定去参加，尽管有些不情愿。雅兹...
# 13  艾莉询问阿丽亚是否在大学，并表达了对卡米尔生病的关心。她还问了当前的上课地点，阿丽亚回答是在...
# 14  奈森向艾伦展示了一个视频，艾伦觉得非常好笑，并用一系列GIF表达了自己的反应。他们讨论了视频...
# 15  群友们在讨论他们在Netflix上观看的节目。弗雷迪刚看完《广告狂人》，凯利看完《王冠》，并...
# 16                   琼斯与安吉丽娜久别重逢，约定下午在镇上见面，琼斯将电话确认地点。
# 17  凯西展示了她自己花费四个小时完成的美丽指甲。阿米莉亚和克里斯汀很喜欢，希望凯西也能为她们做，...
# 18             苏提醒史蒂夫收到东西后立即打电话，并强调此事重要性。史蒂夫回应正在拨打电话。
# 19  蒂米和杰玛讨论参加婚礼邀请。杰玛想邀请蒂米、他的约会对象、洛娜和米歇尔。蒂米质疑杰玛是否想收...
# 20       安祝贺苏和朱莉，称赞他们表现出色。朱莉高兴一切结束，并赞扬安可爱。大家决定今晚小聚庆祝。
# 21  史蒂夫向妈妈展示了新安装的洗碗机，并分享了其安静和高效的特点。妈妈很开心，认为这是一次好的购...
# 22                        玛丽卡问拉拉今天是否会来，拉拉回答会来，玛丽卡很高兴。
# 23  米兰达想取消明天的会议，因为她需要工作。斯蒂芬妮表达了对年轻医生过度工作的担忧，但米兰达认为...
# 24  哈维尔询问附近有无英语流利的纹身店员工，朱迪推荐华沙墨水，并分享了女友的纹身照片。哈维尔对设...
# 25  山姆赞扬了酒店，并询问下个月的房间安排。迈克尔确认了8月15日的入住，山姆表示下午2点抵达。...
# 26            特伦斯指责丹尼尔偷了他的钱，但后来发现是自己记错了位置。丹尼尔感到生气和委屈。
# 27            娜塔莎将去RER接查尔斯，他预计下午5点半到达，并在到达韦西内特车站时联系她。
# 28                         梅格问安是否还在学校，安说有额外数学课，七点钟到家。
# 29  皮特询问珍想要哪种口味的酸奶，珍指定梨味，但表示如果没有也可以不买。皮特提议找其他口味，但珍...
# 30                  克里斯蒂和凯蒂在聚会后感到很累，但她们都认为聚会很棒，玩得很开心。
# 31       山姆和卡拉约定明天下午在米恩木德的咖啡馆见面，品尝那里的美味蛋糕。具体时间定在下午2点。
# 32           乔安娜邀请桑迪玩游戏，建议玩《迪西特》或《卡卡松》。桑迪同意，乔安娜将带来游戏。
# 33                史蒂夫刚买了梦想剧院的新专辑，期待中。罗布已有专辑，两人将分享听后感。
# 34                 彼得向乔伊索要了她的美容店链接，乔伊提供了网址并表示可随时询问问题。
# 35  伊森邀请大家11月21日去看索拉斯特法的演唱会，诺亚可能因加班无法参加，里奥强烈要求他出席。...
# 36    布拉德利、吉尔和朱莉娅讨论了一只入侵古迪逊球场的猫，他们认为这是埃弗顿球迷本赛季最精彩的娱乐。
# 37                       芭芭拉邀请肖恩和扎克到家里，肖恩可以带狗来，并决定留宿。
# 38  杰克抽到了今年的第一个TOTW，打算卖掉因为不适合他的阵容。汤姆祝贺了他，并提到自己今年运气...
# 39  菲尔和迪娜讨论了一副太阳镜的所有权。迪娜在收音机上发现它，可能属于阿德里安。最终，他们决定保...
# 40  梅尔和格洛丽亚聊天，讨论各自近况。孩子们离开家后，梅尔享受宁静的生活，格洛丽亚安慰她别内疚。...
# 41  卡兰的三星S8出现黑屏问题，可能因过热导致。他计划去商店维修，因仍在保修期内。韦德提醒要注意...
# 42  安娜告诉乔安娜她从晚上开始肚子疼，可能与早餐有关。乔安娜猜测可能是食物变质，建议观察一下。安...
# 43  山姆和凯特在讨论楼下的一个聚会。凯特注意到一个做蛋糕的女人，蛋糕上有一个巨大的阴茎。山姆表示...
# 44  对话中，大家讨论了特朗普的行为和动机。卡琳认为他不仅仅是糊涂，而是利用民粹主义策略来恐吓人们...
# 45  佩德罗和亚历克斯讨论超级英雄。亚历克斯认为闪灵比蝙蝠侠和超人更强，因为他几乎能做任何事，包括...
# 46  达米安向伊森求助，请求他帮忙买烤肉串，因为他很饿。伊森同意了，但希望达米安不要总是依赖他人。...
# 47                 巴里发起妇女罢工游行邀请，杰克、戴夫及凯利响应，午间在校园周边集合。
# 48  玛莎向奥菲莉亚询问了她头像中隐形眼镜的品牌，奥菲莉亚推荐了疯狂隐形眼镜（Crazy Lens...
# 49     琳达想给妈妈买花，向父亲迈克尔求助。迈克尔建议她发照片选择，最终确定了郁金香、玫瑰和自由花。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary  \
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
#
#                     pipeline translation_model summarization_model  \
# 0   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 1   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 2   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 3   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 4   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 5   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 6   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 7   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 8   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 9   translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 10  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 11  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 12  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 13  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 14  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 15  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 16  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 17  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 18  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 19  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 20  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 21  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 22  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 23  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 24  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 25  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 26  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 27  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 28  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 29  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 30  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 31  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 32  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 33  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 34  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 35  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 36  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 37  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 38  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 39  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 40  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 41  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 42  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 43  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 44  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 45  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 46  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 47  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 48  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
# 49  translate_then_summarize   aya-expanse:32b     aya-expanse:32b
#
#     num_model_calls
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
# 5                 2
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                2
# 11                2
# 12                2
# 13                2
# 14                2
# 15                2
# 16                2
# 17                2
# 18                2
# 19                2
# 20                2
# 21                2
# 22                2
# 23                2
# 24                2
# 25                2
# 26                2
# 27                2
# 28                2
# 29                2
# 30                2
# 31                2
# 32                2
# 33                2
# 34                2
# 35                2
# 36                2
# 37                2
# 38                2
# 39                2
# 40                2
# 41                2
# 42                2
# 43                2
# 44                2
# 45                2
# 46                2
# 47                2
# 48                2
# 49                2

# %%
# Cell 15: Compare TS outputs with references

comparison_columns = [
    "id",
    "test_index",
    "translated_dialogue",
    "final_summary",
    "reference_chinese_summary",
]

comparison_df = df[comparison_columns].copy()

comparison_df
# Out:
#             id  test_index                                translated_dialogue  \
# 0   gold_00001          23  安妮：你说的对，他骗了我：/\n艾琳：哦不，发生了什么？\n简：谁？那马克家伙？\n安妮：是...
# 1   gold_00002          30  玛丽：嘿，我有点没钱了，借我几盒好吗？\n卡特：好的，给我一个小时，我在火车站。\n玛丽：好...
# 2   gold_00003          39  蒂娜：我要告诉你一件事，这个阿联酋航空的空乘人员看起来像电影明星一样。\n阿拉：哦，是的，我...
# 3   gold_00004          65  安娜：你睡着了吗？\n凯瑟琳：还没有。\n安娜：明天想去看外婆吗？我想她了。\n凯瑟琳：是啊...
# 4   gold_00005          66    乔伊斯：看看这个！\n乔伊斯：<链接>\n迈克尔：好便宜啊！\n埃德森：不信！我现在就订票去！
# 5   gold_00006          67  简：谷歌地图显示至少需要3小时<文件_其他>\n史蒂文：我以前开车2小时就到了，相信我😄\n...
# 6   gold_00007          78  菲奥娜：你有空吗？\r\n蒂娜：有啊，怎么了？\r\n菲奥娜：我想为克里斯准备一顿美味的晚餐...
# 7   gold_00008          86  奥拉弗：我们春节有什么安排吗？\n娜塔莉：我在想一些高雅的活动，比如歌剧之类的。\n佐伊：要...
# 8   gold_00009         120  约翰：想周三去看《一个明星的诞生》吗？\n乔安：抱歉，不能。\n乔安：非常忙。\n乔安：什么...
# 9   gold_00010         137  佩顿：我一直让你给我带那个电子游戏。\n卡梅伦：亲爱的，我没有足够的时间回家。\n佩顿：你什...
# 10  gold_00011         139  保罗：我刚到家。\n\n保罗：今天真忙。\n\n保罗：我把理疗的事给忘了。\n\n艾玛：哦，...
# 11  gold_00012         192  哈里斯：你好吗？\n莱娜：还好，你呢？\n哈里斯：可以更好。\n莱娜：怎么了？\n哈里斯：我...
# 12  gold_00013         210  雅兹：今晚去减肥俱乐部吗？\n玛丽：嗯，我不想去，但我真的应该去。我最近真是太放纵自己了！\...
# 13  gold_00014         211  艾莉：嗨，你在大学吗？\n阿丽亚：是的。\n卡米尔：我生病了：/\n艾莉：糟糕……真不好。\...
# 14  gold_00015         212  奈森：<文件_视频>\n\n艾伦：天啊!!!\n\n艾伦：😂😂😂😂\n\n艾伦：哈哈哈哈\n...
# 15  gold_00016         215  弗雷迪：你在Netflix上看什么？我刚刚看完《广告狂人》。\n\n凯利：我刚刚看完《王冠》...
# 16  gold_00017         244  琼斯：嗨。\n安吉丽娜：嗨。\n安吉丽娜：好久不见。你最近怎么样？\n琼斯：我很好。\n琼斯...
# 17  gold_00018         285  凯西：<文件_照片>\n阿米莉亚：这些太漂亮了!!! 你自己做的吗？\n克里斯汀：哇哦，太棒...
# 18  gold_00019         319                 苏：收到后给我打电话。\n苏：很重要。\n史蒂夫：好，我正在打电话。
# 19  gold_00020         346  蒂米：你想邀请谁？\n杰玛：嗯，有你和你的约会对象:)\n蒂米：约会对象还不确定，但我会去:...
# 20  gold_00021         355  安：恭喜！！\n\n安：你们两个都做得很棒！\n\n苏：谢谢，安。\n\n朱莉：我很高兴一切...
# 21  gold_00022         367  史蒂夫：嗨，洗碗机到了。\n妈妈：好极了，他们给你安装了吗？\n史蒂夫：是的，他们干得不错。...
# 22  gold_00023         393                        玛丽卡：你今天来吗？\n拉拉：来！\n玛丽卡：太好了！
# 23  gold_00024         417  米兰达：嗨，S，我们能取消明天的会议吗？\n斯蒂芬妮：又是吗？发生了什么事？\n米兰达：我必...
# 24  gold_00025         432  哈维尔：嘿，你知道这附近有没有纹身店的员工会说英语？\n朱迪：哦，有华沙墨水（Warsaw ...
# 25  gold_00026         433  山姆：你们拥有一家真的很棒的酒店，伙计们😊\n杰西卡：谢谢你，山姆😊\n迈克尔：谢谢，兄弟\...
# 26  gold_00027         442  特伦斯：靠，丹尼。你拿了我的钱，对吧？:/\n丹尼尔：什么，你的钱？！为什么要拿我啊？\n特...
# 27  gold_00028         499  娜塔莎：你好，我可以去RER接你。\n查尔斯：太好了。我刚落地。我想我大约5点半到。我会给你...
# 28  gold_00029         528    梅格：还在学校吗？\n安：我有额外的数学课。\n梅格：那什么时候能见你？\n安：我七点钟到家。
# 29  gold_00030         532  皮特：你要哪种口味的酸奶来着？我今天脑子像筛子一样。\n珍：梨味的，但只有他们有才行。否则不...
# 30  gold_00031         536  克里斯蒂：派对后你怎么样？\n凯蒂：真的很累......你呢？\n克里斯蒂：一样。\n克里斯...
# 31  gold_00032         537  山姆：你明天工作吗？\n卡拉：不，我放假。\n山姆：我下午有空，想见面吗？\n卡拉：嗯，可以...
# 32  gold_00033         544  乔安娜：想玩点游戏吗？\n桑迪：什么游戏？\n乔安娜：也许是迪西特？\n乔安娜：或者卡卡松？...
# 33  gold_00034         548  史蒂夫：五分钟前买了新的梦想剧院专辑。希望它不错。\n罗布：我这儿桌子上就有，准备第一次听了...
# 34  gold_00035         551  彼得：你能给我你的美容店链接吗？\n乔伊：当然可以。\n乔伊：是这个：https:// **...
# 35  gold_00036         590  伊森：谁要去看索拉斯特法？\n诺亚：索拉斯特法！什么时候？\n诺亚：我完全不知道他们要演出。...
# 36  gold_00037         598  布拉德利：哈哈，看，一只猫入侵了古迪逊球场。<文件_其他>\n吉尔：哈哈哈哈\n朱莉娅：多可...
# 37  gold_00038         605  芭芭拉：我已经到家了，你可以过来。\n肖恩：我能带狗来吗？\n扎克：我正在来的路上。\n芭芭...
# 38  gold_00039         616  杰克：兄弟，我刚抽到一个TOTW！\n杰克：今年第一个！\n汤姆：恭喜啊！\n汤姆：要卖掉吗...
# 39  gold_00040         621  菲尔：晚上好，迪娜！非常感谢你寄来这张漂亮卡片。康斯坦丁很高兴！\n菲尔：这些太阳镜也是你送...
# 40  gold_00041         635  梅尔：你好！你最近怎么样？\n\n格洛丽亚：你好，梅尔！我们还好，就是日常的忙碌啦;) 你们...
# 41  gold_00042         649  卡兰：我的三星S8出问题了。\n韦德：具体是什么问题？\n卡兰：我只看到黑屏。\n韦德：你是...
# 42  gold_00043         676  安娜：妈妈，我肚子疼得厉害。\n乔安娜：哦，亲爱的，什么时候开始的？\n安娜：晚上，而且一直...
# 43  gold_00044         678  山姆：你在哪里？\n凯特：楼下。\n山姆：已经到了吗？\n凯特：是的，快下来吧。\n杰夫：我...
# 44  gold_00045         690  米娅：天啊，他一直谈论那愚蠢的墙。\n詹妮弗：我觉得他只是老糊涂了。\n卡琳：不幸的是，这远...
# 45  gold_00046         711  佩德罗：蝙蝠侠还是超人？\n亚历克斯：老实说... 都不是。\n佩德罗：什么？！\n亚历克斯...
# 46  gold_00047         737  达米安：你在市中心吗？\n伊森：是的\n伊森：怎么了？\n达米安：能不能帮我买个烤肉串？\n...
# 47  gold_00048         767  巴里：我要去参加妇女罢工游行，有没有人感兴趣？\n杰克：我有兴趣，已经和一些朋友做了计划，你...
# 48  gold_00049         799  玛莎：嗨，可以问你一个问题吗？\n奥菲莉亚：我们认识吗？\n玛莎：不认识，但我可以问你关于你...
# 49  gold_00050         800  琳达：爸爸，我想给妈妈买花！但是我不记得她喜欢哪种了 :(\n迈克尔：嗯，我相信她喜欢所有的...
#
#                                         final_summary  \
# 0                            安妮发现马克撒谎了，他实际比他说的年龄大10岁。
# 1                          玛丽向卡特借钱，卡特答应了，一小时后会在火车站见面。
# 2   蒂娜向阿拉诉说在机场的不愉快经历，包括空乘人员的外表和等待时间。阿拉安慰她，并提及自己正前往...
# 3          安娜和凯瑟琳讨论明天去看外婆，凯瑟琳同意了，并约定起床后打电话给安娜。她们互道晚安。
# 4               乔伊斯分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
# 5   简和史蒂文讨论了前往目的地的时间和路线。简担心需要3小时，但史蒂文坚持2小时足够，并保证会准...
# 6   菲奥娜想做塔特馅饼给克里斯，向蒂娜求助。蒂娜同意帮忙，并解释了制作过程，提到加入鸡蛋需不断搅...
# 7   奥拉弗询问春节安排，娜塔莉提议高雅活动，如歌剧。后经讨论，三人决定参加蒂芙尼早餐派对，并计划...
# 8   约翰邀请乔安周三看电影《一个明星的诞生》，但乔安因忙无法前往。两人商定周四晚上八点左右一起看...
# 9   佩顿让卡梅伦带电子游戏，但卡梅伦因出差无暇。佩顿建议快递，卡梅伦表示工作繁忙。佩顿催促他尽快回家。
# 10  保罗刚到家，觉得今天很忙，把理疗的事忘了。他想再约新时间，并提议为半夜才到家的艾玛准备食物，...
# 11  哈里斯告诉莱娜他的朋友青木昨天去世了，原因不明。哈里斯感到难过，莱娜安慰他，并提到他们几个月...
# 12  雅兹和玛丽讨论今晚是否去减肥俱乐部。两人都承认最近放纵自己，决定去参加，尽管有些不情愿。雅兹...
# 13  艾莉询问阿丽亚是否在大学，并表达了对卡米尔生病的关心。她还问了当前的上课地点，阿丽亚回答是在...
# 14  奈森向艾伦展示了一个视频，艾伦觉得非常好笑，并用一系列GIF表达了自己的反应。他们讨论了视频...
# 15  群友们在讨论他们在Netflix上观看的节目。弗雷迪刚看完《广告狂人》，凯利看完《王冠》，并...
# 16                   琼斯与安吉丽娜久别重逢，约定下午在镇上见面，琼斯将电话确认地点。
# 17  凯西展示了她自己花费四个小时完成的美丽指甲。阿米莉亚和克里斯汀很喜欢，希望凯西也能为她们做，...
# 18             苏提醒史蒂夫收到东西后立即打电话，并强调此事重要性。史蒂夫回应正在拨打电话。
# 19  蒂米和杰玛讨论参加婚礼邀请。杰玛想邀请蒂米、他的约会对象、洛娜和米歇尔。蒂米质疑杰玛是否想收...
# 20       安祝贺苏和朱莉，称赞他们表现出色。朱莉高兴一切结束，并赞扬安可爱。大家决定今晚小聚庆祝。
# 21  史蒂夫向妈妈展示了新安装的洗碗机，并分享了其安静和高效的特点。妈妈很开心，认为这是一次好的购...
# 22                        玛丽卡问拉拉今天是否会来，拉拉回答会来，玛丽卡很高兴。
# 23  米兰达想取消明天的会议，因为她需要工作。斯蒂芬妮表达了对年轻医生过度工作的担忧，但米兰达认为...
# 24  哈维尔询问附近有无英语流利的纹身店员工，朱迪推荐华沙墨水，并分享了女友的纹身照片。哈维尔对设...
# 25  山姆赞扬了酒店，并询问下个月的房间安排。迈克尔确认了8月15日的入住，山姆表示下午2点抵达。...
# 26            特伦斯指责丹尼尔偷了他的钱，但后来发现是自己记错了位置。丹尼尔感到生气和委屈。
# 27            娜塔莎将去RER接查尔斯，他预计下午5点半到达，并在到达韦西内特车站时联系她。
# 28                         梅格问安是否还在学校，安说有额外数学课，七点钟到家。
# 29  皮特询问珍想要哪种口味的酸奶，珍指定梨味，但表示如果没有也可以不买。皮特提议找其他口味，但珍...
# 30                  克里斯蒂和凯蒂在聚会后感到很累，但她们都认为聚会很棒，玩得很开心。
# 31       山姆和卡拉约定明天下午在米恩木德的咖啡馆见面，品尝那里的美味蛋糕。具体时间定在下午2点。
# 32           乔安娜邀请桑迪玩游戏，建议玩《迪西特》或《卡卡松》。桑迪同意，乔安娜将带来游戏。
# 33                史蒂夫刚买了梦想剧院的新专辑，期待中。罗布已有专辑，两人将分享听后感。
# 34                 彼得向乔伊索要了她的美容店链接，乔伊提供了网址并表示可随时询问问题。
# 35  伊森邀请大家11月21日去看索拉斯特法的演唱会，诺亚可能因加班无法参加，里奥强烈要求他出席。...
# 36    布拉德利、吉尔和朱莉娅讨论了一只入侵古迪逊球场的猫，他们认为这是埃弗顿球迷本赛季最精彩的娱乐。
# 37                       芭芭拉邀请肖恩和扎克到家里，肖恩可以带狗来，并决定留宿。
# 38  杰克抽到了今年的第一个TOTW，打算卖掉因为不适合他的阵容。汤姆祝贺了他，并提到自己今年运气...
# 39  菲尔和迪娜讨论了一副太阳镜的所有权。迪娜在收音机上发现它，可能属于阿德里安。最终，他们决定保...
# 40  梅尔和格洛丽亚聊天，讨论各自近况。孩子们离开家后，梅尔享受宁静的生活，格洛丽亚安慰她别内疚。...
# 41  卡兰的三星S8出现黑屏问题，可能因过热导致。他计划去商店维修，因仍在保修期内。韦德提醒要注意...
# 42  安娜告诉乔安娜她从晚上开始肚子疼，可能与早餐有关。乔安娜猜测可能是食物变质，建议观察一下。安...
# 43  山姆和凯特在讨论楼下的一个聚会。凯特注意到一个做蛋糕的女人，蛋糕上有一个巨大的阴茎。山姆表示...
# 44  对话中，大家讨论了特朗普的行为和动机。卡琳认为他不仅仅是糊涂，而是利用民粹主义策略来恐吓人们...
# 45  佩德罗和亚历克斯讨论超级英雄。亚历克斯认为闪灵比蝙蝠侠和超人更强，因为他几乎能做任何事，包括...
# 46  达米安向伊森求助，请求他帮忙买烤肉串，因为他很饿。伊森同意了，但希望达米安不要总是依赖他人。...
# 47                 巴里发起妇女罢工游行邀请，杰克、戴夫及凯利响应，午间在校园周边集合。
# 48  玛莎向奥菲莉亚询问了她头像中隐形眼镜的品牌，奥菲莉亚推荐了疯狂隐形眼镜（Crazy Lens...
# 49     琳达想给妈妈买花，向父亲迈克尔求助。迈克尔建议她发照片选择，最终确定了郁金香、玫瑰和自由花。
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。

# %%
# Cell 16: Inspect TS outputs

if not df.empty:
    inspection_columns = [
        "id",
        "test_index",
        "dialogue",
        "translated_dialogue",
        "final_summary",
        "reference_english_summary",
        "reference_chinese_summary",
    ]

    inspection_df = df[inspection_columns].copy()
    display(inspection_df)
else:
    print("No results found.")
# Out:
#             id  test_index                                           dialogue  \
# 0   gold_00001          23  Anne: You were right, he was lying to me :/\nI...
# 1   gold_00002          30  Mary: hey, im kinda broke, lend me a few box\r...
# 2   gold_00003          39  Tina: I'll tell you something, this Emirate st...
# 3   gold_00004          65  Ana: You sleeping?\r\nCatherine: Not yet.\r\nA...
# 4   gold_00005          66  Joyce: Check this out!\r\nJoyce: <link>\r\nMic...
# 5   gold_00006          67  Jane: google maps says it is at least 3h <file...
# 6   gold_00007          78  Fiona: Are you free?\r\nTina: Yes, what's up?\...
# 7   gold_00008          86  Olafur: are we doing anything for New Year's E...
# 8   gold_00009         120  John: wanna go see "A Star is Born" on Wed?\r\...
# 9   gold_00010         137  Peyton: I have been asking you to bring that v...
# 10  gold_00011         139  Paul: I just came back home\r\nPaul: What a bu...
# 11  gold_00012         192  Harris: How are U?\r\nLena: Fine, U?\r\nHarris...
# 12  gold_00013         210  Yaz: Going to slimming club tonight?\r\nMary: ...
# 13  gold_00014         211  Ellie: hey, are you at the university?\r\nAali...
# 14  gold_00015         212  Nathan: <file_video>\r\nAaron: OMG!!! \r\nAaro...
# 15  gold_00016         215  Freddie: What are you watching on Netflix? I'v...
# 16  gold_00017         244  Jones: Hey.\r\nAngelina: Hey.\r\nAngelina: Lon...
# 17  gold_00018         285  Casey: <file_photo>\r\nAmelia: these are so ni...
# 18  gold_00019         319  Sue: Call me when you get this.\r\nSue: it's i...
# 19  gold_00020         346  Timmy: Who do u wanna invite?\r\nGemma: Well, ...
# 20  gold_00021         355  Ann: Congratulations!!\r\nAnn: You did great, ...
# 21  gold_00022         367  Steve: hiya the dishwasher has turned up\r\nMu...
# 22  gold_00023         393  Marika: Are you coming today?\r\nLara: Yes!\r\...
# 23  gold_00024         417  Miranda: Hi S, could we cancel tomorrow's meet...
# 24  gold_00025         432  Javier: Hey do you know any tattoo parlors ove...
# 25  gold_00026         433  Sam: You own a really nice hotel, guys 😊\r\nJe...
# 26  gold_00027         442  Terence: What the hell, Danny. You took my mon...
# 27  gold_00028         499  Natacha: hi, i can come and pick you up at the...
# 28  gold_00029         528  Meg: still at school?\r\nAnn: i have extra mat...
# 29  gold_00030         532  Pete: What flavour yogurt did you want again? ...
# 30  gold_00031         536  Christie: how are you after the party?\r\nKati...
# 31  gold_00032         537  Sam: Are you working tomorrow?\r\nCarla: No, i...
# 32  gold_00033         544  Joana: wana play some games?\r\nSandy: what ga...
# 33  gold_00034         548  Steve: Bought the new Dream Theater album 5 mi...
# 34  gold_00035         551  Peter: Can you send me the link of your beauty...
# 35  gold_00036         590  Ethan: who's going to see solstafir?\r\nNoah: ...
# 36  gold_00037         598  Bradley: haha look a cat invaded the pitch at ...
# 37  gold_00038         605  Barbara: I'm home already, you can come over\r...
# 38  gold_00039         616  Jake: dude, I just pulled a TOTW\nJake: my fir...
# 39  gold_00040         621  Phil: Good evening Deana! Many thanks for this...
# 40  gold_00041         635  Mell: Hi there! How are you doing?\r\nGloria: ...
# 41  gold_00042         649  Callan: Something's wrong with my Samsung S8.\...
# 42  gold_00043         676  Anna: Mum, I have a awful stomachache.\r\nJoan...
# 43  gold_00044         678  Sam: Where are you?\nKate: downstairs\nSam: al...
# 44  gold_00045         690  Mia: God, he keeps talking about the stupid wa...
# 45  gold_00046         711  Pedro: batman or superman??\r\nAlex: honestly....
# 46  gold_00047         737  Damian: are you downtown?\r\nEthan: yes\r\nEth...
# 47  gold_00048         767  Barry: I'm gonna go march in Women's strike, a...
# 48  gold_00049         799  Martha: Hey, can I ask you a question?\r\nOphe...
# 49  gold_00050         800  Linda: Hi Dad, I want to buy flowers for mum! ...
#
#                                   translated_dialogue  \
# 0   安妮：你说的对，他骗了我：/\n艾琳：哦不，发生了什么？\n简：谁？那马克家伙？\n安妮：是...
# 1   玛丽：嘿，我有点没钱了，借我几盒好吗？\n卡特：好的，给我一个小时，我在火车站。\n玛丽：好...
# 2   蒂娜：我要告诉你一件事，这个阿联酋航空的空乘人员看起来像电影明星一样。\n阿拉：哦，是的，我...
# 3   安娜：你睡着了吗？\n凯瑟琳：还没有。\n安娜：明天想去看外婆吗？我想她了。\n凯瑟琳：是啊...
# 4     乔伊斯：看看这个！\n乔伊斯：<链接>\n迈克尔：好便宜啊！\n埃德森：不信！我现在就订票去！
# 5   简：谷歌地图显示至少需要3小时<文件_其他>\n史蒂文：我以前开车2小时就到了，相信我😄\n...
# 6   菲奥娜：你有空吗？\r\n蒂娜：有啊，怎么了？\r\n菲奥娜：我想为克里斯准备一顿美味的晚餐...
# 7   奥拉弗：我们春节有什么安排吗？\n娜塔莉：我在想一些高雅的活动，比如歌剧之类的。\n佐伊：要...
# 8   约翰：想周三去看《一个明星的诞生》吗？\n乔安：抱歉，不能。\n乔安：非常忙。\n乔安：什么...
# 9   佩顿：我一直让你给我带那个电子游戏。\n卡梅伦：亲爱的，我没有足够的时间回家。\n佩顿：你什...
# 10  保罗：我刚到家。\n\n保罗：今天真忙。\n\n保罗：我把理疗的事给忘了。\n\n艾玛：哦，...
# 11  哈里斯：你好吗？\n莱娜：还好，你呢？\n哈里斯：可以更好。\n莱娜：怎么了？\n哈里斯：我...
# 12  雅兹：今晚去减肥俱乐部吗？\n玛丽：嗯，我不想去，但我真的应该去。我最近真是太放纵自己了！\...
# 13  艾莉：嗨，你在大学吗？\n阿丽亚：是的。\n卡米尔：我生病了：/\n艾莉：糟糕……真不好。\...
# 14  奈森：<文件_视频>\n\n艾伦：天啊!!!\n\n艾伦：😂😂😂😂\n\n艾伦：哈哈哈哈\n...
# 15  弗雷迪：你在Netflix上看什么？我刚刚看完《广告狂人》。\n\n凯利：我刚刚看完《王冠》...
# 16  琼斯：嗨。\n安吉丽娜：嗨。\n安吉丽娜：好久不见。你最近怎么样？\n琼斯：我很好。\n琼斯...
# 17  凯西：<文件_照片>\n阿米莉亚：这些太漂亮了!!! 你自己做的吗？\n克里斯汀：哇哦，太棒...
# 18                 苏：收到后给我打电话。\n苏：很重要。\n史蒂夫：好，我正在打电话。
# 19  蒂米：你想邀请谁？\n杰玛：嗯，有你和你的约会对象:)\n蒂米：约会对象还不确定，但我会去:...
# 20  安：恭喜！！\n\n安：你们两个都做得很棒！\n\n苏：谢谢，安。\n\n朱莉：我很高兴一切...
# 21  史蒂夫：嗨，洗碗机到了。\n妈妈：好极了，他们给你安装了吗？\n史蒂夫：是的，他们干得不错。...
# 22                        玛丽卡：你今天来吗？\n拉拉：来！\n玛丽卡：太好了！
# 23  米兰达：嗨，S，我们能取消明天的会议吗？\n斯蒂芬妮：又是吗？发生了什么事？\n米兰达：我必...
# 24  哈维尔：嘿，你知道这附近有没有纹身店的员工会说英语？\n朱迪：哦，有华沙墨水（Warsaw ...
# 25  山姆：你们拥有一家真的很棒的酒店，伙计们😊\n杰西卡：谢谢你，山姆😊\n迈克尔：谢谢，兄弟\...
# 26  特伦斯：靠，丹尼。你拿了我的钱，对吧？:/\n丹尼尔：什么，你的钱？！为什么要拿我啊？\n特...
# 27  娜塔莎：你好，我可以去RER接你。\n查尔斯：太好了。我刚落地。我想我大约5点半到。我会给你...
# 28    梅格：还在学校吗？\n安：我有额外的数学课。\n梅格：那什么时候能见你？\n安：我七点钟到家。
# 29  皮特：你要哪种口味的酸奶来着？我今天脑子像筛子一样。\n珍：梨味的，但只有他们有才行。否则不...
# 30  克里斯蒂：派对后你怎么样？\n凯蒂：真的很累......你呢？\n克里斯蒂：一样。\n克里斯...
# 31  山姆：你明天工作吗？\n卡拉：不，我放假。\n山姆：我下午有空，想见面吗？\n卡拉：嗯，可以...
# 32  乔安娜：想玩点游戏吗？\n桑迪：什么游戏？\n乔安娜：也许是迪西特？\n乔安娜：或者卡卡松？...
# 33  史蒂夫：五分钟前买了新的梦想剧院专辑。希望它不错。\n罗布：我这儿桌子上就有，准备第一次听了...
# 34  彼得：你能给我你的美容店链接吗？\n乔伊：当然可以。\n乔伊：是这个：https:// **...
# 35  伊森：谁要去看索拉斯特法？\n诺亚：索拉斯特法！什么时候？\n诺亚：我完全不知道他们要演出。...
# 36  布拉德利：哈哈，看，一只猫入侵了古迪逊球场。<文件_其他>\n吉尔：哈哈哈哈\n朱莉娅：多可...
# 37  芭芭拉：我已经到家了，你可以过来。\n肖恩：我能带狗来吗？\n扎克：我正在来的路上。\n芭芭...
# 38  杰克：兄弟，我刚抽到一个TOTW！\n杰克：今年第一个！\n汤姆：恭喜啊！\n汤姆：要卖掉吗...
# 39  菲尔：晚上好，迪娜！非常感谢你寄来这张漂亮卡片。康斯坦丁很高兴！\n菲尔：这些太阳镜也是你送...
# 40  梅尔：你好！你最近怎么样？\n\n格洛丽亚：你好，梅尔！我们还好，就是日常的忙碌啦;) 你们...
# 41  卡兰：我的三星S8出问题了。\n韦德：具体是什么问题？\n卡兰：我只看到黑屏。\n韦德：你是...
# 42  安娜：妈妈，我肚子疼得厉害。\n乔安娜：哦，亲爱的，什么时候开始的？\n安娜：晚上，而且一直...
# 43  山姆：你在哪里？\n凯特：楼下。\n山姆：已经到了吗？\n凯特：是的，快下来吧。\n杰夫：我...
# 44  米娅：天啊，他一直谈论那愚蠢的墙。\n詹妮弗：我觉得他只是老糊涂了。\n卡琳：不幸的是，这远...
# 45  佩德罗：蝙蝠侠还是超人？\n亚历克斯：老实说... 都不是。\n佩德罗：什么？！\n亚历克斯...
# 46  达米安：你在市中心吗？\n伊森：是的\n伊森：怎么了？\n达米安：能不能帮我买个烤肉串？\n...
# 47  巴里：我要去参加妇女罢工游行，有没有人感兴趣？\n杰克：我有兴趣，已经和一些朋友做了计划，你...
# 48  玛莎：嗨，可以问你一个问题吗？\n奥菲莉亚：我们认识吗？\n玛莎：不认识，但我可以问你关于你...
# 49  琳达：爸爸，我想给妈妈买花！但是我不记得她喜欢哪种了 :(\n迈克尔：嗯，我相信她喜欢所有的...
#
#                                         final_summary  \
# 0                            安妮发现马克撒谎了，他实际比他说的年龄大10岁。
# 1                          玛丽向卡特借钱，卡特答应了，一小时后会在火车站见面。
# 2   蒂娜向阿拉诉说在机场的不愉快经历，包括空乘人员的外表和等待时间。阿拉安慰她，并提及自己正前往...
# 3          安娜和凯瑟琳讨论明天去看外婆，凯瑟琳同意了，并约定起床后打电话给安娜。她们互道晚安。
# 4               乔伊斯分享了一个便宜的票务链接，迈克尔和埃德森表示感兴趣，埃德森立即订票。
# 5   简和史蒂文讨论了前往目的地的时间和路线。简担心需要3小时，但史蒂文坚持2小时足够，并保证会准...
# 6   菲奥娜想做塔特馅饼给克里斯，向蒂娜求助。蒂娜同意帮忙，并解释了制作过程，提到加入鸡蛋需不断搅...
# 7   奥拉弗询问春节安排，娜塔莉提议高雅活动，如歌剧。后经讨论，三人决定参加蒂芙尼早餐派对，并计划...
# 8   约翰邀请乔安周三看电影《一个明星的诞生》，但乔安因忙无法前往。两人商定周四晚上八点左右一起看...
# 9   佩顿让卡梅伦带电子游戏，但卡梅伦因出差无暇。佩顿建议快递，卡梅伦表示工作繁忙。佩顿催促他尽快回家。
# 10  保罗刚到家，觉得今天很忙，把理疗的事忘了。他想再约新时间，并提议为半夜才到家的艾玛准备食物，...
# 11  哈里斯告诉莱娜他的朋友青木昨天去世了，原因不明。哈里斯感到难过，莱娜安慰他，并提到他们几个月...
# 12  雅兹和玛丽讨论今晚是否去减肥俱乐部。两人都承认最近放纵自己，决定去参加，尽管有些不情愿。雅兹...
# 13  艾莉询问阿丽亚是否在大学，并表达了对卡米尔生病的关心。她还问了当前的上课地点，阿丽亚回答是在...
# 14  奈森向艾伦展示了一个视频，艾伦觉得非常好笑，并用一系列GIF表达了自己的反应。他们讨论了视频...
# 15  群友们在讨论他们在Netflix上观看的节目。弗雷迪刚看完《广告狂人》，凯利看完《王冠》，并...
# 16                   琼斯与安吉丽娜久别重逢，约定下午在镇上见面，琼斯将电话确认地点。
# 17  凯西展示了她自己花费四个小时完成的美丽指甲。阿米莉亚和克里斯汀很喜欢，希望凯西也能为她们做，...
# 18             苏提醒史蒂夫收到东西后立即打电话，并强调此事重要性。史蒂夫回应正在拨打电话。
# 19  蒂米和杰玛讨论参加婚礼邀请。杰玛想邀请蒂米、他的约会对象、洛娜和米歇尔。蒂米质疑杰玛是否想收...
# 20       安祝贺苏和朱莉，称赞他们表现出色。朱莉高兴一切结束，并赞扬安可爱。大家决定今晚小聚庆祝。
# 21  史蒂夫向妈妈展示了新安装的洗碗机，并分享了其安静和高效的特点。妈妈很开心，认为这是一次好的购...
# 22                        玛丽卡问拉拉今天是否会来，拉拉回答会来，玛丽卡很高兴。
# 23  米兰达想取消明天的会议，因为她需要工作。斯蒂芬妮表达了对年轻医生过度工作的担忧，但米兰达认为...
# 24  哈维尔询问附近有无英语流利的纹身店员工，朱迪推荐华沙墨水，并分享了女友的纹身照片。哈维尔对设...
# 25  山姆赞扬了酒店，并询问下个月的房间安排。迈克尔确认了8月15日的入住，山姆表示下午2点抵达。...
# 26            特伦斯指责丹尼尔偷了他的钱，但后来发现是自己记错了位置。丹尼尔感到生气和委屈。
# 27            娜塔莎将去RER接查尔斯，他预计下午5点半到达，并在到达韦西内特车站时联系她。
# 28                         梅格问安是否还在学校，安说有额外数学课，七点钟到家。
# 29  皮特询问珍想要哪种口味的酸奶，珍指定梨味，但表示如果没有也可以不买。皮特提议找其他口味，但珍...
# 30                  克里斯蒂和凯蒂在聚会后感到很累，但她们都认为聚会很棒，玩得很开心。
# 31       山姆和卡拉约定明天下午在米恩木德的咖啡馆见面，品尝那里的美味蛋糕。具体时间定在下午2点。
# 32           乔安娜邀请桑迪玩游戏，建议玩《迪西特》或《卡卡松》。桑迪同意，乔安娜将带来游戏。
# 33                史蒂夫刚买了梦想剧院的新专辑，期待中。罗布已有专辑，两人将分享听后感。
# 34                 彼得向乔伊索要了她的美容店链接，乔伊提供了网址并表示可随时询问问题。
# 35  伊森邀请大家11月21日去看索拉斯特法的演唱会，诺亚可能因加班无法参加，里奥强烈要求他出席。...
# 36    布拉德利、吉尔和朱莉娅讨论了一只入侵古迪逊球场的猫，他们认为这是埃弗顿球迷本赛季最精彩的娱乐。
# 37                       芭芭拉邀请肖恩和扎克到家里，肖恩可以带狗来，并决定留宿。
# 38  杰克抽到了今年的第一个TOTW，打算卖掉因为不适合他的阵容。汤姆祝贺了他，并提到自己今年运气...
# 39  菲尔和迪娜讨论了一副太阳镜的所有权。迪娜在收音机上发现它，可能属于阿德里安。最终，他们决定保...
# 40  梅尔和格洛丽亚聊天，讨论各自近况。孩子们离开家后，梅尔享受宁静的生活，格洛丽亚安慰她别内疚。...
# 41  卡兰的三星S8出现黑屏问题，可能因过热导致。他计划去商店维修，因仍在保修期内。韦德提醒要注意...
# 42  安娜告诉乔安娜她从晚上开始肚子疼，可能与早餐有关。乔安娜猜测可能是食物变质，建议观察一下。安...
# 43  山姆和凯特在讨论楼下的一个聚会。凯特注意到一个做蛋糕的女人，蛋糕上有一个巨大的阴茎。山姆表示...
# 44  对话中，大家讨论了特朗普的行为和动机。卡琳认为他不仅仅是糊涂，而是利用民粹主义策略来恐吓人们...
# 45  佩德罗和亚历克斯讨论超级英雄。亚历克斯认为闪灵比蝙蝠侠和超人更强，因为他几乎能做任何事，包括...
# 46  达米安向伊森求助，请求他帮忙买烤肉串，因为他很饿。伊森同意了，但希望达米安不要总是依赖他人。...
# 47                 巴里发起妇女罢工游行邀请，杰克、戴夫及凯利响应，午间在校园周边集合。
# 48  玛莎向奥菲莉亚询问了她头像中隐形眼镜的品牌，奥菲莉亚推荐了疯狂隐形眼镜（Crazy Lens...
# 49     琳达想给妈妈买花，向父亲迈克尔求助。迈克尔建议她发照片选择，最终确定了郁金香、玫瑰和自由花。
#
#                             reference_english_summary  \
# 0        Mark lied to Anne about his age. Mark is 40.
# 1   Mary ran out of money. Carter is going to lend...
# 2   Tina will catch the evening flight back home. ...
# 3   Ana wants to visit grandma tomorrow. Catherine...
# 4                    Edson is booking his ticket now.
# 5   Jane wants to leave at 4.30 instead of 5 becau...
# 6   Fiona wants to prepare dinner for Chris. She i...
# 7   Nathalie, Olafur and Zoe are planning the New ...
# 8   Joan and John are going to watch "A Star is Bo...
# 9   Peyton is expecting Cameron to bring the video...
# 10  Paul forgot about his physiotherapy and he wil...
# 11  Harris' friend, Aoki, who lives in Michigan, d...
# 12  Yaz and Mary are meeting tonight around 6 and ...
# 13       Ellie's class is in 342 on the second floor.
# 14  Nathan and Aaron are discussing a video which ...
# 15  Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Al...
# 16  Jones and Angelina will meet in town in the af...
# 17  Casey got a new nail polish and did her nails ...
# 18               Steve is calling Sue at her request.
# 19  Gemma will invite Timmy and his Date, as well ...
# 20  Ann, Sue and Julie did a great job and they wi...
# 21  Steve is happy that he got a new dishwasher in...
# 22                            Marika is coming today.
# 23  Miranda can't make her meeting with Stephanie ...
# 24  Javier was initially eager to have a tatoo don...
# 25  Sam appreciates the hotel owned by Jessica and...
# 26  Terence accused Daniel of taking his money. Te...
# 27  Charles has just landed and he will be at RER ...
# 28  Ann is still at school. She will be home at 7 ...
# 29  Pete will get a pear yogurt for Jen if they ha...
# 30  Christie and Katie are tired after the party. ...
# 31  Carla has a day off tomorrow. She will meet Sa...
# 32  Joana will bring Sandy some games like dixit a...
# 33  Steve and Rob will talk about new Dream Theate...
# 34        Joy sent Peter the link to her beauty shop.
# 35  Ethan and Leo are going to see Sólstafir on 21...
# 36  A sweet little black cat got into the pitch du...
# 37  Barbara, Sean and Zac are meeting at Barbara's...
# 38  Jake has got his first TOTW this year. Tom doe...
# 39  Phil received a card from Deana. Constantine w...
# 40  Gloria and Mell plan to have a barbeque at Mel...
# 41  Callan's Samsung S8 overheats, so he's going t...
# 42  Anna got an awful stomachache at night but she...
# 43  Kate and Jeff are downstairs in a room next to...
# 44  Mia, Jennifer, Karine and Peter do not like Tr...
# 45  Alex prefers the Flash to Barman and Superman ...
# 46  Ethan will buy Damian a kebab. Damian had a ba...
# 47  Barry, Dave, Kelly, and Jake will meet around ...
# 48  Martha likes Ophelia's lenses and wants to buy...
# 49  Linda wants to buy flowers for her mother and ...
#
#                             reference_chinese_summary
# 0                                马克向安妮隐瞒了自己的年龄。他40岁了。
# 1                              玛丽的钱用完了，卡特打算一小时后借给她一点。
# 2                 蒂娜将乘晚间航班回家。阿拉正在去开会的路上。她会让蒂娜知道事情的进展。
# 3                   安娜明天想去看望奶奶。凯瑟琳会和她一起去。她起床后会给安娜打电话。
# 4                                            埃德森正在订票。
# 5   简想4点半就走，而不是等到5点，因为谷歌地图提示300公里的车程至少需要3小时，她不想迟到。...
# 6                    菲奥娜想为克里斯准备晚餐。她想起了蒂娜做的馅饼。蒂娜会帮她做的。
# 7   娜塔莉、奥拉维尔和佐伊正在做新年前夜的计划。娜塔莉想要有格调的。但奥拉维尔不喜欢歌剧。他们想...
# 8                           琼和约翰星期四晚上8点左右去看《一个明星的诞生》。
# 9                      佩顿希望卡梅隆能带游戏机过来，但是卡梅隆可能还要再缺席一周。
# 10             保罗忘记去做理疗了，得重新预约。艾玛午夜后回家，所以保罗会给她准备一些吃的。
# 11                  哈里斯的朋友青木住在密歇根州，昨天去世了。哈里斯有几个月没见她了。
# 12                亚兹和玛丽今晚6点左右见面，一起去减肥俱乐部。他们估计吃得太多会被骂。
# 13                                     艾莉的班级在二楼342教室。
# 14                                  内森和亚伦正在讨论内森发来的视频。
# 15     弗雷迪、凯利、吉姆、格雷格、鲍勃、迈克、玛丽、艾伦和南希正在netflix上观看不同的节目。
# 16                                   琼斯和安吉丽娜下午会在城里见面。
# 17      凯西买了新指甲油，自己做了指甲。她花了近4个小时，所以她不会帮朋友做指甲，因为耗时太长了。
# 18                                   史蒂夫正按照苏的要求给她打电话。
# 19                     杰玛将邀请蒂米和他的约会对象，以及罗娜和米歇尔参加她的婚礼。
# 20                       安、苏和朱莉做得很好，今晚他们会举行一个小小的庆祝活动。
# 21                                  史蒂夫很高兴他装了一台新的洗碗机。
# 22                                           玛丽卡今天会来。
# 23                                米兰达不能去见斯蒂芬妮，因为她要工作。
# 24           哈维尔最初很想在warsaw ink纹身，但价格太高了。他决定去哥伦比亚做纹身。
# 25                 山姆很喜欢杰西卡和迈克尔的酒店。他会在8月15日下午2点左右去那里。
# 26           特伦斯指控丹尼尔偷了他的钱。后来他找到了钱，就向丹尼尔道歉。但是丹尼尔还在生气。
# 27                   查尔斯刚刚落地，他会在下午五点半到达rer，娜塔夏会在那里接他。
# 28                         安还在学校，她7点会回家，这样她就可以和麦格见面了。
# 29                               如果商店里有梨味酸奶， 皮特会给珍买的。
# 30                            克里斯蒂和凯蒂在聚会后累了。他们都玩得很开心。
# 31              卡拉明天有一天假。她将在下午两点在meanwood的一个咖啡馆和山姆见面。
# 32                         琼娜将为桑迪带来一些像迪克西特和卡尔卡松这样的游戏。
# 33                              史蒂夫和罗伯将在听完后谈论新的梦剧场专辑。
# 34                                   乔伊把她美容店的链接发给了彼得。
# 35              伊森和里奥要在21点11分去见索斯塔弗。诺亚也想去，但他可能得工作到很晚。
# 36                          在埃弗顿的足球比赛中，一只可爱的小黑猫钻进了球场。
# 37           芭芭拉、肖恩和扎克今晚在芭芭拉家见面。肖恩会把狗带来的，肖恩和扎克会在这里过夜。
# 38                         杰克今年拿到了第一个totw ，汤姆的团队并不出色。
# 39  菲尔收到了迪安娜的一张卡片，康斯坦丁很开心。菲尔有副墨镜。蒂娜在后面收音机上面找到的。迪安娜...
# 40  格洛丽亚和梅尔计划星期六在梅尔家吃烧烤。他们很高兴，因为泰德的姐姐搬到了苏格兰。梅尔需要格洛...
# 41                              卡伦的三星s8过热了，所以他要去店里修理。
# 42         安娜夜里胃疼得厉害，但她不知道其中的原因。她的妈妈乔安娜会用新鲜的薄荷叶为她做热茶。
# 43                   凯特和杰夫在楼下接待处旁边的一个房间里。有位女士正在做杏仁蛋糕。
# 44                                米亚、珍妮弗、卡琳和彼得不喜欢特朗普。
# 45                                 阿莱克斯更喜欢闪电侠，因为他的速度。
# 46                            伊森会请达米安吃烤肉串，达米安今天过得很糟糕。
# 47                    巴里、戴夫、凯利和杰克将于12点在校园附近集合，参加妇女罢工。
# 48             玛莎喜欢奥菲莉娅的眼镜，想买类似的，奥菲莉娅是从crazy lens上买的。
# 49                  琳达想给她妈妈买花，问迈克尔她喜欢哪种花。迈克尔建议琳达买小苍兰。
